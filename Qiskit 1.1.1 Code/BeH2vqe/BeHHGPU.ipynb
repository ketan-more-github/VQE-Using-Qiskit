# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import Aer
from qiskit_ibm_runtime import QiskitRuntimeService, Session
try:
    backend = Aer.get_backend('aer_simulator_statevector_gpu')
    backend.set_options(device='GPU')
    backend.set_options(cuStateVec_enable=False)
    print("GPU options set successfully." , backend)
except Exception as e:
    print(f"Failed to set GPU options: {e}")
# Out:
# GPU options set successfully. AerSimulator('aer_simulator_statevector_gpu')

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver

dist = 2.5811

molecule = MoleculeInfo(
    symbols=["Be", "H" , "H" ],
    coords=([0.0, 0.0, 0.0], [dist, 0.0, 0.0] ,[0.0, 0.0 , -dist] ),
    multiplicity=1,  # = 2*spin + 1
    charge=0,
)


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, remove_orbitals=[4,5,6,7]
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['IIII', 'IIIZ', 'IIZZ', 'IIZI', 'IZII', 'IZIZ', 'XXII', 'XXIZ', 'YYII', 'YYIZ', 'ZZII', 'ZZIZ', 'ZIII', 'ZIIZ', 'IIXX', 'IIYY', 'ZXZX', 'IXZX', 'ZXIX', 'IXIX', 'XZZX', 'XIZX', 'XZIX', 'XIIX', 'IZXX', 'IZYY', 'XXXX', 'YYXX', 'XXYY', 'YYYY', 'ZZXX', 'ZZYY', 'ZIXX', 'ZIYY', 'IZZZ', 'XXZZ', 'YYZZ', 'ZZZZ', 'ZIZZ', 'ZXXZ', 'IXXZ', 'ZXXI', 'IXXI', 'XZXZ', 'XIXZ', 'XZXI', 'XIXI', 'IZZI', 'XXZI', 'YYZI', 'ZZZI', 'ZIZI'],
#               coeffs=[-2.11103338e+00+0.j,  2.69208825e-01+0.j,  2.32536399e-01+0.j,
#   1.98724223e-01+0.j,  2.69208825e-01+0.j,  8.17375792e-02+0.j,
#  -1.45362612e-02+0.j,  3.84156784e-03+0.j, -1.45362612e-02+0.j,
#   3.84156784e-03+0.j,  2.32536399e-01+0.j,  7.41994454e-02+0.j,
#   1.98724223e-01+0.j,  7.53380127e-02+0.j, -1.45362612e-02+0.j,
#  -1.45362612e-02+0.j,  2.49553857e-02+0.j, -2.49553857e-02+0.j,
#  -2.49553857e-02+0.j,  2.49553857e-02+0.j, -2.30856285e-02+0.j,
#   2.30856285e-02+0.j,  2.30856285e-02+0.j, -2.30856285e-02+0.j,
#   3.84156784e-03+0.j,  3.84156784e-03+0.j,  2.22916402e-02+0.j,
#   2.22916402e-02+0.j,  2.22916402e-02+0.j,  2.22916402e-02+0.j,
#  -1.72498864e-02+0.j, -1.72498864e-02+0.j,  1.12800271e-03+0.j,
#   1.12800271e-03+0.j,  7.41994454e-02+0.j, -1.72498864e-02+0.j,
#  -1.72498864e-02+0.j,  9.21365386e-02+0.j,  7.78420005e-02+0.j,
#  -2.30856285e-02+0.j,  2.30856285e-02+0.j,  2.30856285e-02+0.j,
#  -2.30856285e-02+0.j,  3.03166078e-02+0.j, -3.03166078e-02+0.j,
#  -3.03166078e-02+0.j,  3.03166078e-02+0.j,  7.53380127e-02+0.j,
#   1.12800271e-03+0.j,  1.12800271e-03+0.j,  7.78420005e-02+0.j,
#   8.14614564e-02+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"Number of qubits = {var_form.num_qubits}")
print(f"using usscd = {num_params1}")
# Out:
# Number of qubits = 4
# using usscd = 8

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(" ")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([0.52877994, 1.76061579, 2.24764331, 2.5714327 , 0.80619159,
#        3.13108241, 3.00747878, 0.39210386])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
#
# Iters. done: 1 [Current cost: -2.473682401838649]
# Current parameters: [1.52877994 1.76061579 2.24764331 2.5714327  0.80619159 3.13108241
#  3.00747878 0.39210386]
# Device time: 0.7553 seconds
#
# Iters. done: 2 [Current cost: -2.4885231484264616]
# Current parameters: [1.52877994 2.76061579 2.24764331 2.5714327  0.80619159 3.13108241
#  3.00747878 0.39210386]
# Device time: 0.5217 seconds
#
# Iters. done: 3 [Current cost: -2.4978810754655525]
# Current parameters: [1.52877994 2.76061579 3.24764331 2.5714327  0.80619159 3.13108241
#  3.00747878 0.39210386]
# Device time: 0.5429 seconds
#
# Iters. done: 4 [Current cost: -2.488173740666663]
# Current parameters: [1.52877994 2.76061579 2.24764331 3.5714327  0.80619159 3.13108241
#  3.00747878 0.39210386]
# Device time: 0.5167 seconds
#
# Iters. done: 5 [Current cost: -2.5025208263203313]
# Current parameters: [1.52877994 2.76061579 2.24764331 3.5714327  1.80619159 3.13108241
#  3.00747878 0.39210386]
# Device time: 0.5499 seconds
#
# Iters. done: 6 [Current cost: -2.441457747818062]
# Current parameters: [1.52877994 2.76061579 2.24764331 3.5714327  0.80619159 4.13108241
#  3.00747878 0.39210386]
# Device time: 0.5383 seconds
#
# Iters. done: 7 [Current cost: -2.488354542192589]
# Current parameters: [1.52877994 2.76061579 2.24764331 3.5714327  0.80619159 3.13108241
#  4.00747878 0.39210386]
# Device time: 0.7041 seconds
#
# Iters. done: 8 [Current cost: -2.447453186713481]
# Current parameters: [1.52877994 2.76061579 2.24764331 3.5714327  0.80619159 3.13108241
#  3.00747878 1.39210386]
# Device time: 0.5428 seconds
#
# Iters. done: 9 [Current cost: -2.438887272464537]
# Current parameters: [ 1.6675656   2.84812797  2.15686359  3.61482209  0.23515027  2.99860409
#   2.49250478 -0.20297567]
# Device time: 0.5614 seconds
#
# Iters. done: 10 [Current cost: -2.3793319236358026]
# Current parameters: [1.59817277 2.80437188 2.20225345 3.5931274  0.52067093 3.06484325
#  2.74999178 0.09456409]
# Device time: 0.5640 seconds
#
# Iters. done: 11 [Current cost: -2.459213106669763]
# Current parameters: [1.7717082  2.76061579 2.24764331 3.5714327  0.86523278 3.13108241
#  3.00747878 0.39210386]
# Device time: 0.5814 seconds
#
# Iters. done: 12 [Current cost: -2.4654808997080373]
# Current parameters: [1.20238588 2.77537768 2.23233023 3.57875179 1.1595177  3.10873545
#  2.92061097 0.29172354]
# Device time: 0.5760 seconds
#
# Iters. done: 13 [Current cost: -2.5618947256630467]
# Current parameters: [0.82784196 2.79703207 2.20986731 3.58948825 1.24888473 3.07595445
#  2.79318359 0.58039166]
# Device time: 0.5502 seconds
#
# Iters. done: 14 [Current cost: -2.5197044390631165]
# Current parameters: [1.20238588 2.77537768 1.98612633 3.57875179 1.1595177  3.10873545
#  2.96401184 0.29172354]
# Device time: 0.5900 seconds
#
# Iters. done: 15 [Current cost: -2.5841882866634576]
# Current parameters: [1.02022199 2.78590955 1.95298981 3.5839736  1.20298241 3.09279202
#  3.35414053 0.04426379]
# Device time: 0.5516 seconds
#
# Iters. done: 16 [Current cost: -2.5863040145954774]
# Current parameters: [1.02383014 3.03459091 1.95062972 3.5839736  1.18813649 3.09279202
#  3.34075225 0.02879292]
# Device time: 0.5928 seconds
#
# Iters. done: 17 [Current cost: -2.598663288568671]
# Current parameters: [ 0.91725902  3.0347996   1.82128162  3.58813661  1.06373279  3.08008132
#   3.06787507 -0.33424219]
# Device time: 0.5668 seconds
#
# Iters. done: 18 [Current cost: -2.607375100718823]
# Current parameters: [ 0.94038114  3.0347996   1.82128162  3.58813661  1.06935238  2.83121632
#   3.06787507 -0.33424219]
# Device time: 0.5746 seconds
#
# Iters. done: 19 [Current cost: -2.5933917051962143]
# Current parameters: [ 1.10278239  3.12215704  1.66793349  3.59557075  1.4501297   3.19607298
#   3.02099585 -0.47361415]
# Device time: 0.5561 seconds
#
# Iters. done: 20 [Current cost: -2.6264631488543926]
# Current parameters: [ 1.31209337  3.24000415  1.44234669  3.88386896  1.29932595  3.36042918
#   3.09715134 -0.52597169]
# Device time: 0.5724 seconds
#
# Iters. done: 21 [Current cost: -2.6066789098165857]
# Current parameters: [ 1.25059788  3.11428986  1.67609442  3.42645311  1.36935193  3.20798253
#   3.06729103 -0.52939214]
# Device time: 0.5706 seconds
#
# Iters. done: 22 [Current cost: -2.654752321009697]
# Current parameters: [ 1.22290001  3.22829631  1.46752978  3.00660709  1.36479486  3.33490808
#   3.06894385 -0.51117468]
# Device time: 0.5680 seconds
#
# Iters. done: 23 [Current cost: -2.6113205879732146]
# Current parameters: [ 1.41990451  3.17536955  2.07229156  3.40771422  1.39226198  3.30715213
#   3.04696756 -0.75189761]
# Device time: 0.5767 seconds
#
# Iters. done: 24 [Current cost: -2.6742691775485445]
# Current parameters: [ 1.44622563  2.76298725  2.05409756  3.39875454  1.44791976  3.35873271
#   3.24070354 -0.94043083]
# Device time: 0.5551 seconds
#
# Iters. done: 25 [Current cost: -2.6598081271134126]
# Current parameters: [ 1.53834329  3.06240085  2.06200231  3.40163494  1.36923704  3.31763639
#   2.886956   -0.65533812]
# Device time: 0.5745 seconds
#
# Iters. done: 26 [Current cost: -2.6659312953581087]
# Current parameters: [ 1.33653829  3.33675402  2.40444897  3.41444666  1.57119291  3.49774208
#   2.92452401 -0.90453454]
# Device time: 0.5530 seconds
#
# Iters. done: 27 [Current cost: -2.630911586078598]
# Current parameters: [ 1.51722479  3.21819697  2.08114172  3.40039645  1.41567588  3.09222204
#   3.06680301 -0.81455621]
# Device time: 0.6001 seconds
#
# Iters. done: 28 [Current cost: -2.6704955616923085]
# Current parameters: [ 1.4341987   3.16889559  2.11514286  3.38520297  1.44355213  3.30098993
#   3.10352596 -0.66723198]
# Device time: 0.5613 seconds
#
# Iters. done: 29 [Current cost: -2.6825864315572163]
# Current parameters: [ 1.57880415  3.23835354  2.09277029  3.48462192  1.38017473  3.37948086
#   3.22530765 -0.63019285]
# Device time: 0.5812 seconds
#
# Iters. done: 30 [Current cost: -2.6753361944032754]
# Current parameters: [ 1.39891494  3.14280889  2.18366383  3.43967085  1.37587291  3.26830143
#   3.10846522 -0.64814651]
# Device time: 0.5569 seconds
#
# Iters. done: 31 [Current cost: -2.6752904645593247]
# Current parameters: [ 1.4271847   3.19483715  2.10661723  3.1696232   1.3431104   3.3052211
#   3.16330953 -0.62786198]
# Device time: 0.5711 seconds
#
# Iters. done: 32 [Current cost: -2.6763817577030764]
# Current parameters: [ 1.33463898  3.18272572  1.96796786  3.41235024  1.55103125  3.25292114
#   3.1443255  -0.54693169]
# Device time: 0.5950 seconds
#
# Iters. done: 33 [Current cost: -2.675021003203021]
# Current parameters: [ 1.44399271  3.07372279  2.11067732  3.37450632  1.47505591  3.31218821
#   3.16176218 -0.70998136]
# Device time: 0.5630 seconds
#
# Iters. done: 34 [Current cost: -2.6866775340463565]
# Current parameters: [ 1.41479141  3.1049943   2.12678277  3.37610763  1.4875282   3.31787061
#   3.19139661 -0.73732418]
# Device time: 0.5691 seconds
#
# Iters. done: 35 [Current cost: -2.6787232120959015]
# Current parameters: [ 1.50794737  3.02407272  2.13500039  3.34975048  1.52805545  3.33412022
#   3.10428736 -0.67431779]
# Device time: 2.3149 seconds
#
# Iters. done: 36 [Current cost: -2.681298491105244]
# Current parameters: [ 1.41397456  3.06369372  2.10138496  3.37985443  1.47099004  3.36103869
#   3.15760597 -0.69076017]
# Device time: 0.5432 seconds
#
# Iters. done: 37 [Current cost: -2.6817657362240923]
# Current parameters: [ 1.43695469  3.05244922  2.02768442  3.38701171  1.49648614  3.23997877
#   3.18178843 -0.66521322]
# Device time: 0.5580 seconds
#
# Iters. done: 38 [Current cost: -2.686902683138796]
# Current parameters: [ 1.46663103  3.06258612  2.0214832   3.43618364  1.50383591  3.25549727
#   3.19488889 -0.66531013]
# Device time: 0.5655 seconds
#
# Iters. done: 39 [Current cost: -2.6877397433197365]
# Current parameters: [ 1.53391063  3.0692      1.99998395  3.3878159   1.4338589   3.26763764
#   3.24875159 -0.64776889]
# Device time: 0.5628 seconds
#
# Iters. done: 40 [Current cost: -2.689102075962135]
# Current parameters: [ 1.54245986  3.08113999  1.96009949  3.37476515  1.44238644  3.2819563
#   3.22824648 -0.68285881]
# Device time: 0.5610 seconds
#
# Iters. done: 41 [Current cost: -2.689688100244615]
# Current parameters: [ 1.55508953  3.02874055  1.95737459  3.41765707  1.36584044  3.24381477
#   3.19005096 -0.72868113]
# Device time: 0.5482 seconds
#
# Iters. done: 42 [Current cost: -2.683635298170816]
# Current parameters: [ 1.58429813  3.06356538  1.98423448  3.35986546  1.466392    3.27644973
#   3.20746007 -0.6848031 ]
# Device time: 0.5618 seconds
#
# Iters. done: 43 [Current cost: -2.692517521118763]
# Current parameters: [ 1.64376342  3.06229578  1.94531073  3.33562515  1.53186123  3.28012149
#   3.18959297 -0.6115523 ]
# Device time: 0.5570 seconds
#
# Iters. done: 44 [Current cost: -2.700148510127588]
# Current parameters: [ 1.71282653  3.08367717  1.93489319  3.30151347  1.61862661  3.25759023
#   3.21670619 -0.59271149]
# Device time: 0.5750 seconds
#
# Iters. done: 45 [Current cost: -2.700187355020919]
# Current parameters: [ 1.70527688  3.03487568  1.92324791  3.29959555  1.63299876  3.2761569
#   3.24313397 -0.60158106]
# Device time: 0.5653 seconds
#
# Iters. done: 46 [Current cost: -2.698538670735764]
# Current parameters: [ 1.7402047   3.09803642  1.95737182  3.28465558  1.6202695   3.34881995
#   3.16065633 -0.54359302]
# Device time: 0.7221 seconds
#
# Iters. done: 47 [Current cost: -2.69147497802074]
# Current parameters: [ 1.74168019  3.08647712  1.92925302  3.35493705  1.61694316  3.26725659
#   3.22362681 -0.59869636]
# Device time: 0.6191 seconds
#
# Iters. done: 48 [Current cost: -2.6978762341141067]
# Current parameters: [ 1.73050631  3.03843672  1.88925033  3.29059151  1.59466636  3.17281056
#   3.16526635 -0.56711024]
# Device time: 0.5882 seconds
#
# Iters. done: 49 [Current cost: -2.7004728106336966]
# Current parameters: [ 1.75212932  3.04970987  1.86151155  3.26888556  1.55819817  3.18391946
#   3.19009121 -0.56829874]
# Device time: 0.9555 seconds
#
# Iters. done: 50 [Current cost: -2.6999378511559198]
# Current parameters: [ 1.67448517  3.08273601  1.79787136  3.29972494  1.63247275  3.18118194
#   3.14610165 -0.58207622]
# Device time: 0.5865 seconds
#
# Iters. done: 51 [Current cost: -2.706021748950349]
# Current parameters: [ 1.65663888  3.08653944  1.79661628  3.31256303  1.63004743  3.17580026
#   3.17109656 -0.52966141]
# Device time: 0.5624 seconds
#
# Iters. done: 52 [Current cost: -2.7049435237589865]
# Current parameters: [ 1.61553216  3.13570564  1.78721828  3.27764878  1.64644587  3.11244594
#   3.16375678 -0.64133265]
# Device time: 0.5802 seconds
#
# Iters. done: 53 [Current cost: -2.7006841240588213]
# Current parameters: [ 1.67171983  3.09160183  1.78498554  3.28023333  1.64157991  3.21273068
#   3.10251116 -0.56488206]
# Device time: 0.5619 seconds
#
# Iters. done: 54 [Current cost: -2.702311553967511]
# Current parameters: [ 1.69187158  3.08809293  1.79524337  3.2914218   1.65415626  3.17558994
#   3.1529088  -0.57739133]
# Device time: 0.5849 seconds
#
# Iters. done: 55 [Current cost: -2.7015305146352837]
# Current parameters: [ 1.67740745  3.08445082  1.78512428  3.35455528  1.61152322  3.18663932
#   3.13795859 -0.59589432]
# Device time: 0.5699 seconds
#
# Iters. done: 56 [Current cost: -2.7064993932174852]
# Current parameters: [ 1.68152532  3.07094728  1.77313756  3.35172479  1.60612285  3.16612495
#   3.12617183 -0.5898416 ]
# Device time: 0.5988 seconds
#
# Iters. done: 57 [Current cost: -2.708001600250244]
# Current parameters: [ 1.65653621  3.02194427  1.75636015  3.34972797  1.60701555  3.18000255
#   3.14100267 -0.60332096]
# Device time: 0.5948 seconds
#
# Iters. done: 58 [Current cost: -2.702254398200916]
# Current parameters: [ 1.68951237  3.07860041  1.75514276  3.34147128  1.5899621   3.17199184
#   3.13748479 -0.59113715]
# Device time: 0.6579 seconds
#
# Iters. done: 59 [Current cost: -2.704040651818185]
# Current parameters: [ 1.68401208  3.0628954   1.82106292  3.35278133  1.57533595  3.14991301
#   3.10852931 -0.58592275]
# Device time: 0.6087 seconds
#
# Iters. done: 60 [Current cost: -2.7036477725585812]
# Current parameters: [ 1.66021979  3.08243243  1.77144541  3.34403335  1.60384587  3.15348256
#   3.12562116 -0.60262395]
# Device time: 0.6248 seconds
#
# Iters. done: 61 [Current cost: -2.704163486658461]
# Current parameters: [ 1.69271141  3.07765226  1.76175551  3.39287232  1.63484342  3.16081239
#   3.10773985 -0.56299644]
# Device time: 0.6051 seconds
#
# Iters. done: 62 [Current cost: -2.699837851299704]
# Current parameters: [ 1.69856391  3.06689326  1.77930957  3.3441333   1.62086134  3.15481142
#   3.13565685 -0.60162738]
# Device time: 0.6152 seconds
#
# Iters. done: 63 [Current cost: -2.704263176356014]
# Current parameters: [ 1.68519725  3.0710591   1.77086546  3.3545552   1.60467468  3.17016634
#   3.11705722 -0.60061031]
# Device time: 0.8730 seconds
#
# Iters. done: 64 [Current cost: -2.7048185591997265]
# Current parameters: [ 1.67952778  3.07023685  1.77498717  3.32958028  1.61543922  3.17505046
#   3.11349078 -0.57755344]
# Device time: 0.5896 seconds
#
# Iters. done: 65 [Current cost: -2.703075817986579]
# Current parameters: [ 1.68061719  3.07269241  1.77112987  3.36283248  1.60928686  3.16270711
#   3.12829819 -0.58053329]
# Device time: 0.5915 seconds
#
# Iters. done: 66 [Current cost: -2.7076276423657015]
# Current parameters: [ 1.67870538  3.06675449  1.76919421  3.35200515  1.60921777  3.16821109
#   3.12815815 -0.59125549]
# Device time: 0.6078 seconds
#
# Iters. done: 67 [Current cost: -2.7001097691227884]
# Current parameters: [ 1.68438673  3.072171    1.78397649  3.3522695   1.596539    3.16271783
#   3.1251152  -0.58636293]
# Device time: 0.6021 seconds
#
# Iters. done: 68 [Current cost: -2.7033588506463375]
# Current parameters: [ 1.68473009  3.07536901  1.7688627   3.34998039  1.60378141  3.16630833
#   3.12800653 -0.58883494]
# Device time: 0.6310 seconds
#
# Iters. done: 69 [Current cost: -2.707937369399785]
# Current parameters: [ 1.68201664  3.07199586  1.77460993  3.35240468  1.6068552   3.16908884
#   3.12756892 -0.5899638 ]
# Device time: 0.6285 seconds
#
# Iters. done: 70 [Current cost: -2.706657075589283]
# Current parameters: [ 1.67743826  3.07630857  1.7741617   3.35116503  1.60780563  3.16346562
#   3.12570925 -0.59186834]
# Device time: 0.6073 seconds
#
# Iters. done: 71 [Current cost: -2.708183558194243]
# Current parameters: [ 1.67564208  3.07667651  1.7736132   3.35054189  1.60688891  3.16527359
#   3.12374886 -0.59006397]
# Device time: 0.5898 seconds
#
# Iters. done: 72 [Current cost: -2.702480671481665]
# Current parameters: [ 1.68181375  3.07677187  1.77552031  3.3489152   1.61285224  3.16120705
#   3.12397768 -0.59077275]
# Device time: 0.6010 seconds
#
# Iters. done: 73 [Current cost: -2.7020015799421415]
# Current parameters: [ 1.67648143  3.0757982   1.77521222  3.34921158  1.60760234  3.16278223
#   3.12799108 -0.59001143]
# Device time: 0.6190 seconds
#
# Iters. done: 74 [Current cost: -2.701820216355266]
# Current parameters: [ 1.67959894  3.07665722  1.77509964  3.35545175  1.60421805  3.1612602
#   3.12530486 -0.59623769]
# Device time: 0.6110 seconds
#
# Iters. done: 75 [Current cost: -2.7040884914716656]
# Current parameters: [ 1.67763183  3.07582275  1.77461678  3.3483922   1.6070515   3.16434454
#   3.12520133 -0.59421151]
# Device time: 0.5902 seconds
#
# Iters. done: 76 [Current cost: -2.7052212766905286]
# Current parameters: [ 1.67588778  3.07464715  1.76886674  3.35286885  1.61146993  3.16400799
#   3.12774226 -0.59452857]
# Device time: 0.6462 seconds
#
# Iters. done: 77 [Current cost: -2.7024647298552313]
# Current parameters: [ 1.67802965  3.07761911  1.7756757   3.35212651  1.60869119  3.16617837
#   3.12701227 -0.59223408]
# Device time: 0.6087 seconds
#
# Iters. done: 78 [Current cost: -2.7019642946293723]
# Current parameters: [ 1.67664398  3.07520183  1.77523148  3.35159713  1.60839722  3.16341936
#   3.12524594 -0.59211538]
# Device time: 0.6157 seconds
#
# Iters. done: 79 [Current cost: -2.7025141082915067]
# Current parameters: [ 1.68003461  3.07742805  1.77334877  3.35044349  1.60916922  3.16208196
#   3.12436967 -0.59115095]
# Device time: 0.6333 seconds
#
# Iters. done: 80 [Current cost: -2.7045419978063974]
# Current parameters: [ 1.67768294  3.07667982  1.77374676  3.35190005  1.60630525  3.16285419
#   3.12597944 -0.59232289]
# Device time: 0.6305 seconds
#
# Iters. done: 81 [Current cost: -2.705630180716272]
# Current parameters: [ 1.67692225  3.07697521  1.77428075  3.35109455  1.60802133  3.16313553
#   3.12565543 -0.59212423]
# Device time: 0.6093 seconds
#
# Iters. done: 82 [Current cost: -2.704231550015611]
# Current parameters: [ 1.67733793  3.07566594  1.77258361  3.35123543  1.60837186  3.1638326
#   3.12631565 -0.59213909]
# Device time: 0.6217 seconds
#
# Iters. done: 83 [Current cost: -2.7014214014587887]
# Current parameters: [ 1.67751584  3.07617207  1.77442684  3.35073078  1.60760379  3.1632725
#   3.12625335 -0.59132421]
# Device time: 0.6053 seconds
#
# Iters. done: 84 [Current cost: -2.7029769015696936]
# Current parameters: [ 1.67743947  3.07643047  1.77418445  3.35152324  1.60793161  3.16350961
#   3.12582459 -0.59161612]
# Device time: 0.6590 seconds
#
# Iters. done: 85 [Current cost: -2.703301333482583]
# Current parameters: [ 1.67783118  3.07642752  1.77441035  3.35090267  1.60767404  3.16406546
#   3.12564059 -0.59239048]
# Device time: 0.6197 seconds
#
# Iters. done: 86 [Current cost: -2.7052757510469383]
# Current parameters: [ 1.67773982  3.07628621  1.77421973  3.35120134  1.60801676  3.16319689
#   3.12578494 -0.59200898]
# Device time: 0.6379 seconds
#
# Iters. done: 87 [Current cost: -2.7058613777849865]
# Current parameters: [ 1.6775574   3.07622664  1.77387745  3.35089147  1.60764404  3.16332238
#   3.12489263 -0.59161605]
# Device time: 0.6432 seconds
#
# Iters. done: 88 [Current cost: -2.7055741560496793]
# Current parameters: [ 1.67729334  3.07612213  1.77380456  3.35107975  1.60786433  3.1635268
#   3.12583905 -0.59202262]
# Device time: 0.6253 seconds
#
# Iters. done: 89 [Current cost: -2.705891055315717]
# Current parameters: [ 1.67737838  3.07622212  1.77425083  3.35111131  1.60798124  3.16352432
#   3.12566165 -0.59183422]
# Device time: 0.5985 seconds
#
# Iters. done: 90 [Current cost: -2.705137957193594]
# Current parameters: [ 1.67731489  3.0761045   1.77432331  3.35133848  1.60752446  3.16333737
#   3.12565605 -0.59203272]
# Device time: 0.8918 seconds
#
# Iters. done: 91 [Current cost: -2.7068173091448107]
# Current parameters: [ 1.67753876  3.07639901  1.77418186  3.35111884  1.60770679  3.16360556
#   3.12571152 -0.59196543]
# Device time: 0.6639 seconds
#
# Iters. done: 92 [Current cost: -2.705851684663929]
# Current parameters: [ 1.67745298  3.07631428  1.77411767  3.35120528  1.60782207  3.16347141
#   3.12560704 -0.59188684]
# Device time: 0.5878 seconds
#
# Iters. done: 93 [Current cost: -2.7051181158712074]
# Current parameters: [ 1.67744126  3.07630483  1.77415443  3.35103364  1.60770522  3.16336055
#   3.12576588 -0.5917344 ]
# Device time: 0.6229 seconds
#
# Iters. done: 94 [Current cost: -2.7025982729110405]
# Current parameters: [ 1.67730111  3.07646517  1.77418969  3.35114716  1.60784357  3.16339659
#   3.12573234 -0.59196016]
# Device time: 0.5937 seconds
#
# Iters. done: 95 [Current cost: -2.7041065958736916]
# Current parameters: [ 1.67744075  3.07631117  1.77416238  3.35123675  1.60781208  3.16349257
#   3.12576589 -0.59183892]
# Device time: 0.6062 seconds
#
# Iters. done: 96 [Current cost: -2.705079824934394]
# Current parameters: [ 1.67743872  3.07631023  1.77412172  3.35114935  1.60782359  3.16347518
#   3.12572442 -0.5918713 ]
# Device time: 0.6206 seconds
#
# Iters. done: 97 [Current cost: -2.7075981610796194]
# Current parameters: [ 1.67741276  3.07624058  1.77415932  3.3511655   1.60777421  3.16345667
#   3.12572336 -0.59192712]
# Device time: 0.6366 seconds
#
# Iters. done: 98 [Current cost: -2.7077270658009613]
# Current parameters: [ 1.67747019  3.07630826  1.77416967  3.35117057  1.60782733  3.16344488
#   3.12571852 -0.59188832]
# Device time: 0.6188 seconds
#
# Iters. done: 99 [Current cost: -2.7025675090994965]
# Current parameters: [ 1.67739738  3.07630224  1.77415444  3.35112497  1.60774922  3.1634737
#   3.1256942  -0.59181215]
# Device time: 0.6008 seconds
#
# Iters. done: 100 [Current cost: -2.7046401466173897]
# Current parameters: [ 1.67740851  3.07631679  1.7741553   3.35117498  1.6078176   3.16343027
#   3.12571143 -0.5918651 ]
# Device time: 0.6233 seconds
#
# Iters. done: 101 [Current cost: -2.7075132076217785]
# Current parameters: [ 1.67739552  3.07636666  1.77418183  3.35115831  1.60780036  3.16350734
#   3.12571212 -0.59191906]
# Device time: 0.5864 seconds
#
# Iters. done: 102 [Current cost: -2.7028038058093227]
# Current parameters: [ 1.67741986  3.07628803  1.77417732  3.35115955  1.6078373   3.16348303
#   3.12570093 -0.59185886]
# Device time: 0.6193 seconds
#
# Iters. done: 103 [Current cost: -2.704969720250161]
# Current parameters: [ 1.67751158  3.07631066  1.77417358  3.35114021  1.60779618  3.16340765
#   3.12572662 -0.59187887]
# Device time: 0.6090 seconds
#
# Iters. done: 104 [Current cost: -2.7093303411582403]
# Current parameters: [ 1.67751158  3.07631066  1.77417358  3.35114021  1.60779618  3.16340765
#   3.12572662 -0.59187887]
# Device time: 0.6140 seconds
#
# Total time: 64.5042304993 seconds
# Total device time: 64.4440007210 seconds
# Total classical optimizer time 0.0602297783

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -2.7093303411582403
#        x: [ 1.678e+00  3.076e+00  1.774e+00  3.351e+00  1.608e+00
#             3.163e+00  3.126e+00 -5.919e-01]
#     nfev: 104
#    maxcv: 0.0

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -16.969031171956
#   - computed part:      -2.709330341158
#   - FreezeCoreTransformer extracted energy part: -14.259700830797
# ~ Nuclear repulsion energy (Hartree): 1.785131332242
# > Total ground state energy (Hartree): -15.183899839713
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [4.8775721  0.0  -4.8775721]

# %%
from qiskit_algorithms import NumPyMinimumEigensolver


sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(hamiltonian)
result = problem.interpret(sol)
print(result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -16.968855707155
#   - computed part:      -2.709154876358
#   - FreezeCoreTransformer extracted energy part: -14.259700830797
# ~ Nuclear repulsion energy (Hartree): 1.785131332242
# > Total ground state energy (Hartree): -15.183724374913
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [4.8775721  0.0  -4.8775721]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
