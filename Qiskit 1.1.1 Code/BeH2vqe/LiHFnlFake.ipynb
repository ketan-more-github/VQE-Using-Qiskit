# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_ibm_runtime.fake_provider import FakeAlmadenV2
from qiskit_aer import QasmSimulator
# backend = QasmSimulator()
backend = FakeAlmadenV2()

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver

dist = 2.5811

molecule = MoleculeInfo(
    symbols=["Be", "H" , "H" ],
    coords=([0.0, 0.0, 0.0], [dist, 0.0, 0.0] ,[0.0, 0.0 , -dist] ),
    multiplicity=1,  # = 2*spin + 1
    charge=0,
)


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, remove_orbitals=[4,5,6,7]
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['IIII', 'IIIZ', 'IIZZ', 'IIZI', 'IZII', 'IZIZ', 'XXII', 'XXIZ', 'YYII', 'YYIZ', 'ZZII', 'ZZIZ', 'ZIII', 'ZIIZ', 'IIXX', 'IIYY', 'ZXZX', 'IXZX', 'ZXIX', 'IXIX', 'XZZX', 'XIZX', 'XZIX', 'XIIX', 'IZXX', 'IZYY', 'XXXX', 'YYXX', 'XXYY', 'YYYY', 'ZZXX', 'ZZYY', 'ZIXX', 'ZIYY', 'IZZZ', 'XXZZ', 'YYZZ', 'ZZZZ', 'ZIZZ', 'ZXXZ', 'IXXZ', 'ZXXI', 'IXXI', 'XZXZ', 'XIXZ', 'XZXI', 'XIXI', 'IZZI', 'XXZI', 'YYZI', 'ZZZI', 'ZIZI'],
#               coeffs=[-2.11103338e+00+0.j,  2.69208825e-01+0.j,  2.32536399e-01+0.j,
#   1.98724223e-01+0.j,  2.69208825e-01+0.j,  8.17375792e-02+0.j,
#  -1.45362612e-02+0.j,  3.84156784e-03+0.j, -1.45362612e-02+0.j,
#   3.84156784e-03+0.j,  2.32536399e-01+0.j,  7.41994454e-02+0.j,
#   1.98724223e-01+0.j,  7.53380127e-02+0.j, -1.45362612e-02+0.j,
#  -1.45362612e-02+0.j,  2.49553857e-02+0.j, -2.49553857e-02+0.j,
#  -2.49553857e-02+0.j,  2.49553857e-02+0.j, -2.30856285e-02+0.j,
#   2.30856285e-02+0.j,  2.30856285e-02+0.j, -2.30856285e-02+0.j,
#   3.84156784e-03+0.j,  3.84156784e-03+0.j,  2.22916402e-02+0.j,
#   2.22916402e-02+0.j,  2.22916402e-02+0.j,  2.22916402e-02+0.j,
#  -1.72498864e-02+0.j, -1.72498864e-02+0.j,  1.12800271e-03+0.j,
#   1.12800271e-03+0.j,  7.41994454e-02+0.j, -1.72498864e-02+0.j,
#  -1.72498864e-02+0.j,  9.21365386e-02+0.j,  7.78420005e-02+0.j,
#  -2.30856285e-02+0.j,  2.30856285e-02+0.j,  2.30856285e-02+0.j,
#  -2.30856285e-02+0.j,  3.03166078e-02+0.j, -3.03166078e-02+0.j,
#  -3.03166078e-02+0.j,  3.03166078e-02+0.j,  7.53380127e-02+0.j,
#   1.12800271e-03+0.j,  1.12800271e-03+0.j,  7.78420005e-02+0.j,
#   8.14614564e-02+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 8

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(" ")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([0.29538276, 1.66206609, 1.37846603, 0.57319071, 2.42850274,
#        2.22937698, 0.05233915, 2.76133803])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
#
# Iters. done: 1 [Current cost: -2.1641703135184827]
# Current parameters: [1.29538276 1.66206609 1.37846603 0.57319071 2.42850274 2.22937698
#  0.05233915 2.76133803]
# Device time: 2.1605 seconds
#
# Iters. done: 2 [Current cost: -2.0236719505698706]
# Current parameters: [0.29538276 2.66206609 1.37846603 0.57319071 2.42850274 2.22937698
#  0.05233915 2.76133803]
# Device time: 2.0412 seconds
#
# Iters. done: 3 [Current cost: -2.171542878865784]
# Current parameters: [0.29538276 2.66206609 2.37846603 0.57319071 2.42850274 2.22937698
#  0.05233915 2.76133803]
# Device time: 2.0861 seconds
#
# Iters. done: 4 [Current cost: -2.1713052766956986]
# Current parameters: [0.29538276 2.66206609 1.37846603 1.57319071 2.42850274 2.22937698
#  0.05233915 2.76133803]
# Device time: 2.3677 seconds
#
# Iters. done: 5 [Current cost: -2.1795914874928393]
# Current parameters: [0.29538276 2.66206609 1.37846603 1.57319071 3.42850274 2.22937698
#  0.05233915 2.76133803]
# Device time: 2.1043 seconds
#
# Iters. done: 6 [Current cost: -2.1639916629506954]
# Current parameters: [0.29538276 2.66206609 1.37846603 1.57319071 2.42850274 3.22937698
#  0.05233915 2.76133803]
# Device time: 2.1322 seconds
#
# Iters. done: 7 [Current cost: -2.182017709385485]
# Current parameters: [0.29538276 2.66206609 1.37846603 1.57319071 2.42850274 3.22937698
#  1.05233915 2.76133803]
# Device time: 2.1288 seconds
#
# Iters. done: 8 [Current cost: -2.1850755937641875]
# Current parameters: [0.29538276 2.66206609 1.37846603 1.57319071 2.42850274 3.22937698
#  1.05233915 3.76133803]
# Device time: 2.2983 seconds
#
# Iters. done: 9 [Current cost: -2.1968051616212403]
# Current parameters: [-0.69181343  2.7138686   1.37679654  1.62974336  2.3188923   3.24642456
#   1.07382504  3.84375454]
# Device time: 2.1037 seconds
#
# Iters. done: 10 [Current cost: -2.1408373519385018]
# Current parameters: [0.32158391 3.16137912 1.37846603 1.57319071 2.42850274 3.22937698
#  1.05233915 3.76133803]
# Device time: 2.0635 seconds
#
# Iters. done: 11 [Current cost: -2.1800518417577956]
# Current parameters: [1.1027211  2.15309791 1.3751618  1.68511927 2.21156265 3.26311741
#  1.09486384 3.92445611]
# Device time: 2.0921 seconds
#
# Iters. done: 12 [Current cost: -2.112307773434967]
# Current parameters: [0.29538276 2.66206609 0.87852402 1.57319071 2.43611739 3.22937698
#  1.05233915 3.76133803]
# Device time: 2.3110 seconds
#
# Iters. done: 13 [Current cost: -2.1800277199370863]
# Current parameters: [0.2995666  2.59372675 1.46173352 1.58953124 3.42222395 3.23430277
#  1.05854736 3.78515175]
# Device time: 2.1185 seconds
#
# Iters. done: 14 [Current cost: -2.1801874419490126]
# Current parameters: [0.29646203 2.64443713 1.39598979 1.07386364 2.42510669 3.23064764
#  1.05394064 3.76748107]
# Device time: 2.0765 seconds
#
# Iters. done: 15 [Current cost: -2.1807676604402486]
# Current parameters: [0.29538276 2.66206609 1.37846603 1.57319071 2.42850274 3.03353384
#  1.20772727 3.76133803]
# Device time: 2.1218 seconds
#
# Iters. done: 16 [Current cost: -2.1805880697808]
# Current parameters: [0.2958933  2.65372694 1.38675541 1.57973553 2.42689628 2.93147014
#  0.65101741 3.76424391]
# Device time: 2.2643 seconds
#
# Iters. done: 17 [Current cost: -2.186084708383599]
# Current parameters: [-0.11891457  2.58148078  1.47979728  1.67785121  2.36202915  3.43171706
#   0.98907747  3.79710952]
# Device time: 2.1387 seconds
#
# Iters. done: 18 [Current cost: -2.1929049702507326]
# Current parameters: [0.44783005 2.58506269 1.4467476  1.64552755 2.38026793 3.36635652
#  1.01034618 3.7854608 ]
# Device time: 2.0657 seconds
#
# Iters. done: 19 [Current cost: -2.165955585027136]
# Current parameters: [0.29584779 2.66204169 1.37937532 1.57417138 2.48820269 3.2296726
#  1.05271174 3.87115006]
# Device time: 2.1287 seconds
#
# Iters. done: 20 [Current cost: -2.176487563121049]
# Current parameters: [0.27409643 2.65180306 1.39267112 1.58165347 2.61384965 3.25092236
#  1.04409655 3.59768432]
# Device time: 2.2537 seconds
#
# Iters. done: 21 [Current cost: -2.192534949081882]
# Current parameters: [0.28461481 2.65719934 1.38360443 1.57812273 2.40917579 3.16252374
#  0.95118532 3.74237352]
# Device time: 2.0796 seconds
#
# Iters. done: 22 [Current cost: -2.193896114668589]
# Current parameters: [0.2977003  2.70623128 1.42262328 1.57319071 2.42783017 3.22937698
#  1.05233915 3.76133803]
# Device time: 2.1409 seconds
#
# Iters. done: 23 [Current cost: -2.18370299361402]
# Current parameters: [0.27903733 2.69196041 1.26894651 1.57677334 2.39872866 3.25158055
#  1.05217617 3.72851616]
# Device time: 2.1366 seconds
#
# Iters. done: 24 [Current cost: -2.1800442075082724]
# Current parameters: [0.26143867 2.65698441 1.38525181 1.62431162 2.42336073 3.23313899
#  1.0570806  3.76373719]
# Device time: 2.3235 seconds
#
# Iters. done: 25 [Current cost: -2.1798857468704456]
# Current parameters: [0.24965493 2.59948551 1.40061041 1.48293712 2.40555864 3.24527512
#  1.05742838 3.74805382]
# Device time: 2.1462 seconds
#
# Iters. done: 26 [Current cost: -2.1883569938346206]
# Current parameters: [0.30346047 2.65200955 1.37729074 1.5717047  2.4788112  3.23018648
#  1.04928776 3.72676392]
# Device time: 2.0688 seconds
#
# Iters. done: 27 [Current cost: -2.1831162568579527]
# Current parameters: [0.30277292 2.65833321 1.3817761  1.57669737 2.42616446 3.25407736
#  1.03597406 3.76250742]
# Device time: 2.0726 seconds
#
# Iters. done: 28 [Current cost: -2.1799598522576464]
# Current parameters: [0.32904778 2.645326   1.37595247 1.57303937 2.40681616 3.19322173
#  1.07894534 3.76231096]
# Device time: 2.3232 seconds
#
# Iters. done: 29 [Current cost: -2.1877112599404955]
# Current parameters: [0.27591157 2.65359191 1.38218552 1.55187757 2.42393831 3.22637892
#  1.05753512 3.76049036]
# Device time: 2.1102 seconds
#
# Iters. done: 30 [Current cost: -2.178965457829274]
# Current parameters: [0.29408004 2.66148134 1.37906821 1.57376684 2.42515114 3.2213336
#  1.04017022 3.75716731]
# Device time: 2.0919 seconds
#
# Iters. done: 31 [Current cost: -2.1783979869271803]
# Current parameters: [0.29762171 2.66811872 1.36940346 1.57316724 2.44346893 3.22667846
#  1.05649786 3.78591893]
# Device time: 2.1112 seconds
#
# Iters. done: 32 [Current cost: -2.1701058441608656]
# Current parameters: [0.29509682 2.6779126  1.36059053 1.57317512 2.42064937 3.2365554
#  1.06262242 3.74766746]
# Device time: 2.2813 seconds
#
# Iters. done: 33 [Current cost: -2.179787491146798]
# Current parameters: [0.30415435 2.6555044  1.38328635 1.57535499 2.42458666 3.22745076
#  1.06104477 3.76015872]
# Device time: 2.1034 seconds
#
# Iters. done: 34 [Current cost: -2.1811222706182094]
# Current parameters: [0.29533978 2.65716805 1.37436822 1.57371598 2.43219589 3.22948311
#  1.0521739  3.75882872]
# Device time: 2.1317 seconds
#
# Iters. done: 35 [Current cost: -2.1818744678619195]
# Current parameters: [0.29469486 2.66886205 1.38762684 1.57260157 2.43740514 3.23039937
#  1.05376168 3.75577987]
# Device time: 2.0326 seconds
#
# Iters. done: 36 [Current cost: -2.1689124722731683]
# Current parameters: [0.28589256 2.66113462 1.38026008 1.58439737 2.42519276 3.23071788
#  1.05473886 3.76376467]
# Device time: 2.1717 seconds
#
# Iters. done: 37 [Current cost: -2.187952968029987]
# Current parameters: [0.29175129 2.66070422 1.37934755 1.56754282 2.42568327 3.23064635
#  1.05339726 3.76296189]
# Device time: 2.1247 seconds
#
# Iters. done: 38 [Current cost: -2.180453665462834]
# Current parameters: [0.29618647 2.66067168 1.37994956 1.57352589 2.42889417 3.23164365
#  1.05040761 3.76249274]
# Device time: 2.1581 seconds
#
# Iters. done: 39 [Current cost: -2.1836648051822363]
# Current parameters: [0.29733438 2.66669954 1.37434409 1.5742632  2.42535783 3.2313716
#  1.05316562 3.75958737]
# Device time: 2.0662 seconds
#
# Iters. done: 40 [Current cost: -2.186615741469817]
# Current parameters: [0.29625683 2.66396617 1.37687086 1.57354893 2.43060814 3.22519437
#  1.05332251 3.76691423]
# Device time: 2.2949 seconds
#
# Iters. done: 41 [Current cost: -2.1883294949431376]
# Current parameters: [0.294748   2.66391309 1.3803026  1.57304481 2.43045011 3.22892293
#  1.05329902 3.75956873]
# Device time: 2.1112 seconds
#
# Iters. done: 42 [Current cost: -2.177766796189126]
# Current parameters: [0.29641432 2.66217582 1.37847948 1.57205459 2.42850197 3.22871394
#  1.05144784 3.76087591]
# Device time: 2.1225 seconds
#
# Iters. done: 43 [Current cost: -2.1791185840364955]
# Current parameters: [0.29347552 2.66145515 1.37858417 1.57555827 2.42667654 3.22801487
#  1.05168496 3.76123609]
# Device time: 2.1376 seconds
#
# Iters. done: 44 [Current cost: -2.185429366895246]
# Current parameters: [0.29718252 2.66068611 1.37936923 1.5737795  2.42747944 3.22926632
#  1.0551471  3.76143251]
# Device time: 2.3052 seconds
#
# Iters. done: 45 [Current cost: -2.182655679864823]
# Current parameters: [0.29534921 2.66301219 1.3773032  1.57354189 2.428156   3.23048098
#  1.05264092 3.7614513 ]
# Device time: 2.0812 seconds
#
# Iters. done: 46 [Current cost: -2.179558729250108]
# Current parameters: [0.29578449 2.66229767 1.37834795 1.57368155 2.42890974 3.22901856
#  1.05225039 3.7617644 ]
# Device time: 2.0688 seconds
#
# Iters. done: 47 [Current cost: -2.1799832293566532]
# Current parameters: [0.29422963 2.66158974 1.3785431  1.57208821 2.4285547  3.22929442
#  1.05281621 3.7622322 ]
# Device time: 2.0705 seconds
#
# Iters. done: 48 [Current cost: -2.181021532978186]
# Current parameters: [0.29516847 2.66088571 1.37762711 1.57338805 2.42935005 3.22952637
#  1.05238777 3.76039456]
# Device time: 2.3277 seconds
#
# Iters. done: 49 [Current cost: -2.1863429622415893]
# Current parameters: [0.29541366 2.661822   1.37901966 1.57331838 2.42849349 3.23002053
#  1.05194774 3.76139166]
# Device time: 2.1060 seconds
#
# Iters. done: 50 [Current cost: -2.184202189768566]
# Current parameters: [0.29508793 2.66217165 1.37839846 1.57327717 2.42848251 3.22926917
#  1.05200047 3.7612984 ]
# Device time: 2.1237 seconds
#
# Iters. done: 51 [Current cost: -2.186678009588209]
# Current parameters: [0.29548098 2.66185732 1.3786373  1.5733902  2.42785316 3.22911292
#  1.05284314 3.7610454 ]
# Device time: 2.1118 seconds
#
# Iters. done: 52 [Current cost: -2.182249735070512]
# Current parameters: [0.29522983 2.66254976 1.37885132 1.57306863 2.42896952 3.22941016
#  1.05269331 3.76090377]
# Device time: 2.3267 seconds
#
# Iters. done: 53 [Current cost: -2.1744623508644625]
# Current parameters: [0.29525206 2.66190855 1.37840285 1.57290997 2.42851962 3.22938041
#  1.05247353 3.76164683]
# Device time: 2.0766 seconds
#
# Iters. done: 54 [Current cost: -2.1781116158919502]
# Current parameters: [0.29535658 2.6618853  1.37846044 1.5732208  2.42862437 3.22931535
#  1.05233632 3.7612562 ]
# Device time: 2.1596 seconds
#
# Iters. done: 55 [Current cost: -2.176153262407116]
# Current parameters: [0.29550735 2.66223643 1.37815839 1.57321091 2.42838852 3.22965897
#  1.05235857 3.76126131]
# Device time: 2.0693 seconds
#
# Iters. done: 56 [Current cost: -2.1804146591476727]
# Current parameters: [0.2956472  2.66213638 1.37855528 1.57290764 2.4284157  3.22922827
#  1.05213594 3.76127115]
# Device time: 2.2589 seconds
#
# Iters. done: 57 [Current cost: -2.1741193521890403]
# Current parameters: [0.29531552 2.66222454 1.37857811 1.57317542 2.42857386 3.22939607
#  1.05244052 3.76129953]
# Device time: 2.0950 seconds
#
# Iters. done: 58 [Current cost: -2.1820072820415866]
# Current parameters: [0.29535835 2.66202834 1.37852406 1.57316901 2.42847434 3.22945941
#  1.05230979 3.761314  ]
# Device time: 2.1847 seconds
#
# Iters. done: 59 [Current cost: -2.188100484842934]
# Current parameters: [0.29546726 2.66208219 1.37851328 1.57334096 2.4284898  3.22936924
#  1.05230572 3.76149943]
# Device time: 2.0770 seconds
#
# Iters. done: 60 [Current cost: -2.1827069307004727]
# Current parameters: [0.29534422 2.66204473 1.37846318 1.57322916 2.42831254 3.22928298
#  1.0524344  3.76129226]
# Device time: 2.2855 seconds
#
# Iters. done: 61 [Current cost: -2.1826948035706373]
# Current parameters: [0.29543884 2.66208681 1.378476   1.57313394 2.4284957  3.22933886
#  1.05230064 3.76132718]
# Device time: 2.0840 seconds
#
# Iters. done: 62 [Current cost: -2.177368138249897]
# Current parameters: [0.29536265 2.66205437 1.37847471 1.57316585 2.42850379 3.229365
#  1.05234482 3.76137101]
# Device time: 2.0794 seconds
#
# Iters. done: 63 [Current cost: -2.1875423899114557]
# Current parameters: [0.29538083 2.66208311 1.37838604 1.57320787 2.42850639 3.22942852
#  1.05235686 3.7613326 ]
# Device time: 2.1056 seconds
#
# Iters. done: 64 [Current cost: -2.1869565703559424]
# Current parameters: [0.29541516 2.66205328 1.37847563 1.57318902 2.42850469 3.22938816
#  1.05237015 3.7613481 ]
# Device time: 2.2997 seconds
#
# Iters. done: 65 [Current cost: -2.18182293426868]
# Current parameters: [0.2953738  2.66208511 1.3784837  1.57326887 2.42850109 3.22936769
#  1.05229038 3.76136388]
# Device time: 2.1146 seconds
#
# Iters. done: 66 [Current cost: -2.175781591884248]
# Current parameters: [0.29537985 2.66207862 1.37846624 1.57319301 2.42845654 3.22937139
#  1.05235184 3.76133966]
# Device time: 2.1791 seconds
#
# Iters. done: 67 [Current cost: -2.182184487556759]
# Current parameters: [0.29534933 2.66202236 1.3784549  1.57319987 2.42852763 3.22933971
#  1.05234907 3.76126979]
# Device time: 2.1588 seconds
#
# Iters. done: 68 [Current cost: -2.1761333995410763]
# Current parameters: [0.29538221 2.66210165 1.3784842  1.57319499 2.42851487 3.22938403
#  1.05235298 3.7613157 ]
# Device time: 2.3050 seconds
#
# Iters. done: 69 [Current cost: -2.1828158676434044]
# Current parameters: [0.2953242  2.66206833 1.37846275 1.57314566 2.42853313 3.22937198
#  1.05234261 3.76139773]
# Device time: 2.0723 seconds
#
# Iters. done: 70 [Current cost: -2.1725162282041657]
# Current parameters: [0.2953242  2.66206833 1.37846275 1.57314566 2.42853313 3.22937198
#  1.05234261 3.76139773]
# Device time: 2.1156 seconds
#
# Total time: 150.6738967896 seconds
# Total device time: 150.6399390697 seconds
# Total classical optimizer time 0.0339577198

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -2.1725162282041657
#        x: [ 2.953e-01  2.662e+00  1.378e+00  1.573e+00  2.429e+00
#             3.229e+00  1.052e+00  3.761e+00]
#     nfev: 70
#    maxcv: 0.0

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -16.432217059001
#   - computed part:      -2.172516228204
#   - FreezeCoreTransformer extracted energy part: -14.259700830797
# ~ Nuclear repulsion energy (Hartree): 1.785131332242
# > Total ground state energy (Hartree): -14.647085726759
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [4.8775721  0.0  -4.8775721]

# %%
from qiskit_algorithms import NumPyMinimumEigensolver


sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(hamiltonian)
result = problem.interpret(sol)
print(result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -16.968855707155
#   - computed part:      -2.709154876358
#   - FreezeCoreTransformer extracted energy part: -14.259700830797
# ~ Nuclear repulsion energy (Hartree): 1.785131332242
# > Total ground state energy (Hartree): -15.183724374913
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [4.8775721  0.0  -4.8775721]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
