# %% [markdown]
# *Usage estimate: 73 minutes on ibm\_kyiv or 28 minutes on ibm\_manila. (NOTE: This is an estimate only. Your runtime may vary.)*
#
# ## Background
#
# [Variational quantum algorithms](https://arxiv.org/abs/2012.09265) are promising candidate hybrid-algorithms for observing quantum computation utility on noisy near-term devices. Variational algorithms are characterized by the use of a classical optimization algorithm to iteratively update a parameterized trial solution, or "ansatz". Chief among these methods is the Variational Quantum Eigensolver (VQE) that aims to solve for the ground state of a given Hamiltonian represented as a linear combination of Pauli terms, with an ansatz circuit where the number of parameters to optimize over is polynomial in the number of qubits.  Given that the size of the full solution vector is exponential in the number of qubits, successful minimization using VQE requires, in general, additional problem-specific information to define the structure of the ansatz circuit.
#
# Executing a VQE algorithm requires the following components:
#
# 1. Hamiltonian and ansatz (problem specification)
# 2. Qiskit Runtime estimator
# 3. Classical optimizer
#
# Although the Hamiltonian and ansatz require domain-specific knowledge to construct, these details are immaterial to the Runtime, and we can execute a wide class of VQE problems in the same manner.

# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %% [markdown]
# ## Setup
#
# Here we import the tools needed for a VQE experiment.

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import Aer
print(Aer.backends())
try:
    backend = Aer.get_backend('aer_simulator_statevector')
    backend.set_options(device='CPU')

    print("CPU options set successfully." , backend)
except Exception as e:
    print(f"Failed to set CPU options: {e}")
# Out:
# [AerSimulator('aer_simulator'), AerSimulator('aer_simulator'), AerSimulator('aer_simulator_statevector'), AerSimulator('aer_simulator_statevector_gpu'), AerSimulator('aer_simulator_density_matrix'), AerSimulator('aer_simulator_density_matrix_gpu'), AerSimulator('aer_simulator_stabilizer'), AerSimulator('aer_simulator_matrix_product_state'), AerSimulator('aer_simulator_extended_stabilizer'), AerSimulator('aer_simulator_unitary'), AerSimulator('aer_simulator_unitary_gpu'), AerSimulator('aer_simulator_superop'), AerSimulator('aer_simulator_tensor_network_gpu'), QasmSimulator('qasm_simulator'), StatevectorSimulator('statevector_simulator'), UnitarySimulator('unitary_simulator')]
# CPU options set successfully. AerSimulator('aer_simulator_statevector')

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver


molecule = MoleculeInfo(
    # Coordinates in Angstrom
  symbols=["O", "H" , "H"],
  coords=([0.0, 0.0, 0.0], [0.757, 0.586, 0.0] ,[-0.757, 0.586 , 0.0]), 
  multiplicity=1,  # = 2*spin + 1
  charge=0
)



driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, remove_orbitals=[6,7]
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['IIIIIIII', 'IIIIIIIZ', 'IIIIIZXX', 'IIIIIIYY', 'IIIIXXXX', 'IIIIYXXY', 'IIIIIIZZ', 'IIIIIZZI', 'IIIIXXZI', 'IIIIYYII', 'IIIIZZII', 'IIIIZIII', 'IIIZIIII', 'IZXXIIII', 'IIYYIIII', 'XXXXIIII', 'YXXYIIII', 'IIZZIIII', 'IZZIIIII', 'XXZIIIII', 'YYIIIIII', 'ZZIIIIII', 'ZIIIIIII', 'IIIIIIZI', 'IIIIIZZZ', 'IIIIXXZZ', 'IIIIYYIZ', 'IIIIZZIZ', 'IIIIZIIZ', 'IIIZIIIZ', 'IZXXIIIZ', 'IIYYIIIZ', 'XXXXIIIZ', 'YXXYIIIZ', 'IIZZIIIZ', 'IZZIIIIZ', 'XXZIIIIZ', 'YYIIIIIZ', 'ZZIIIIIZ', 'ZIIIIIIZ', 'IIIIIZYY', 'IIIIIIXX', 'IIIIXXYY', 'IIIIYXYX', 'IIZXIIZX', 'IIIXIIZX', 'IIZXIIIX', 'IIIXIIIX', 'IZXZIIZX', 'IIXIIIZX', 'IZXZIIIX', 'IIXIIIIX', 'XXXZIIZX', 'YXYIIIZX', 'XXXZIIIX', 'YXYIIIIX', 'IIIIXYYX', 'IIIIYYYY', 'IIIIZIXX', 'IIIIZZYY', 'IIIIZZXX', 'IIIIZIYY', 'IIIZIZXX', 'IIIZIIYY', 'IZXXIZXX', 'IIYYIZXX', 'IZXXIIYY', 'IIYYIIYY', 'XXXXIZXX', 'YXXYIZXX', 'XXXXIIYY', 'YXXYIIYY', 'IIZZIZXX', 'IIZZIIYY', 'IZZIIZXX', 'IZZIIIYY', 'XXZIIZXX', 'YYIIIZXX', 'XXZIIIYY', 'YYIIIIYY', 'ZZIIIZXX', 'ZZIIIIYY', 'ZIIIIZXX', 'ZIIIIIYY', 'IIIIYYXX', 'IIIIXYXY', 'ZXXXZXXX', 'IYXYZXXX', 'ZXXXIYXY', 'IYXYIYXY', 'ZXZIZXXX', 'IXIIZXXX', 'ZXZIIYXY', 'IXIIIYXY', 'XZIIZXXX', 'XIIIZXXX', 'XZIIIYXY', 'XIIIIYXY', 'IIIZXXXX', 'IIIZYXXY', 'IZXXXXXX', 'IIYYXXXX', 'IZXXYXXY', 'IIYYYXXY', 'XXXXXXXX', 'YXXYXXXX', 'XXXXYXXY', 'YXXYYXXY', 'IIZZXXXX', 'IIZZYXXY', 'IZZIXXXX', 'IZZIYXXY', 'XXZIXXXX', 'YYIIXXXX', 'XXZIYXXY', 'YYIIYXXY', 'ZZIIXXXX', 'ZZIIYXXY', 'ZIIIXXXX', 'ZIIIYXXY', 'IIIIIZIZ', 'IIIIXXIZ', 'IIIIYYZZ', 'IIIIZZZZ', 'IIIIZIZZ', 'IIIZIIZZ', 'IZXXIIZZ', 'IIYYIIZZ', 'XXXXIIZZ', 'YXXYIIZZ', 'IIZZIIZZ', 'IZZIIIZZ', 'XXZIIIZZ', 'YYIIIIZZ', 'ZZIIIIZZ', 'ZIIIIIZZ', 'IIZXIZXZ', 'IIIXIZXZ', 'IIZXIIXI', 'IIIXIIXI', 'IZXZIZXZ', 'IIXIIZXZ', 'IZXZIIXI', 'IIXIIIXI', 'XXXZIZXZ', 'YXYIIZXZ', 'XXXZIIXI', 'YXYIIIXI', 'ZXXZZXXZ', 'IYYIZXXZ', 'ZXXZIYYI', 'IYYIIYYI', 'IIZXXXXZ', 'IIIXXXXZ', 'IIZXYXYI', 'IIIXYXYI', 'IZXZXXXZ', 'IIXIXXXZ', 'IZXZYXYI', 'IIXIYXYI', 'XXXZXXXZ', 'YXYIXXXZ', 'XXXZYXYI', 'YXYIYXYI', 'IIIIZIZI', 'IIIIZZZI', 'IIIZIZZI', 'IZXXIZZI', 'IIYYIZZI', 'XXXXIZZI', 'YXXYIZZI', 'IIZZIZZI', 'IZZIIZZI', 'XXZIIZZI', 'YYIIIZZI', 'ZZIIIZZI', 'ZIIIIZZI', 'IIIIYYZI', 'IIIIXXII', 'ZXXXZXZI', 'IYXYZXZI', 'ZXXXIXII', 'IYXYIXII', 'ZXZIZXZI', 'IXIIZXZI', 'ZXZIIXII', 'IXIIIXII', 'XZIIZXZI', 'XIIIZXZI', 'XZIIIXII', 'XIIIIXII', 'IIIZXXZI', 'IIIZYYII', 'IZXXXXZI', 'IIYYXXZI', 'IZXXYYII', 'IIYYYYII', 'XXXXXXZI', 'YXXYXXZI', 'XXXXYYII', 'YXXYYYII', 'IIZZXXZI', 'IIZZYYII', 'IZZIXXZI', 'IZZIYYII', 'XXZIXXZI', 'YYIIXXZI', 'XXZIYYII', 'YYIIYYII', 'ZZIIXXZI', 'ZZIIYYII', 'ZIIIXXZI', 'ZIIIYYII', 'IIIIIZII', 'IIIZZZII', 'IZXXZZII', 'IIYYZZII', 'XXXXZZII', 'YXXYZZII', 'IIZZZZII', 'IZZIZZII', 'XXZIZZII', 'YYIIZZII', 'ZZIIZZII', 'ZIIIZZII', 'ZXXXXZII', 'IYXYXZII', 'ZXXXXIII', 'IYXYXIII', 'ZXZIXZII', 'IXIIXZII', 'ZXZIXIII', 'IXIIXIII', 'XZIIXZII', 'XIIIXZII', 'XZIIXIII', 'XIIIXIII', 'IIIZZIII', 'IZXXZIII', 'IIYYZIII', 'XXXXZIII', 'YXXYZIII', 'IIZZZIII', 'IZZIZIII', 'XXZIZIII', 'YYIIZIII', 'ZZIIZIII', 'ZIIIZIII', 'IIZIIIII', 'IZZZIIII', 'XXZZIIII', 'YYIZIIII', 'ZZIZIIII', 'ZIIZIIII', 'IZYYIIII', 'IIXXIIII', 'XXYYIIII', 'YXYXIIII', 'XYYXIIII', 'YYYYIIII', 'ZIXXIIII', 'ZZYYIIII', 'ZZXXIIII', 'ZIYYIIII', 'YYXXIIII', 'XYXYIIII', 'IZIZIIII', 'XXIZIIII', 'YYZZIIII', 'ZZZZIIII', 'ZIZZIIII', 'ZIZIIIII', 'ZZZIIIII', 'YYZIIIII', 'XXIIIIII', 'IZIIIIII'],
#               coeffs=[-1.76848911e+01+0.j,  1.46553764e+00+0.j, -6.33199950e-02+0.j,
#  -6.33199950e-02+0.j,  1.76020564e-01+0.j,  1.76020564e-01+0.j,
#   1.08046296e+00+0.j,  1.10971525e+00+0.j,  1.48929412e-01+0.j,
#   1.48929412e-01+0.j,  1.12621963e+00+0.j,  6.39763035e-01+0.j,
#   1.46553764e+00+0.j, -6.33199950e-02+0.j, -6.33199950e-02+0.j,
#   1.76020564e-01+0.j,  1.76020564e-01+0.j,  1.08046296e+00+0.j,
#   1.10971525e+00+0.j,  1.48929412e-01+0.j,  1.48929412e-01+0.j,
#   1.12621963e+00+0.j,  6.39763035e-01+0.j,  1.25191877e-01+0.j,
#   1.37917645e-01+0.j,  1.86072702e-02+0.j,  1.86072702e-02+0.j,
#   1.50736188e-01+0.j,  1.28072355e-01+0.j,  1.82049950e-01+0.j,
#   1.04016102e-03+0.j,  1.04016102e-03+0.j,  3.57312092e-02+0.j,
#   3.57312092e-02+0.j,  1.61307928e-01+0.j,  1.68925671e-01+0.j,
#   2.38438574e-02+0.j,  2.38438574e-02+0.j,  1.86849172e-01+0.j,
#   1.53548840e-01+0.j,  3.25989574e-03+0.j,  3.25989574e-03+0.j,
#  -2.90054929e-02+0.j,  2.90054929e-02+0.j,  3.61160515e-02+0.j,
#  -3.61160515e-02+0.j, -3.61160515e-02+0.j,  3.61160515e-02+0.j,
#   4.98842810e-03+0.j, -4.98842810e-03+0.j, -4.98842810e-03+0.j,
#   4.98842810e-03+0.j, -1.00332050e-02+0.j, -1.00332050e-02+0.j,
#   1.00332050e-02+0.j,  1.00332050e-02+0.j, -2.99045077e-02+0.j,
#  -2.99045077e-02+0.j, -5.46079684e-03+0.j, -5.46079684e-03+0.j,
#  -5.89136302e-04+0.j, -5.89136302e-04+0.j,  1.04016102e-03+0.j,
#   1.04016102e-03+0.j,  3.10080264e-02+0.j,  3.10080264e-02+0.j,
#   3.10080264e-02+0.j,  3.10080264e-02+0.j,  5.23658719e-03+0.j,
#   5.23658719e-03+0.j,  5.23658719e-03+0.j,  5.23658719e-03+0.j,
#   1.72853236e-03+0.j,  1.72853236e-03+0.j, -2.61157723e-02+0.j,
#  -2.61157723e-02+0.j, -7.83248126e-03+0.j, -7.83248126e-03+0.j,
#  -7.83248126e-03+0.j, -7.83248126e-03+0.j, -1.71870061e-02+0.j,
#  -1.71870061e-02+0.j,  1.46542497e-02+0.j,  1.46542497e-02+0.j,
#  -2.48725878e-02+0.j,  2.48725878e-02+0.j,  3.61129835e-02+0.j,
#   3.61129835e-02+0.j,  3.61129835e-02+0.j,  3.61129835e-02+0.j,
#  -1.17262093e-02+0.j,  1.17262093e-02+0.j, -1.17262093e-02+0.j,
#   1.17262093e-02+0.j,  1.47837373e-02+0.j, -1.47837373e-02+0.j,
#   1.47837373e-02+0.j, -1.47837373e-02+0.j,  3.57312092e-02+0.j,
#   3.57312092e-02+0.j,  5.23658719e-03+0.j,  5.23658719e-03+0.j,
#   5.23658719e-03+0.j,  5.23658719e-03+0.j,  2.54764848e-02+0.j,
#   2.54764848e-02+0.j,  2.54764848e-02+0.j,  2.54764848e-02+0.j,
#   1.89722879e-02+0.j,  1.89722879e-02+0.j,  2.20720264e-02+0.j,
#   2.20720264e-02+0.j,  1.52433860e-02+0.j,  1.52433860e-02+0.j,
#   1.52433860e-02+0.j,  1.52433860e-02+0.j,  3.96563250e-02+0.j,
#   3.96563250e-02+0.j,  2.41939263e-02+0.j,  2.41939263e-02+0.j,
#   1.37842376e-01+0.j,  1.79531385e-02+0.j,  1.79531385e-02+0.j,
#   1.50037919e-01+0.j,  1.25141919e-01+0.j,  1.61307928e-01+0.j,
#   1.72853236e-03+0.j,  1.72853236e-03+0.j,  1.89722879e-02+0.j,
#   1.89722879e-02+0.j,  1.58277174e-01+0.j,  1.49649806e-01+0.j,
#   1.08065495e-02+0.j,  1.08065495e-02+0.j,  1.57239880e-01+0.j,
#   1.42873617e-01+0.j,  4.98842810e-03+0.j, -4.98842810e-03+0.j,
#  -4.98842810e-03+0.j,  4.98842810e-03+0.j,  1.18074295e-02+0.j,
#  -1.18074295e-02+0.j, -1.18074295e-02+0.j,  1.18074295e-02+0.j,
#  -7.14658900e-03+0.j, -7.14658900e-03+0.j,  7.14658900e-03+0.j,
#   7.14658900e-03+0.j,  7.20196112e-03+0.j,  7.20196112e-03+0.j,
#   7.20196112e-03+0.j,  7.20196112e-03+0.j, -1.00332050e-02+0.j,
#   1.00332050e-02+0.j, -1.00332050e-02+0.j,  1.00332050e-02+0.j,
#  -7.14658900e-03+0.j,  7.14658900e-03+0.j, -7.14658900e-03+0.j,
#   7.14658900e-03+0.j,  1.77316976e-02+0.j,  1.77316976e-02+0.j,
#   1.77316976e-02+0.j,  1.77316976e-02+0.j,  1.68269586e-01+0.j,
#   1.20107088e-01+0.j,  1.68925671e-01+0.j, -2.61157723e-02+0.j,
#  -2.61157723e-02+0.j,  2.20720264e-02+0.j,  2.20720264e-02+0.j,
#   1.49649806e-01+0.j,  1.95731773e-01+0.j,  3.03275403e-02+0.j,
#   3.03275403e-02+0.j,  1.82251705e-01+0.j,  1.37265834e-01+0.j,
#  -2.94877626e-02+0.j, -2.94877626e-02+0.j, -1.17262093e-02+0.j,
#  -1.17262093e-02+0.j,  1.17262093e-02+0.j,  1.17262093e-02+0.j,
#   1.39821193e-02+0.j, -1.39821193e-02+0.j, -1.39821193e-02+0.j,
#   1.39821193e-02+0.j, -4.41231570e-04+0.j,  4.41231570e-04+0.j,
#   4.41231570e-04+0.j, -4.41231570e-04+0.j,  2.38438574e-02+0.j,
#   2.38438574e-02+0.j, -7.83248126e-03+0.j, -7.83248126e-03+0.j,
#  -7.83248126e-03+0.j, -7.83248126e-03+0.j,  1.52433860e-02+0.j,
#   1.52433860e-02+0.j,  1.52433860e-02+0.j,  1.52433860e-02+0.j,
#   1.08065495e-02+0.j,  1.08065495e-02+0.j,  3.03275403e-02+0.j,
#   3.03275403e-02+0.j,  1.71587457e-02+0.j,  1.71587457e-02+0.j,
#   1.71587457e-02+0.j,  1.71587457e-02+0.j,  2.90465311e-02+0.j,
#   2.90465311e-02+0.j,  1.11429375e-02+0.j,  1.11429375e-02+0.j,
#   1.37587392e-01+0.j,  1.86849172e-01+0.j, -1.71870061e-02+0.j,
#  -1.71870061e-02+0.j,  3.96563250e-02+0.j,  3.96563250e-02+0.j,
#   1.57239880e-01+0.j,  1.82251705e-01+0.j,  2.90465311e-02+0.j,
#   2.90465311e-02+0.j,  2.20039773e-01+0.j,  1.47238626e-01+0.j,
#   1.47837373e-02+0.j,  1.47837373e-02+0.j, -1.47837373e-02+0.j,
#  -1.47837373e-02+0.j, -4.41231570e-04+0.j,  4.41231570e-04+0.j,
#   4.41231570e-04+0.j, -4.41231570e-04+0.j,  9.65123408e-03+0.j,
#  -9.65123408e-03+0.j, -9.65123408e-03+0.j,  9.65123408e-03+0.j,
#   1.53548840e-01+0.j,  1.46542497e-02+0.j,  1.46542497e-02+0.j,
#   2.41939263e-02+0.j,  2.41939263e-02+0.j,  1.42873617e-01+0.j,
#   1.37265834e-01+0.j,  1.11429375e-02+0.j,  1.11429375e-02+0.j,
#   1.47238626e-01+0.j,  1.49284551e-01+0.j,  1.25191877e-01+0.j,
#   1.37917645e-01+0.j,  1.86072702e-02+0.j,  1.86072702e-02+0.j,
#   1.50736188e-01+0.j,  1.28072355e-01+0.j,  3.25989574e-03+0.j,
#   3.25989574e-03+0.j, -2.90054929e-02+0.j,  2.90054929e-02+0.j,
#  -2.99045077e-02+0.j, -2.99045077e-02+0.j, -5.46079684e-03+0.j,
#  -5.46079684e-03+0.j, -5.89136302e-04+0.j, -5.89136302e-04+0.j,
#  -2.48725878e-02+0.j,  2.48725878e-02+0.j,  1.37842376e-01+0.j,
#   1.79531385e-02+0.j,  1.79531385e-02+0.j,  1.50037919e-01+0.j,
#   1.25141919e-01+0.j,  1.68269586e-01+0.j,  1.20107088e-01+0.j,
#  -2.94877626e-02+0.j, -2.94877626e-02+0.j,  1.37587392e-01+0.j])

# %% [markdown]
# ## Step 1: Map classical inputs to a quantum problem
#
# Although the problem instance in question for the VQE algorithm can come from a variety of domains, the form for execution through Qiskit Runtime is the same. Qiskit provides a convenience class for expressing Hamiltonians in Pauli form, and a collection of widely used ansatz circuits in the [`qiskit.circuit.library`](https://docs.quantum-computing.ibm.com/api/qiskit/circuit_library).
#
# This example Hamiltonian is derived from a quantum chemistry problem.

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
vv = var_form.decompose()
vv.decompose().draw("mpl", style="iqp")

# %% [markdown]
# Our choice of ansatz is the `EfficientSU2` that, by default, linearly entangles qubits, making it ideal for quantum hardware with limited connectivity.

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 24

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
# ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %% [markdown]
# Note that, in addition to the array of optimization parameters that must be the first argument, we use additional arguments to pass the terms needed in the cost function, such as the `cost_history_dict`. This dictionary stores the current vector at each iteration, for example in case you need to restart the routine due to failure, and also returns the current iteration number and average time per iteration.

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %% [markdown]
# We can now use a classical optimizer of our choice to minimize the cost function. Here, we use the [COBYLA routine from SciPy through the `minimize` function](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html). Note that when running on real quantum hardware, the choice of optimizer is important, as not all optimizers handle noisy cost function landscapes equally well.
#
# To begin the routine, specify a random initial set of parameters:

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([3.04406804, 0.52063288, 2.6303422 , 2.42518969, 0.08295942,
#        2.32703944, 2.75647323, 2.19325591, 1.83213127, 1.5197755 ,
#        0.46906478, 2.65236196, 2.8192362 , 1.3048618 , 2.1290726 ,
#        2.3588862 , 2.5008692 , 1.97029962, 2.77202261, 2.94868133,
#        1.86610232, 0.86964572, 1.95434853, 0.30944384])

# %% [markdown]
# Because we are sending a large number of jobs that we would like to execute together, we use a [`Session`](https://docs.quantum-computing.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.Session) to execute all the generated circuits in one block.  Here `args` is the standard SciPy way to supply the additional parameters needed by the cost function.

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
# Iters. done: 1 [Current cost: -22.256192062364143]
# Current parameters: [4.04406804 0.52063288 2.6303422  2.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5577 seconds
# Iters. done: 2 [Current cost: -21.772890931463422]
# Current parameters: [3.04406804 1.52063288 2.6303422  2.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.8928 seconds
# Iters. done: 3 [Current cost: -22.085468159427133]
# Current parameters: [3.04406804 0.52063288 3.6303422  2.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.3642 seconds
# Iters. done: 4 [Current cost: -22.31811631264651]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.7764 seconds
# Iters. done: 5 [Current cost: -22.413994348662843]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 1.08295942 2.32703944
#  2.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6486 seconds
# Iters. done: 6 [Current cost: -22.01831442407146]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 3.32703944
#  2.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6670 seconds
# Iters. done: 7 [Current cost: -22.325312434342166]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  3.75647323 2.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.7906 seconds
# Iters. done: 8 [Current cost: -22.392985542975822]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 3.19325591 1.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5772 seconds
# Iters. done: 9 [Current cost: -22.16574674251655]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 1.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.4835 seconds
# Iters. done: 10 [Current cost: -22.44704255645796]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5176 seconds
# Iters. done: 11 [Current cost: -22.453598573148177]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  1.46906478 2.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.2294 seconds
# Iters. done: 12 [Current cost: -22.442517960194433]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 3.65236196
#  2.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.2823 seconds
# Iters. done: 13 [Current cost: -22.429219020781552]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6728 seconds
# Iters. done: 14 [Current cost: -22.47418979222716]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  2.3048618  2.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5687 seconds
# Iters. done: 15 [Current cost: -22.428502611879555]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  3.1290726  2.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.7247 seconds
# Iters. done: 16 [Current cost: -22.459951063278933]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5341 seconds
# Iters. done: 17 [Current cost: -22.478072501648565]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  3.5008692  1.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5807 seconds
# Iters. done: 18 [Current cost: -22.429858603438355]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  2.97029962
#  2.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.2649 seconds
# Iters. done: 19 [Current cost: -22.475717165692114]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.1311 seconds
# Iters. done: 20 [Current cost: -22.531064665432098]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 3.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5044 seconds
# Iters. done: 21 [Current cost: -22.521578242345136]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 2.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.5742 seconds
# Iters. done: 22 [Current cost: -22.50556125598777]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 1.86964572 1.95434853 0.30944384]
# Device time: 5.1879 seconds
# Iters. done: 23 [Current cost: -22.46700080978403]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 2.95434853 0.30944384]
# Device time: 4.5953 seconds
# Iters. done: 24 [Current cost: -22.526765770853856]
# Current parameters: [3.04406804 0.52063288 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 1.30944384]
# Device time: 4.6115 seconds
# Iters. done: 25 [Current cost: -22.48203610758037]
# Current parameters: [ 2.37335693  0.28370726  3.71627886  3.55824641 -0.46615356  2.20396928
#   2.72731783  1.84874517  2.8779946   2.52887375  0.45368743  2.61852873
#   3.84781209  1.24145848  2.10931251  3.36427451  2.43395937  1.96703096
#   3.84556358  2.93551636  1.83070944  0.78073979  1.94838265  0.24140344]
# Device time: 4.6757 seconds
# Iters. done: 26 [Current cost: -21.84223148184754]
# Current parameters: [3.21060563 0.04918275 3.6303422  3.42518969 0.08295942 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.4304 seconds
# Iters. done: 27 [Current cost: -22.55356966698199]
# Current parameters: [ 4.11127323  0.33662808  3.67018194  3.48687402 -0.1716062   2.26998482
#   2.74295696  2.03354272  2.85339325  2.52399339  0.46193593  2.63667707
#   3.83248382  1.27546839  2.11991194  3.36138419  2.46985019  1.96878429
#   3.80611578  2.94257813  1.84969438  0.82842944  1.95158278  0.2779007 ]
# Device time: 3.7529 seconds
# Iters. done: 28 [Current cost: -21.81591652036021]
# Current parameters: [3.21060563 0.04918275 4.1243293  3.42518969 0.16026882 2.32703944
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6668 seconds
# Iters. done: 29 [Current cost: -22.28987840748794]
# Current parameters: [ 3.06467067 -0.0259516   3.22773943  3.47255757  0.970377    2.28322675
#   2.74609398  2.07061089  2.84845851  2.52301445  0.46359048  2.64031741
#   3.82940915  1.28229037  2.12203805  3.36080442  2.47704945  1.96913598
#   3.79820302  2.94399463  1.85350254  0.83799542  1.95222469  0.28522162]
# Device time: 4.6203 seconds
# Iters. done: 30 [Current cost: -22.316609485725543]
# Current parameters: [3.21060563 0.04918275 3.6303422  3.08567957 0.08295942 1.95997966
#  2.75647323 2.19325591 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6901 seconds
# Iters. done: 31 [Current cost: -22.53972925549514]
# Current parameters: [3.16144047 0.02387016 3.54589022 2.69905616 0.05487603 3.00494894
#  2.75297649 2.15193708 2.83763188 2.5208667  0.4672205  2.64830418
#  3.82266345 1.29725754 2.12670268 3.35953244 2.49284438 1.9699076
#  3.78084273 2.9471024  1.86185748 0.85898281 1.95363301 0.30128343]
# Device time: 4.5962 seconds
# Iters. done: 32 [Current cost: -22.54156629850872]
# Current parameters: [3.21060563 0.04918275 3.6303422  3.42518969 0.08295942 2.32703944
#  2.25825417 2.23541941 2.83213127 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6535 seconds
# Iters. done: 33 [Current cost: -22.610985895103365]
# Current parameters: [ 3.10991864e+00 -2.65576558e-03  3.45739012e+00  3.42210890e+00
#   2.54465029e-02  2.34274160e+00  2.30145168e+00  3.21002653e+00
#   2.84339616e+00  2.52201020e+00  4.65287822e-01  2.64405189e+00
#   3.82625497e+00  1.28928877e+00  2.12421916e+00  3.36020967e+00
#   2.48443490e+00  1.96949678e+00  3.79008564e+00  2.94544777e+00
#   1.85740917e+00  8.47808776e-01  1.95288320e+00  2.92731854e-01]
# Device time: 4.1939 seconds
# Iters. done: 34 [Current cost: -22.55234214541334]
# Current parameters: [3.19506482 0.04369303 3.63233341 3.4282727  0.07023611 2.32418782
#  2.25757862 2.22743687 3.33161169 2.5197755  0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.1278 seconds
# Iters. done: 35 [Current cost: -22.603950728488385]
# Current parameters: [ 2.51568857 -0.23104705  3.32242085  3.51380522 -0.43274533  2.27252656
#   2.1562965   2.02206194  2.78086029  2.52454855  0.46099765  2.63461265
#   3.83422745  1.27159967  2.11870622  3.36171297  2.46576751  1.96858484
#   3.81060307  2.94177483  1.8475348   0.82300462  1.95121876  0.27374904]
# Device time: 4.5013 seconds
# Iters. done: 36 [Current cost: -22.108695484913945]
# Current parameters: [3.2100275  0.04897852 3.62929977 3.42557578 0.0896203  2.32668232
#  2.25816956 2.23441973 2.83226436 3.01972837 0.46906478 2.65236196
#  3.8192362  1.3048618  2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.7858 seconds
# Iters. done: 37 [Current cost: -22.616759720832878]
# Current parameters: [ 3.10457227 -0.01037658  3.24016105  3.45168339  0.99675382  2.31999367
#   2.19995262  2.17705272  2.84527288  3.01187961  0.46393402  2.64107326
#   3.82877076  1.28370682  2.1224795   3.36068405  2.47854424  1.96920901
#   3.79656009  2.94428874  1.85429323  0.83998161  1.95235797  0.28674166]
# Device time: 4.7021 seconds
# Iters. done: 38 [Current cost: -22.30204168356117]
# Current parameters: [ 3.21001778  0.04897509  3.62954046  3.3873764   0.08808233  2.36201465
#   2.2579444   2.2317591   2.83261855  3.01979863 -0.02821054  2.65236196
#   3.8192362   1.3048618   2.1290726   3.3588862   2.5008692   1.97029962
#   3.77202261  2.94868133  1.86610232  0.86964572  1.95434853  0.30944384]
# Device time: 4.6907 seconds
# Iters. done: 39 [Current cost: -22.60085688713479]
# Current parameters: [3.20443563 0.04198889 3.57893755 2.69965302 0.05313331 3.00208178
#  2.24343099 2.20330676 2.83762486 3.02229018 0.57644187 2.64980104
#  3.82139918 1.30006266 2.12757691 3.35929405 2.49580464 1.97005221
#  3.7775891  2.94768485 1.86342335 0.86291623 1.95389696 0.3042937 ]
# Device time: 4.5983 seconds
# Iters. done: 40 [Current cost: -22.616172450059526]
# Current parameters: [3.2100275  0.04897852 3.62929977 3.42557578 0.0896203  2.32668232
#  2.25816956 2.23441973 2.83226436 3.01972837 0.46906478 2.21123784
#  3.8192362  1.54025406 2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6131 seconds
# Iters. done: 41 [Current cost: -22.620857074368]
# Current parameters: [3.2073624  0.04556607 3.60223923 3.4237342  0.08596842 2.33033753
#  2.25300428 2.24387547 2.83160605 3.02033618 0.47107102 2.68142746
#  3.8203021  2.42228849 2.12833554 3.35908718 2.49837342 1.9701777
#  3.77476573 2.94819027 1.86478215 0.86632948 1.954126   0.30690589]
# Device time: 3.8731 seconds
# Iters. done: 42 [Current cost: -22.591596961159578]
# Current parameters: [3.21351535 0.03190646 3.61214727 3.43713847 0.08759761 2.33949723
#  2.27540135 2.23336955 2.83221041 3.01971766 0.46908287 2.21127764
#  3.32043553 1.54032864 2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 3.2359 seconds
# Iters. done: 43 [Current cost: -22.61822806596224]
# Current parameters: [3.08665886 0.55209647 3.99013545 3.05940107 0.12935078 1.95571842
#  1.69764421 2.32453266 2.8298906  3.02377729 0.48078992 2.20837993
#  3.75268205 1.54041365 2.124561   3.36011645 2.48559243 1.96955332
#  3.78881339 2.94567552 1.85802146 0.84934684 1.95298641 0.29390894]
# Device time: 4.7387 seconds
# Iters. done: 44 [Current cost: -22.309584370629867]
# Current parameters: [3.49537568 0.07047227 3.55588448 3.4811269  0.07511026 2.37715858
#  2.08011575 2.13653407 2.59524715 2.77597361 0.46878863 2.21063025
#  3.81974939 1.53911543 2.1290726  3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6356 seconds
# Iters. done: 45 [Current cost: -22.586554388030994]
# Current parameters: [ 3.80348694  0.24094343  3.26682637  3.44685556 -0.25419145  2.31038673
#   2.51449     2.33684131  3.19700729  3.39479147  0.49295762  2.18982305
#   3.84364794  1.51436244  2.11742442  3.3620625   2.46142717  1.96837281
#   3.81537356  2.94092084  1.84523892  0.81723743  1.95083176  0.26933537]
# Device time: 4.5792 seconds
# Iters. done: 46 [Current cost: -22.14335447662338]
# Current parameters: [ 2.89861935 -0.11068129  3.46343316  3.47335172 -0.15638071  2.33868122
#   2.17829121  2.10065931  2.74440403  2.96191147  0.47789799  2.20159606
#   3.82986539  1.52778175  2.12449471  3.36013453  2.48536797  1.96954236
#   3.7890601   2.94563136  1.85790273  0.84904858  1.95296639  0.29368069]
# Device time: 4.6583 seconds
# Iters. done: 47 [Current cost: -22.598042867242174]
# Current parameters: [3.20930855 0.04819465 3.62752495 3.42607175 0.09772936 2.3269042
#  2.25837509 2.23311393 2.83223968 3.01942791 0.46902336 2.21114671
#  3.81931318 1.54008328 1.87921708 3.3588862  2.5008692  1.97029962
#  3.77202261 2.94868133 1.86610232 0.86964572 1.95434853 0.30944384]
# Device time: 4.6456 seconds
# Iters. done: 48 [Current cost: -22.59214841557001]
# Current parameters: [ 3.10152129 -0.01847086  3.39260963  3.44178501  0.50203117  2.34211212
#   2.2343453   2.18384236  2.83490726  3.01722238  0.4772667   2.20254455
#   3.82886447  1.52910933  2.17894033  3.36003417  2.48661411  1.96960323
#   3.78769046  2.94587655  1.85856189  0.85070438  1.9530775   0.29494788]
# Device time: 4.7025 seconds
# Iters. done: 49 [Current cost: -22.57415692271227]
# Current parameters: [3.21115042 0.04569503 3.63056254 3.42470992 0.08980724 2.3257444
#  2.25730247 2.23467326 2.83265731 3.02011986 0.46906406 2.21123625
#  3.81923755 1.54025108 2.12907167 3.60878574 2.5008692  1.97029962
#  3.76964935 2.95105459 1.86847558 0.87201898 1.95672179 0.31181709]
# Device time: 4.1334 seconds
# Iters. done: 50 [Current cost: -22.62995564441734]
# Current parameters: [ 3.26544103 -0.20064951  3.66758876  3.35870191  0.09872657  2.259635
#   2.18189706  2.2595976   2.86242899  3.05326873  0.47290012  2.20965115
#   3.82143336  1.53921014  2.1420283   3.59876308  2.49552459  1.97003853
#   3.60462705  3.1208996   2.03654507  1.03581397  2.12714184  0.47727878]
# Device time: 3.6200 seconds
# Iters. done: 51 [Current cost: -22.513451153771722]
# Current parameters: [3.21115042 0.04569503 3.63056254 3.42470992 0.08980724 2.3257444
#  2.25730247 2.23467326 2.83265731 3.02011986 0.46906406 2.21123625
#  3.81923755 1.54025108 2.12907167 3.60878574 2.5130676  1.7205974
#  3.76964935 2.95105459 1.86847558 0.87201898 1.95672179 0.31181709]
# Device time: 4.7370 seconds
# Iters. done: 52 [Current cost: -22.59470490922508]
# Current parameters: [3.20181069 0.04292702 3.61180984 3.42362069 0.08821162 2.32641603
#  2.25301714 2.23691391 2.83308821 3.02174685 0.47039927 2.2107316
#  3.81995806 1.53996792 2.13354378 3.61035181 2.99945827 2.00003008
#  3.77212339 2.95023654 1.86704786 0.86912351 1.95610119 0.30949392]
# Device time: 4.5527 seconds
# Iters. done: 53 [Current cost: -22.647544513379454]
# Current parameters: [3.20941559 0.02068983 3.62036186 3.41775669 0.08947765 2.320064
#  2.24714479 2.23863095 2.83574947 3.0243982  0.47039438 2.21072083
#  3.81996715 1.53994773 2.13353748 3.61035353 2.99943697 2.00002904
#  3.99289276 2.96630922 1.88312054 0.97855027 1.97217387 0.32556661]
# Device time: 4.5750 seconds
# Iters. done: 54 [Current cost: -22.629750815681287]
# Current parameters: [3.15774411 0.15805255 3.5584899  3.45381557 0.08085698 2.35996894
#  2.28179698 2.22894966 2.81935593 3.00861233 0.4710343  2.21055765
#  3.82023929 1.53994433 2.13561781 3.6110576  3.00038994 2.0025281
#  3.60749474 2.86573913 1.78227219 1.28480862 1.8716939  0.22430957]
# Device time: 4.6971 seconds
# Iters. done: 55 [Current cost: -22.621108434891962]
# Current parameters: [3.17605558 0.11823654 3.58284718 3.44347999 0.08392401 2.34792812
#  2.2729047  2.23109893 2.82407548 3.01276766 0.47041585 2.21076808
#  3.81992725 1.54003628 2.13356508 3.610346   2.99953041 2.0000336
#  3.7720441  2.895804   1.92356993 0.86921937 1.90166865 0.5210099 ]
# Device time: 4.5787 seconds
# Iters. done: 56 [Current cost: -22.627110342409477]
# Current parameters: [ 3.2234531  -0.03194549  3.63296901  3.4037382   0.09179885  2.30559219
#   2.23187551  2.24347611  2.84208704  3.03117364  0.47089747  2.21050141
#   3.82026586  1.53979182  2.13524596  3.6109609   3.00007994  2.00213081
#   3.7723131   3.00326717  1.41757107  0.86720907  2.0092079   0.49470236]
# Device time: 4.6084 seconds
# Iters. done: 57 [Current cost: -22.59762034750013]
# Current parameters: [3.20417847 0.0360035  3.6144725  3.42179494 0.0886058  2.32443834
#  2.25118879 2.23744851 2.83391679 3.02257234 0.47039775 2.21072825
#  3.81996089 1.53996163 2.13354182 3.61035234 2.99945163 2.00002975
#  3.77213068 2.76640292 1.86704435 0.8691147  2.12531163 0.30948718]
# Device time: 3.7296 seconds
# Iters. done: 58 [Current cost: -22.58760781385407]
# Current parameters: [ 3.27705004 -0.21994375  3.68466212  3.353789    0.10067906  2.25341132
#   2.17853325  2.26010006  2.86468952  3.05493743  0.47224518  2.20988697
#   3.82109084  1.53932933  2.13984406  3.61260371  3.0017713   2.00780122
#   3.7728103   2.7048797   1.86756688  0.86206003  1.65453934  0.30073181]
# Device time: 3.4784 seconds
# Iters. done: 59 [Current cost: -22.523860892506903]
# Current parameters: [3.19678196 0.04125629 3.60729399 3.59987282 0.09247604 2.16857175
#  2.25067327 2.3109488  2.81983726 3.00919441 0.44522339 2.21078556
#  3.81991249 1.54006903 2.13357529 3.61034322 2.99956497 2.00003529
#  3.77200612 2.95025753 1.8671043  0.86926529 1.9561107  0.30960243]
# Device time: 4.7808 seconds
# Iters. done: 60 [Current cost: -22.606663349198413]
# Current parameters: [3.14330425 0.02049169 3.52633313 3.34742493 0.060286   2.47772564
#  2.24213111 2.67239696 2.73947898 2.92507641 0.48652732 2.20587047
#  3.82451908 1.53188319 2.13807924 3.61342446 2.9941688  2.00808476
#  3.78144242 2.96317662 1.86348518 0.85109133 1.95099217 0.29205034]
# Device time: 4.6364 seconds
# Iters. done: 61 [Current cost: -22.564980502858926]
# Current parameters: [3.28660301 0.07623572 3.43659452 3.36517957 0.0201694  2.2581724
#  2.23357472 2.25418785 2.90430226 3.09136674 0.47014042 2.20844895
#  3.82188601 1.53569025 2.13186236 3.61081031 2.99376481 1.99975194
#  3.77838111 2.94911631 1.86403622 0.86155837 1.95559354 0.30370426]
# Device time: 4.6399 seconds
# Iters. done: 62 [Current cost: -22.649823741624807]
# Current parameters: [ 3.35888475  0.18818923  3.42992079  3.48688202 -0.06332672  2.47496552
#   2.45238097  2.10120512  2.98283019  3.18897337  0.49954396  2.19449608
#   3.83906344  1.52168411  2.21009078  3.64052459  3.01408503  2.09921524
#   3.79756867  3.11872091  1.86572638  0.75821548  1.90247426  0.18145789]
# Device time: 4.5296 seconds
# Iters. done: 63 [Current cost: -22.661028697878773]
# Current parameters: [ 3.3480079   0.22174     3.45475708  3.5647483  -0.06153523  2.55990526
#   2.26360577  2.1187236   3.0583181   3.2643966   0.49966024  2.19423739
#   3.83439672  1.52119933  2.20978251  3.64060865  3.01304122  2.09916425
#   3.79871593  3.11851553  1.86517424  0.75682852  1.90238119  0.18039643]
# Device time: 4.7255 seconds
# Iters. done: 64 [Current cost: -22.667960873410856]
# Current parameters: [ 3.22207308  0.51782344  3.56566974  3.35079727 -0.05897217  2.41261028
#   2.14277215  2.02861167  3.03200106  3.25366541  0.52286797  2.18499482
#   3.80957969  1.5129551   2.26825355  3.66282367  3.02820359  2.1735162
#   3.81309019  3.24529715  1.86642294  0.67953794  1.86266963  0.08898335]
# Device time: 4.7507 seconds
# Iters. done: 65 [Current cost: -22.560366593774557]
# Current parameters: [ 3.35591182  0.20818534  3.46709154  3.5603343  -0.06087736  2.55439584
#   2.26071762  2.11955847  3.06100116  3.26702793  0.49961086  2.07776384
#   3.83410142  1.30292837  2.2099038   3.63960828  3.01354739  2.09918898
#   3.7868411   3.12993362  1.87676049  0.76881959  1.91374482  0.19222965]
# Device time: 3.7174 seconds
# Iters. done: 66 [Current cost: -22.681652266582294]
# Current parameters: [ 3.42499198  0.01109887  3.50661955  3.50905848 -0.07716899  2.5580351
#   2.23677844  2.08325031  3.11830975  3.33444332  0.51542705  2.09665141
#   3.84005307  1.34447074  2.25004003  3.6393277   3.02712783  2.14970722
#   3.61531189  3.39407567  2.05698271  0.89849777  2.06476947  0.31131042]
# Device time: 3.4668 seconds
# Iters. done: 67 [Current cost: -22.624347460873434]
# Current parameters: [ 3.35366745  0.20475106  3.44579543  3.56078412 -0.01758681  2.55679229
#   2.25852159  2.11768379  2.8871415   3.43995232  0.49951407  2.07721636
#   3.83477501  1.3019024   2.21129867  3.63970371  3.01236238  2.09913109
#   3.78814355  3.12970046  1.87613366  0.76724501  1.91363916  0.19102462]
# Device time: 4.5893 seconds
# Iters. done: 68 [Current cost: -22.65255835209824]
# Current parameters: [3.25551178 0.15714809 3.22868848 3.58551855 0.32708195 2.60328995
#  2.25201375 2.03311814 3.14485242 3.19221037 0.50557102 2.06522779
#  3.84434098 1.28227606 2.24402625 3.64697396 3.00780159 2.12194291
#  3.79778912 3.17262253 1.87668229 0.73577463 1.90546293 0.15803684]
# Device time: 4.6440 seconds
# Iters. done: 69 [Current cost: -22.743243346382098]
# Current parameters: [3.19549839 0.15262638 3.24423696 3.556508   0.32943577 2.60870229
#  2.28935649 2.05249666 3.19485803 3.24350409 0.28005373 2.06535557
#  3.84423306 1.28251551 2.24402625 3.64697396 3.00780159 2.12194291
#  3.79778912 3.17262253 1.87668229 0.73577463 1.90546293 0.15803684]
# Device time: 4.8438 seconds
# Iters. done: 70 [Current cost: -22.72359057833503]
# Current parameters: [3.50466757 0.18181227 3.14452211 3.62898332 0.31124667 2.68956192
#  2.10074715 1.9112389  2.94617238 2.963614   0.30867972 2.05952828
#  3.84713398 1.27378824 2.25880348 3.65186975 3.01319447 2.1399924
#  3.79543894 3.20751849 1.88182134 0.72332001 1.89994456 0.14163064]
# Device time: 4.5990 seconds
# Iters. done: 71 [Current cost: -22.645081247637343]
# Current parameters: [3.22802483 0.14304982 3.21404231 3.58973919 0.30536684 2.60435291
#  2.24496803 2.02131079 3.13709698 3.18710687 0.50635073 1.84748397
#  3.84513036 1.39691326 2.24362216 3.64708415 3.00643329 2.12187607
#  3.79929302 3.1723533  1.87595851 0.73395652 1.90534093 0.15664543]
# Device time: 4.4985 seconds
# Iters. done: 72 [Current cost: -22.744447885492733]
# Current parameters: [ 2.9179657  -0.00751339  3.04640254  3.64002097  0.06873902  2.6292148
#   2.17818032  1.87682169  3.06719624  3.13252801  0.52687686  1.91533989
#   3.85502888  1.337984    2.24773111  3.65109558  2.99467703  2.13152836
#   3.81427119  3.18949454  1.87105451  0.70705416  1.90084328  0.1321041 ]
# Device time: 4.5685 seconds
# Iters. done: 73 [Current cost: -22.818194843032337]
# Current parameters: [2.91619071e+00 9.77853772e-04 3.05488863e+00 3.63426836e+00
#  7.01202105e-02 2.62282420e+00 2.16958284e+00 1.87728650e+00
#  3.06722206e+00 3.13251961e+00 5.26865935e-01 1.91531585e+00
#  4.10417171e+00 1.33793894e+00 2.23630277e+00 3.65109558e+00
#  2.99467703e+00 2.13152836e+00 3.81427119e+00 3.18949454e+00
#  1.87105451e+00 7.07054158e-01 1.90084328e+00 1.32104102e-01]
# Device time: 3.3034 seconds
# Iters. done: 74 [Current cost: -22.80954568433004]
# Current parameters: [ 2.88817987e+00 -2.86785828e-03  3.02029509e+00  3.65300549e+00
#   8.40806280e-02  2.66480232e+00  2.20511076e+00  1.83264069e+00
#   3.10454036e+00  3.13434712e+00  5.57925200e-01  1.91234188e+00
#   3.82888707e+00  1.32414322e+00  1.76170856e+00  3.65836597e+00
#   3.00276478e+00  2.15835751e+00  3.81069839e+00  3.24137210e+00
#   1.87873076e+00  6.88640399e-01  1.89264821e+00  1.07794732e-01]
# Device time: 3.8432 seconds
# Iters. done: 75 [Current cost: -22.815648253752975]
# Current parameters: [ 2.93604981 -0.07049916  3.06396676  3.62329074  0.07173589  2.61171434
#   2.16035285  1.88236619  3.0747676   3.14047363  0.52731186  1.91514026
#   3.85529637  1.33783252  2.24921627  3.6511613   2.98182902  2.35058188
#   3.81536599  3.12832137  1.87118081  0.70546753  1.83059865  0.13118537]
# Device time: 4.5184 seconds
# Iters. done: 76 [Current cost: -22.848179917902495]
# Current parameters: [ 2.93133105 -0.31836022  3.07615119  3.58502961  0.08302165  2.63620322
#   2.15821587  1.78705514  3.21390295  3.18114363  0.61818957  1.9062246
#   3.84543842  1.29855466  2.27025739  3.67223392  3.00631462  2.21276633
#   3.80980179  3.01664433  1.8936717   0.64605959  1.50855169  0.05775524]
# Device time: 4.4228 seconds
# Iters. done: 77 [Current cost: -22.746691851834203]
# Current parameters: [ 2.93127235 -0.07594295  3.05663828  3.61549379  0.06913757  2.62535764
#   2.15841602  1.92654349  3.06571547  3.13111414  0.52882845  1.91465246
#   3.85575356  1.33702011  2.24966331  3.89608797  2.98041626  2.35133796
#   3.81434195  3.13085856  1.8729874   0.70617639  1.83332471  0.13232225]
# Device time: 3.4138 seconds
# Iters. done: 78 [Current cost: -22.82596760530297]
# Current parameters: [ 2.83269428 -0.09036741  2.94506833  3.57130697  0.04380861  2.81111372
#   2.19007004  2.24798451  3.04530008  3.04936255  0.59461439  1.90556463
#   3.85340349  1.30714092  2.26255062  3.53235107  2.97978558  2.42873119
#   3.82369005  3.20526825  1.87769796  0.65705687  1.80702546  0.07723777]
# Device time: 3.4007 seconds
# Iters. done: 79 [Current cost: -22.735198935303742]
# Current parameters: [ 2.96052897 -0.13873557  3.09241125  3.60533657  0.07581561  2.59206019
#   2.14272808  1.8874098   3.08292279  3.14846537  0.5271484   1.91516314
#   3.85524435  1.33780177  2.24869995  3.65099257  2.9817119   2.34997908
#   3.88783776  3.17795477  1.80352841  0.52133729  1.88021011  0.21233536]
# Device time: 3.2568 seconds
# Iters. done: 80 [Current cost: -22.794741797410925]
# Current parameters: [ 2.90772653 -0.07077823  3.03798104  3.63528679  0.07193478  2.63703932
#   2.18152884  1.82367287  3.11634963  3.14904358  0.55754553  1.91232851
#   3.85179884  1.32495367  2.25667484  3.64606436  2.98528217  2.39385485
#   3.7242922   3.17167181  1.44921181  0.91130343  1.81488424  0.22134227]
# Device time: 3.5773 seconds
# Iters. done: 81 [Current cost: -22.804858518708624]
# Current parameters: [ 2.94032646 -0.0681247   3.07285723  3.62409464  0.07246802  2.61166919
#   2.16273824  1.88118012  3.07443415  3.13954891  0.52665155  1.9153904
#   3.85493952  1.33797351  2.24700419  3.65038648  2.73517645  2.33587418
#   3.81414102  3.15541398  1.87188762  0.70690121  1.80634066  0.13233563]
# Device time: 3.2902 seconds
# Iters. done: 82 [Current cost: -22.845312898975937]
# Current parameters: [ 2.88327768 -0.05820116  3.02908466  3.65374189  0.07388124  2.6694077
#   2.21557014  1.74866942  3.16509686  3.15609204  0.5923569   1.90962524
#   3.84655026  1.30973631  2.25949788  3.63770191  2.91696736  2.43531518
#   3.78435139  2.82354347  1.92268649  0.72376546  2.13387151  0.04966683]
# Device time: 3.2975 seconds
# Iters. done: 83 [Current cost: -22.826764778921767]
# Current parameters: [ 2.95683897 -0.13860926  3.08785434  3.6843295   0.07747771  2.52189974
#   2.14151581  1.92066869  3.07690483  3.14289315  0.51604086  1.91513176
#   3.85530355  1.33781658  2.2492113   3.65116265  2.98181219  2.35058106
#   3.81538448  3.17701975  1.820648    0.70544518  1.8792919  -0.05796362]
# Device time: 3.3389 seconds
# Iters. done: 84 [Current cost: -22.865345689377733]
# Current parameters: [ 2.87882994 -0.05791867  3.02082784  4.06082815  0.08282294  2.29115486
#   2.20021658  1.94848602  3.11497121  3.12294989  0.52047608  1.91082056
#   3.84830357  1.31566815  2.25798592  3.6405994   2.98686584  2.42143797
#   3.79066592  3.17184663  1.90941144  0.72005157  1.81366435  0.05593122]
# Device time: 3.7059 seconds
# Iters. done: 85 [Current cost: -22.706843256859408]
# Current parameters: [ 3.04191035 -0.10839582  2.91514556  3.62561696  0.01014777  2.45340212
#   2.12148485  1.9380208   3.14787986  3.21228569  0.51578348  1.91286624
#   3.85721703  1.33357101  2.24754271  3.65161766  2.97616217  2.35030504
#   3.84964107  3.1779507   1.81970286  0.71184443  1.88083046 -0.06166427]
# Device time: 3.3279 seconds
# Iters. done: 86 [Current cost: -22.89010393803055]
# Current parameters: [ 3.02529435 -0.15785775  2.96011058  3.62258633  0.02743528  2.48074395
#   2.12840554  1.89710662  3.16344254  3.20804355  0.53504851  1.9118205
#   3.8545012   1.3268528   2.25082525  3.64795912  2.97893735  2.37432226
#   4.28039933  3.22763816  1.86249044  0.93651518  1.9099491  -0.06436972]
# Device time: 3.4031 seconds
# Iters. done: 87 [Current cost: -22.821553447995395]
# Current parameters: [ 3.01249858e+00 -1.79082455e-01  2.91282117e+00  3.57648043e+00
#   5.14472358e-02  2.35367676e+00  2.01858364e+00  2.01861306e+00
#   3.11049819e+00  3.16463574e+00  5.00000775e-01  1.92026388e+00
#   3.84995817e+00  1.34094301e+00  2.20571934e+00  3.63573179e+00
#   2.96529679e+00  2.29712939e+00  3.83938475e+00  3.08727549e+00
#   1.81879838e+00  7.67091911e-01  1.90922921e+00  3.69000959e-03]
# Device time: 3.3367 seconds
# Iters. done: 88 [Current cost: -22.797920130184345]
# Current parameters: [ 2.89308427  0.13822846  2.96427966  3.39585683  0.02017374  2.33844375
#   2.02035023  1.78359037  3.1812275   3.20287752  0.58051974  1.90325445
#   3.82677068  1.30874071  2.29107381  3.65607301  2.98903755  2.45864904
#   3.81322296  3.29960987  1.84465909  0.66367075  1.84654243 -0.21443135]
# Device time: 3.3966 seconds
# Iters. done: 89 [Current cost: -22.766137658845988]
# Current parameters: [ 3.06773916 -0.188208    2.92361568  3.59566524  0.0079779   2.45783945
#   2.11097947  1.90008941  3.17192765  3.23917328  0.52151514  1.9263738
#   3.85945961  1.36044956  2.25799753  3.61651711  3.01982527  2.40825944
#   3.76435096  3.28032574  1.9355285   0.79371706  1.91829394  0.00756477]
# Device time: 3.5179 seconds
# Iters. done: 90 [Current cost: -22.825399856220375]
# Current parameters: [ 3.07272276 -0.24798687  2.87625251  3.6804268  -0.0249973   2.53138051
#   2.19733964  1.95305415  3.25249029  3.25532242  0.57994377  1.90854538
#   3.85877675  1.31373252  2.2815105   3.82238147  2.77232889  2.21619525
#   3.8167099   3.30139389  1.67663328  0.62141134  2.06121262 -0.226196  ]
# Device time: 3.3086 seconds
# Iters. done: 91 [Current cost: -22.801661150198793]
# Current parameters: [ 3.03457681 -0.11161248  2.87603929  3.63448868  0.05405391  2.47298423
#   2.13062229  1.92176361  2.98554048  3.38734692  0.52412997  1.91022987
#   3.85717839  1.32500073  2.24444644  3.64823982  2.97407945  2.35618698
#   3.85099259  3.16277642  1.81308113  0.70683729  1.87147453 -0.08553523]
# Device time: 3.3698 seconds
# Iters. done: 92 [Current cost: -22.833867659294214]
# Current parameters: [ 3.04488144 -0.09080335  2.92548991  3.66548643  0.0092628   2.49813809
#   2.02313043  1.9430327   3.17858917  3.24250503  0.50911679  1.91268449
#   3.85496333  1.33329264  2.24776057  3.65179566  2.97583907  2.35079391
#   3.85010655  3.17883826  1.81958796  0.71084956  1.88062257 -0.06262279]
# Device time: 3.3978 seconds
# Iters. done: 93 [Current cost: -22.854073894706417]
# Current parameters: [ 3.15818474 -0.10221832  2.85132824  3.63883711 -0.0183886   2.49951366
#   2.11900756  1.85556474  3.06363471  3.07923458  0.4320496   1.90862245
#   3.85799898  1.32032402  2.24525124  3.64764405  2.97781736  2.36797559
#   3.84783036  3.16692924  1.81196351  0.70196253  1.86269489 -0.10634544]
# Device time: 3.2683 seconds
# Iters. done: 94 [Current cost: -22.875024122573596]
# Current parameters: [ 3.0280098  -0.10737965  2.88509737  3.63022206  0.04951131  2.46093521
#   2.12192332  1.92879889  3.15521901  3.20342586  0.51641557  1.96515567
#   3.85839978  1.43185158  2.25097571  3.65283086  2.97534189  2.3526201
#   3.85622217  3.17706367  1.81436586  0.70295061  1.87475708 -0.07060285]
# Device time: 3.2580 seconds
# Iters. done: 95 [Current cost: -22.830986269189296]
# Current parameters: [ 3.08237158 -0.08149498  3.01248923  3.6167368  -0.18744857  2.44140282
#   2.15658017  1.96570113  3.12296496  3.24032321  0.52506951  1.94882489
#   3.85162515  1.39542192  2.22498397  3.64419587  2.97798836  2.34522061
#   3.84728664  3.13605333  1.80985711  0.7217743   1.87162432 -0.07266869]
# Device time: 3.3625 seconds
# Iters. done: 96 [Current cost: -22.81428970738729]
# Current parameters: [ 3.02635691e+00 -1.15570063e-01  2.90831179e+00  3.62683594e+00
#  -6.17450486e-04  2.45409816e+00  2.11911083e+00  1.93272094e+00
#   3.14553898e+00  3.21130770e+00  5.09274449e-01  1.80420216e+00
#   3.85760768e+00  1.39078958e+00  2.24734104e+00  3.65167265e+00
#   2.97547930e+00  2.35027168e+00  3.85039161e+00  3.17781634e+00
#   1.81934165e+00  7.10937080e-01  1.88076958e+00 -6.23586725e-02]
# Device time: 3.2442 seconds
# Iters. done: 97 [Current cost: -22.87057985066642]
# Current parameters: [ 2.9813466  -0.11389497  2.923724    3.59726619  0.01104721  2.46402036
#   2.175371    1.9503864   3.20790725  3.25960668  0.29769324  1.92068032
#   3.85667941  1.30188173  2.24448563  3.64931582  2.97584661  2.35365379
#   3.8484299   3.16926667  1.81706044  0.71130285  1.87623338 -0.0739743 ]
# Device time: 3.3368 seconds
# Iters. done: 98 [Current cost: -22.83188716456344]
# Current parameters: [ 3.05225272 -0.10819856  2.92317041  3.62194571  0.00853033  2.44433753
#   2.1154515   1.95038686  3.13922354  3.21234345  0.50785004  1.91297825
#   3.86203255  1.33757421  2.36875731  3.64976737  2.97425579  2.34352536
#   3.85039156  3.16485558  1.8178349   0.71668751  1.88291586 -0.05537336]
# Device time: 3.4052 seconds
# Iters. done: 99 [Current cost: -22.852127845575428]
# Current parameters: [ 3.19628573 -0.0351655   2.98286644  3.60444608  0.12532587  2.45231669
#   2.18413319  1.99296229  3.19990466  3.22895931  0.53476424  1.86717251
#   3.85034268  1.31719562  2.21064026  3.64581072  2.98185023  2.35317899
#   3.83980663  3.15641499  1.81770369  0.72313095  1.87415362 -0.07349254]
# Device time: 3.2512 seconds
# Iters. done: 100 [Current cost: -22.833699643027828]
# Current parameters: [ 3.04107453 -0.11192494  2.91319043  3.62189152  0.00832879  2.45960025
#   2.11900646  1.97781371  3.13744313  3.20389102  0.51418483  1.91274857
#   3.85729068  1.33390921  2.24685955  3.65240417  2.96561984  2.33843561
#   3.87119511  3.17481245  1.91594196  0.65993482  1.88781274 -0.09403489]
# Device time: 3.4210 seconds
# Iters. done: 101 [Current cost: -22.851057794381553]
# Current parameters: [ 2.98377821 -0.09840868  2.8378985   3.60655413 -0.0144841   2.55586652
#   2.16306779  2.06002961  3.14402996  3.16149899  0.56973324  1.90008677
#   3.86004409  1.27595449  2.24231166  3.5815176   3.00399186  2.41654173
#   3.83125104  3.19919486  1.76173567  0.74385488  1.85677489 -0.072507  ]
# Device time: 4.0765 seconds
# Iters. done: 102 [Current cost: -22.794992015604365]
# Current parameters: [ 3.05441227 -0.1247983   2.92461644  3.62142533  0.01036932  2.43670917
#   2.10840302  1.9679076   3.13323504  3.21006825  0.50443178  1.9137122
#   3.85644615  1.33813688  2.24612864  3.66382567  2.97744476  2.31574433
#   3.85543538  3.2492536   1.8065535   0.70731143  1.79887123 -0.0598319 ]
# Device time: 3.2766 seconds
# Iters. done: 103 [Current cost: -22.79513339583866]
# Current parameters: [ 3.02829858 -0.19396828  2.90317355  3.61659082  0.00721123  2.47551859
#   2.14887985  1.82869913  3.22768002  3.22825106  0.5785452   1.90233789
#   3.86020926  1.28111292  2.24824388  3.6352115   3.00722479  2.31206627
#   3.83533275  3.05899795  1.84179765  0.70825605  1.78455236 -0.09789134]
# Device time: 3.2539 seconds
# Iters. done: 104 [Current cost: -22.863218296590006]
# Current parameters: [ 3.01183186e+00 -4.98900030e-02  2.87688805e+00  3.79756650e+00
#  -1.64204193e-04  2.34393641e+00  2.17327142e+00  1.89518458e+00
#   3.16401081e+00  3.19419940e+00  5.31750220e-01  1.90222790e+00
#   3.85588600e+00  1.27642963e+00  2.23360843e+00  3.66722068e+00
#   2.96561732e+00  2.39458913e+00  3.84621412e+00  3.16788942e+00
#   1.83631420e+00  7.05654367e-01  1.91080751e+00 -1.18835569e-02]
# Device time: 3.2951 seconds
# Iters. done: 105 [Current cost: -22.805488358610923]
# Current parameters: [ 3.04849686 -0.14542089  2.91298027  3.61309308  0.00401856  2.4680907
#   2.13262258  1.92088709  3.16366494  3.21283309  0.5343524   1.91038922
#   3.85774739  1.31347924  2.24335483  3.6921814   2.93024465  2.32339722
#   3.84046486  3.200008    1.78517099  0.69969372  1.95273931 -0.08989223]
# Device time: 3.2858 seconds
# Iters. done: 106 [Current cost: -22.839494830315395]
# Current parameters: [ 3.04176242 -0.11185769  2.91454767  3.62687239  0.01037489  2.4559436
#   2.12380498  1.93668202  3.14823119  3.21208828  0.51634933  1.91284522
#   3.79655827  1.33339747  2.25041614  3.6515613   2.97643925  2.35086757
#   3.86186883  3.17936653  1.8208814   0.71785547  1.88170938 -0.06127046]
# Device time: 3.3092 seconds
# Iters. done: 107 [Current cost: -22.84090655767405]
# Current parameters: [ 3.03869911 -0.1116792   2.92867236  3.6194036   0.01327191  2.46085984
#   2.12426366  1.9195113   3.1477876   3.20917948  0.52042946  1.91136982
#   3.89358156  1.32596919  2.24354873  3.6495799   2.97957524  2.360609
#   3.95212136  3.1852267   1.82782722  0.76369807  1.89103231 -0.06267416]
# Device time: 3.3249 seconds
# Iters. done: 108 [Current cost: -22.827662782540774]
# Current parameters: [ 3.04367432 -0.10980148  2.91963129  3.62916253  0.01136154  2.44437362
#   2.12013969  1.92940904  3.15009864  3.21423572  0.51511642  1.91296218
#   3.8568693   1.33363438  2.24737017  3.5968706   2.96358071  2.33751764
#   3.85358377  3.18833101  1.81286874  0.70123118  1.88817257 -0.0683408 ]
# Device time: 3.2256 seconds
# Iters. done: 109 [Current cost: -22.83884295870852]
# Current parameters: [ 3.00870166 -0.04540368  2.92628807  3.56131003  0.01296451  2.42628005
#   2.09511351  1.89962246  3.14289212  3.20118343  0.52809631  1.90909051
#   3.86316317  1.31765318  2.24666002  3.67024105  2.98849046  2.38143929
#   3.82587448  3.18177105  1.82225377  0.69945229  1.87864932 -0.08543963]
# Device time: 3.3357 seconds
# Iters. done: 110 [Current cost: -22.827139220640603]
# Current parameters: [ 3.04978543 -0.13279208  2.92372704  3.62234458  0.01154896  2.44365893
#   2.11488114  1.9413045   3.15056146  3.21501177  0.51537363  1.91283742
#   3.85725189  1.33354068  2.24769623  3.65157876  2.96357042  2.39510694
#   3.85903989  3.17461222  1.80912041  0.68814628  1.87354299 -0.05908372]
# Device time: 3.2348 seconds
# Iters. done: 111 [Current cost: -22.83284279435088]
# Current parameters: [ 3.04864181 -0.1036581   2.91016834  3.61108007  0.00602454  2.47669937
#   2.1290906   1.92783467  3.14496735  3.21293042  0.51623704  1.91180098
#   3.86518298  1.32837286  2.2434013   3.65815329  3.03996256  2.32370427
#   3.86621508  3.1756726   1.80734087  0.65222223  1.90399912  0.01000725]
# Device time: 3.2111 seconds
# Iters. done: 112 [Current cost: -22.833986447206854]
# Current parameters: [ 3.03952669 -0.09365714  2.91236237  3.61584274  0.00918056  2.46887212
#   2.12541817  1.93111845  3.14611428  3.21157211  0.516476    1.91286489
#   3.85710146  1.33377527  2.24681453  3.64915187  2.9353029   2.34969367
#   3.84970015  3.17200355  1.8301088   0.71292147  1.86478592 -0.02711257]
# Device time: 3.2486 seconds
# Iters. done: 113 [Current cost: -22.82447902512794]
# Current parameters: [ 3.04780568e+00 -1.40634656e-01  2.90686782e+00  3.62542535e+00
#   3.57752527e-03  2.46906123e+00  2.13463357e+00  1.93401384e+00
#   3.16132325e+00  3.21262263e+00  5.30683768e-01  1.91130569e+00
#   3.87630038e+00  1.31859088e+00  2.24379748e+00  3.70759177e+00
#   2.94507549e+00  2.31160442e+00  3.82175892e+00  3.19504412e+00
#   1.79298078e+00  7.15053341e-01  1.94559415e+00 -9.92355878e-02]
# Device time: 3.2050 seconds
# Iters. done: 114 [Current cost: -22.83267313029903]
# Current parameters: [ 3.02782664 -0.10356992  2.89498186  3.62830247  0.00488169  2.4765336
#   2.13191557  1.96960055  3.14708408  3.20136432  0.52639321  1.91047446
#   3.86456718  1.32358199  2.24708672  3.63813353  2.9937741   2.36503935
#   3.83794677  3.17311201  1.81181876  0.72587005  1.87696914 -0.06982993]
# Device time: 3.3183 seconds
# Iters. done: 115 [Current cost: -22.819381187080154]
# Current parameters: [ 3.05149176 -0.10548366  2.89334564  3.61886949  0.00428681  2.44586316
#   2.11911314  1.93956638  3.14924939  3.22765515  0.51606054  1.91255458
#   3.85741729  1.3328136   2.24708676  3.65137492  2.97548966  2.35047329
#   3.85343221  3.17734874  1.81961813  0.71280774  1.88082315 -0.0626704 ]
# Device time: 3.1848 seconds
# Iters. done: 116 [Current cost: -22.841931675552257]
# Current parameters: [ 3.03665402 -0.11228539  2.92730638  3.63681848  0.02657795  2.46108393
#   2.12573269  1.92855033  3.10259032  3.24136907  0.51335563  1.9126768
#   3.8598227   1.33175289  2.24406605  3.65363198  2.9813612   2.34994892
#   3.84157305  3.16885968  1.82131644  0.7146863   1.88020219 -0.06785387]
# Device time: 3.1798 seconds
# Iters. done: 117 [Current cost: -22.842126191439036]
# Current parameters: [ 3.03552413 -0.10786287  2.90298132  3.63738473  0.0288203   2.44702254
#   2.12119291  1.93395297  3.15029157  3.20814321  0.51551212  1.90758284
#   3.85779303  1.32338451  2.250621    3.65395345  2.97502266  2.35239596
#   3.85041116  3.18411593  1.8223142   0.70931535  1.88136821 -0.05775536]
# Device time: 3.2588 seconds
# Iters. done: 118 [Current cost: -22.837584994146557]
# Current parameters: [ 3.04553502 -0.09525738  2.93598177  3.65687875 -0.01973396  2.42974576
#   2.13098382  1.93479476  3.15571176  3.20415346  0.51371217  1.92005477
#   3.86189343  1.34371346  2.24134591  3.6605063   2.98396707  2.34888767
#   3.84225839  3.16668157  1.82662087  0.71711703  1.88177592 -0.05861333]
# Device time: 3.1788 seconds
# Iters. done: 119 [Current cost: -22.837173269237613]
# Current parameters: [ 3.03709993 -0.1077871   2.9137459   3.62773275  0.01086609  2.45381055
#   2.12305518  1.93557345  3.15181408  3.21173489  0.52001702  1.91114569
#   3.85722484  1.32896613  2.24757923  3.65409066  2.97404544  2.34043822
#   3.85735026  3.16025062  1.81060999  0.70316601  1.86830714 -0.07083505]
# Device time: 3.2408 seconds
# Iters. done: 120 [Current cost: -22.862841358102713]
# Current parameters: [ 3.04772335 -0.13846579  2.91964795  3.6140629   0.01167728  2.46180038
#   2.12188476  1.91281899  3.16810038  3.21436098  0.5231437   1.91333528
#   3.86051063  1.33220571  2.24997526  3.64568977  2.99263635  2.34755573
#   3.83156481  3.17170714  1.84303603  0.72549483  1.8663569  -0.06187578]
# Device time: 3.2612 seconds
# Iters. done: 121 [Current cost: -22.824260758262]
# Current parameters: [ 3.05655103 -0.10503371  2.90800703  3.6297837   0.00551879  2.46310329
#   2.1215306   1.92603155  3.13997632  3.19894251  0.50623095  1.91213842
#   3.85746498  1.33178302  2.24854527  3.6516364   2.97667642  2.35400512
#   3.84975178  3.17942451  1.81881732  0.70898283  1.87783351 -0.06892095]
# Device time: 3.2474 seconds
# Iters. done: 122 [Current cost: -22.83716093059434]
# Current parameters: [ 3.04596336 -0.12153946  2.91587071  3.61135191  0.01933411  2.43557366
#   2.09590258  1.95376273  3.13386131  3.18887273  0.50240956  1.91399309
#   3.85724127  1.33476869  2.23536714  3.64981969  2.97579091  2.33800407
#   3.84560982  3.15484309  1.81700684  0.72631061  1.8911864  -0.05139938]
# Device time: 3.1739 seconds
# Iters. done: 123 [Current cost: -22.834489150943746]
# Current parameters: [ 3.05954641 -0.10214603  2.9195096   3.62678619  0.01919884  2.45244648
#   2.12079847  1.94122033  3.14634683  3.20920866  0.53753598  1.90871033
#   3.85679675  1.33612172  2.24655448  3.65136911  2.976599    2.35014453
#   3.8490515   3.17692601  1.81973382  0.71276408  1.88072847 -0.06141278]
# Device time: 3.3581 seconds
# Iters. done: 124 [Current cost: -22.80532986583821]
# Current parameters: [ 3.05406219 -0.0936559   2.93298468  3.61539162  0.03177532  2.45890257
#   2.1397527   1.95174257  3.17095355  3.22525309  0.48021768  1.90788856
#   3.85798615  1.33385593  2.24347575  3.65296098  2.97903774  2.35083758
# ...
#   2.12125354  1.93770346  3.14796758  3.21210745  0.51594221  1.91290775
#   3.85713752  1.33352435  2.24756449  3.65147737  2.9756344   2.35071505
#   3.84919519  3.17807546  1.81987521  0.7124284   1.88065449 -0.06273726]
# Device time: 3.2042 seconds
# Iters. done: 165 [Current cost: -22.864759346790454]
# Current parameters: [ 3.04190681 -0.10817899  2.91528262  3.6275469   0.00828722  2.45200944
#   2.1224725   1.93782557  3.14857461  3.21159146  0.51598909  1.91322416
#   3.85733743  1.33377554  2.24741197  3.65063916  2.97678188  2.34908508
#   3.84969739  3.17830971  1.81944655  0.71144362  1.88135337 -0.06104505]
# Device time: 3.3539 seconds
# Iters. done: 166 [Current cost: -22.849259839889093]
# Current parameters: [ 3.04220025 -0.10841267  2.91541955  3.6258598   0.01035859  2.45351959
#   2.12172373  1.93812811  3.14807246  3.21280916  0.51591066  1.91387542
#   3.85726625  1.33296743  2.24770407  3.65168308  2.97675804  2.35053222
#   3.84982855  3.17828857  1.82012005  0.71127546  1.88091529 -0.06248022]
# Device time: 3.4238 seconds
# Iters. done: 167 [Current cost: -22.83238871198917]
# Current parameters: [ 3.04183527 -0.1082093   2.91488281  3.62455724  0.01003672  2.45332128
#   2.12108491  1.9386351   3.14743333  3.21075201  0.5157157   1.91476769
#   3.85703921  1.33243757  2.24723784  3.65183425  2.97474574  2.34925068
#   3.84966472  3.177387    1.82050654  0.71194248  1.88060942 -0.0603598 ]
# Device time: 3.2660 seconds
# Iters. done: 168 [Current cost: -22.86281759948824]
# Current parameters: [ 3.04233993 -0.10840245  2.91395084  3.62508029  0.00980674  2.45287961
#   2.12140968  1.93826405  3.14797772  3.21308496  0.51554427  1.91289703
#   3.8571138   1.33384462  2.24744629  3.65171591  2.97616983  2.35005548
#   3.84950677  3.17824754  1.81941674  0.71183578  1.88020731 -0.06156027]
# Device time: 3.3911 seconds
# Iters. done: 169 [Current cost: -22.88717082349227]
# Current parameters: [ 3.04165175 -0.10842143  2.9148095   3.62570456  0.01001454  2.45373478
#   2.1215595   1.93830197  3.1478486   3.2121163   0.51607004  1.91286935
#   3.85702559  1.33343023  2.24708792  3.65145599  2.97640784  2.35049904
#   3.84955902  3.17797314  1.81966485  0.71201032  1.88075043 -0.06176751]
# Device time: 3.2955 seconds
# Iters. done: 170 [Current cost: -22.868228833559158]
# Current parameters: [ 3.0415982  -0.10851937  2.91500782  3.62522557  0.00985584  2.45366634
#   2.12153863  1.93822833  3.14775882  3.21188589  0.51604193  1.91252315
#   3.85705227  1.33351293  2.24912846  3.65187387  2.97644357  2.35006807
#   3.84961908  3.17812367  1.81929866  0.71201226  1.88080083 -0.06163452]
# Device time: 3.6212 seconds
# Iters. done: 171 [Current cost: -22.835002004842416]
# Current parameters: [ 3.04170103 -0.10806737  2.9148441   3.62585738  0.010504    2.45324314
#   2.12142923  1.93804808  3.14777833  3.21214963  0.51585013  1.91270324
#   3.85722961  1.33340009  2.2475005   3.65184192  2.97603173  2.3502126
#   3.85001164  3.17809461  1.8194773   0.71150548  1.88087046 -0.06173535]
# Device time: 3.3090 seconds
# Iters. done: 172 [Current cost: -22.841888908027467]
# Current parameters: [ 3.04176489 -0.10931531  2.91525701  3.62549913  0.01060452  2.45329205
#   2.12173631  1.93707358  3.1486118   3.21224016  0.51562998  1.91252097
#   3.85718769  1.33326927  2.24724471  3.65175886  2.97620707  2.3499642
#   3.84911921  3.17776981  1.81989738  0.71200801  1.88026141 -0.06144588]
# Device time: 3.3122 seconds
# Iters. done: 173 [Current cost: -22.828255652764238]
# Current parameters: [ 3.0425316  -0.10843229  2.91506985  3.62597343  0.01039522  2.45346258
#   2.12157139  1.93804104  3.14781497  3.21210011  0.51601689  1.91294789
#   3.85723488  1.3335543   2.24765588  3.65157299  2.97597087  2.35033138
#   3.84956403  3.17791103  1.819465    0.71214658  1.88061594 -0.06174736]
# Device time: 3.2452 seconds
# Iters. done: 174 [Current cost: -22.81711536253809]
# Current parameters: [ 3.04247871 -0.10783905  2.9157175   3.62471604  0.00965289  2.45350754
#   2.12137649  1.93780965  3.14757642  3.21206664  0.51586149  1.91236374
#   3.85704902  1.33403583  2.2470291   3.65167327  2.97655783  2.35030686
#   3.8494336   3.17807216  1.82004033  0.71118142  1.88097427 -0.06148477]
# Device time: 3.2241 seconds
# Iters. done: 175 [Current cost: -22.849138204113515]
# Current parameters: [ 3.04200981 -0.10868417  2.91521204  3.62545768  0.00996441  2.45330772
#   2.12136301  1.93810649  3.14835111  3.21201438  0.51583896  1.91291594
#   3.85725708  1.33364459  2.24748969  3.65169688  2.97598698  2.35075383
#   3.85000281  3.17813863  1.81951091  0.71173021  1.88081571 -0.06164436]
# Device time: 3.4109 seconds
# Iters. done: 176 [Current cost: -22.849116003118393]
# Current parameters: [ 3.04159484 -0.10849789  2.91554144  3.62540585  0.00982094  2.4537837
#   2.12150155  1.937759    3.14754017  3.21279811  0.51559189  1.91310715
#   3.85755488  1.33382473  2.24710333  3.6519596   2.97608747  2.34963393
#   3.8502941   3.17849727  1.81947572  0.71278322  1.88113947 -0.06177115]
# Device time: 3.3397 seconds
# Iters. done: 177 [Current cost: -22.852351458543918]
# Current parameters: [ 3.04180439 -0.10815849  2.91515473  3.6256065   0.01007739  2.45378285
#   2.12177718  1.93782423  3.14800072  3.2125253   0.515953    1.91285351
#   3.85721253  1.33355963  2.24766261  3.65128067  2.97571656  2.35037715
#   3.84968559  3.17819676  1.8197732   0.71167547  1.88061319 -0.06147474]
# Device time: 3.2317 seconds
# Iters. done: 178 [Current cost: -22.84092685985176]
# Current parameters: [ 3.04191196 -0.10888562  2.91517912  3.62515657  0.01056665  2.45326319
#   2.12105711  1.93811907  3.14767182  3.21221085  0.51554413  1.91280189
#   3.85714033  1.33347762  2.24751795  3.65017184  2.97613294  2.34986047
#   3.84970623  3.17811034  1.81929161  0.71162617  1.88122526 -0.06206121]
# Device time: 3.2202 seconds
# Iters. done: 179 [Current cost: -22.850519237613227]
# Current parameters: [ 3.04173112 -0.10831589  2.91503691  3.62511367  0.0099886   2.45321926
#   2.12123906  1.93841862  3.1476448   3.21173389  0.51556605  1.91389379
#   3.85715104  1.33306074  2.24747027  3.65176063  2.975615    2.34984187
#   3.84951853  3.17749895  1.82028186  0.7118841   1.88083094 -0.06102356]
# Device time: 3.2202 seconds
# Iters. done: 180 [Current cost: -22.858606842855185]
# Current parameters: [ 3.04178218 -0.10823455  2.91528482  3.62558334  0.01016439  2.45341863
#   2.12170032  1.93842517  3.14800466  3.21238515  0.51534171  1.91274279
#   3.85772365  1.33353944  2.24749834  3.65162804  2.97623219  2.35041767
#   3.84933317  3.17777794  1.81950313  0.71184893  1.88087698 -0.06164653]
# Device time: 3.2997 seconds
# Iters. done: 181 [Current cost: -22.837295208439443]
# Current parameters: [ 3.04192671 -0.10850492  2.91512713  3.62550651  0.01030247  2.4535538
#   2.12142121  1.93816665  3.14779938  3.21233716  0.51572894  1.91273041
#   3.85720454  1.33361234  2.24755656  3.65171653  2.97601505  2.35036693
#   3.84969352  3.17792009  1.81990404  0.71185459  1.88075659 -0.06181877]
# Device time: 3.1464 seconds
# Iters. done: 182 [Current cost: -22.851153109208227]
# Current parameters: [ 3.04186576 -0.10856136  2.91512922  3.6260933   0.00970787  2.45310441
#   2.12163363  1.93816754  3.14793755  3.21223076  0.51573112  1.91271562
#   3.85714701  1.33380898  2.2475733   3.65147414  2.97617974  2.35000255
#   3.84972257  3.17794675  1.82007584  0.71175376  1.88092556 -0.06170456]
# Device time: 3.2277 seconds
# Iters. done: 183 [Current cost: -22.88814645907325]
# Current parameters: [ 3.04186357 -0.10841438  2.91523929  3.62553269  0.01027147  2.45324777
#   2.1215239   1.93817981  3.14793593  3.21239959  0.51611967  1.91283825
#   3.85730351  1.33361626  2.24752499  3.65161073  2.9761729   2.35024677
#   3.84964031  3.1779356   1.81973952  0.71188134  1.88085524 -0.06157948]
# Device time: 3.2364 seconds
# Iters. done: 184 [Current cost: -22.87826965649708]
# Current parameters: [ 3.04184271 -0.10827402  2.91541397  3.62580269  0.01015659  2.45339749
#   2.12117806  1.93816023  3.1480819   3.21261209  0.51564987  1.91287944
#   3.85655227  1.33357803  2.24754449  3.65168451  2.9761795   2.35029606
#   3.84953598  3.17784935  1.81951312  0.71190358  1.88092535 -0.06148522]
# Device time: 3.2352 seconds
# Iters. done: 185 [Current cost: -22.84095488289577]
# Current parameters: [ 3.0418673  -0.10842022  2.91515574  3.62567652  0.01028918  2.45335873
#   2.12145222  1.93807022  3.14782262  3.21220405  0.5157072   1.91291969
#   3.8572086   1.33367868  2.24755568  3.65162337  2.97620841  2.35037743
#   3.84949506  3.17829987  1.81979105  0.71188064  1.88082819 -0.06153491]
# Device time: 3.3838 seconds
# Iters. done: 186 [Current cost: -22.80591315626341]
# Current parameters: [ 3.04208077 -0.10838367  2.91485782  3.62556006  0.0100295   2.45329683
#   2.12151928  1.9378004   3.14786982  3.21247492  0.51580061  1.91265087
#   3.85725584  1.33320072  2.247602    3.65156802  2.97617913  2.35055132
#   3.84970711  3.17783465  1.81989975  0.71206141  1.8814194  -0.06150622]
# Device time: 3.1825 seconds
# Iters. done: 187 [Current cost: -22.87377890350354]
# Current parameters: [ 3.0418801  -0.10858188  2.91516636  3.62564268  0.01004963  2.45338584
#   2.12153719  1.93801248  3.14771196  3.21234358  0.51586389  1.91288657
#   3.85719756  1.33353727  2.24749661  3.65174015  2.97598434  2.35033178
#   3.84944265  3.17798889  1.81956289  0.71169199  1.88094608 -0.06171576]
# Device time: 3.2618 seconds
# Iters. done: 188 [Current cost: -22.858735106384522]
# Current parameters: [ 3.04176148 -0.10850208  2.9152897   3.62565814  0.0100013   2.45315344
#   2.12146805  1.93786148  3.14741413  3.21243119  0.51575647  1.91288501
#   3.85726354  1.33350932  2.24758127  3.65146153  2.97637546  2.35060699
#   3.84994886  3.17763819  1.81964899  0.71184366  1.88042742 -0.06151132]
# Device time: 3.1993 seconds
# Iters. done: 189 [Current cost: -22.83414142166292]
# Current parameters: [ 3.04184261 -0.10851451  2.91511818  3.62555935  0.01019122  2.45339479
#   2.12154006  1.93776224  3.14810013  3.21224145  0.51578121  1.91280799
#   3.85721647  1.33349217  2.24747034  3.65167615  2.97625457  2.35012111
#   3.849573    3.17781849  1.81972599  0.71183325  1.88073774 -0.06170096]
# Device time: 3.2417 seconds
# Iters. done: 190 [Current cost: -22.851344365775972]
# Current parameters: [ 3.0418569  -0.10839019  2.91508294  3.62560842  0.01017395  2.45340937
#   2.12147484  1.93797882  3.14786594  3.21223838  0.51578287  1.91283858
#   3.85721465  1.33373461  2.24753201  3.65160414  2.976104    2.35032501
#   3.84962717  3.17786481  1.81966532  0.71188358  1.88087337 -0.06160327]
# Device time: 3.3223 seconds
# Iters. done: 191 [Current cost: -22.884008940480243]
# Current parameters: [ 3.0419384  -0.10832386  2.91508763  3.62560978  0.01015097  2.45345862
#   2.12154111  1.93801126  3.14791764  3.2123822   0.51582278  1.91316022
#   3.85722622  1.33369663  2.24762842  3.6516182   2.9763048   2.35034218
#   3.84970507  3.17786138  1.81974573  0.71172477  1.88096074 -0.06184794]
# Device time: 3.2359 seconds
# Iters. done: 192 [Current cost: -22.860052081709327]
# Current parameters: [ 3.04185912 -0.10839886  2.91528833  3.62569428  0.01018549  2.45347942
#   2.12146562  1.93798933  3.14787001  3.2121931   0.51581971  1.9128624
#   3.8572475   1.33353734  2.24755543  3.65160531  2.97616459  2.35033282
#   3.8496543   3.17791296  1.81973974  0.71183771  1.88090576 -0.06166898]
# Device time: 3.2450 seconds
# Iters. done: 193 [Current cost: -22.871951929641444]
# Current parameters: [ 3.04192324 -0.10837214  2.91505446  3.62569811  0.01003033  2.45347837
#   2.12111905  1.938       3.14791446  3.21237126  0.5158647   1.91285763
#   3.85741852  1.33357729  2.24756344  3.65160936  2.97617351  2.35026363
#   3.84956875  3.17794883  1.81971392  0.71179945  1.88077622 -0.06164258]
# Device time: 3.2165 seconds
# Iters. done: 194 [Current cost: -22.86114959870241]
# Current parameters: [ 3.04198446 -0.10833734  2.91514191  3.62558061  0.01015173  2.45337434
#   2.12147832  1.93803157  3.14788085  3.21221876  0.51581247  1.91280378
#   3.8571696   1.333576    2.24755308  3.65158742  2.97619937  2.35036367
#   3.8495557   3.17790328  1.81974784  0.71170808  1.88080772 -0.06164419]
# Device time: 3.1820 seconds
# Iters. done: 195 [Current cost: -22.824810185577437]
# Current parameters: [ 3.04200225 -0.10826609  2.91525608  3.62547264  0.00997048  2.45346442
#   2.12150577  1.93799766  3.14777517  3.21228677  0.51577823  1.91282188
#   3.8572388   1.33363986  2.24739042  3.65168993  2.97617967  2.35011814
#   3.84980104  3.17803253  1.81962303  0.7119786   1.88089714 -0.06169391]
# Device time: 3.1942 seconds
# Iters. done: 196 [Current cost: -22.865735658381222]
# Current parameters: [ 3.04194209 -0.10848022  2.91511491  3.62561406  0.01015458  2.45350468
#   2.12151428  1.93806949  3.1478639   3.21228494  0.51578102  1.91284533
#   3.85721606  1.33357196  2.24761044  3.65164382  2.97623767  2.35024977
#   3.84968934  3.17794509  1.81966386  0.71178845  1.88084799 -0.06154314]
# Device time: 3.1752 seconds
# Iters. done: 197 [Current cost: -22.838408713442256]
# Current parameters: [ 3.04174903 -0.10834573  2.91511284  3.62552846  0.01002753  2.45336418
#   2.12148378  1.93805638  3.14788169  3.21218892  0.51584431  1.91281614
#   3.85716713  1.33352457  2.24787687  3.65163902  2.97616109  2.35028417
#   3.8495968   3.17797786  1.819627    0.71199701  1.88080649 -0.06180113]
# Device time: 3.2465 seconds
# Iters. done: 198 [Current cost: -22.799876916455677]
# Current parameters: [ 3.04191957 -0.10845209  2.91516005  3.62560301  0.01019808  2.45339891
#   2.12145799  1.93800147  3.14787408  3.21232125  0.51577027  1.91278567
#   3.85721428  1.33359994  2.24754548  3.65146457  2.97620477  2.35029098
#   3.84965266  3.17799591  1.81962465  0.71182032  1.88087341 -0.06174987]
# Device time: 3.2727 seconds
# Iters. done: 199 [Current cost: -22.808103610469328]
# Current parameters: [ 3.04188239 -0.1084188   2.91510441  3.62552008  0.01016076  2.45332684
#   2.1214127   1.93812147  3.14785211  3.21218496  0.51569861  1.91311155
#   3.85720986  1.333424    2.24747136  3.6514656   2.97597477  2.35015861
#   3.84967158  3.17785635  1.81975902  0.71186329  1.88085819 -0.06158675]
# Device time: 3.2314 seconds
# Iters. done: 200 [Current cost: -22.876887871789066]
# Current parameters: [ 3.04185084 -0.10830483  2.91507345  3.62569941  0.01021613  2.45334862
#   2.12148685  1.9380249   3.14787367  3.21227827  0.51578264  1.91283965
#   3.85722931  1.33352534  2.24750935  3.65169782  2.97612343  2.35028318
#   3.84973954  3.17796519  1.81966108  0.71178363  1.88083711 -0.06168107]
# Device time: 3.3498 seconds
# Iters. done: 201 [Current cost: -22.838358324931907]
# Current parameters: [ 3.0419078  -0.10839238  2.91513266  3.62560547  0.0101417   2.45340159
#   2.12153296  1.93803993  3.1478755   3.21226222  0.51575904  1.91285678
#   3.85731667  1.3335684   2.24753907  3.65160845  2.97616674  2.35031406
#   3.84962485  3.17794693  1.81970019  0.71183937  1.88082604 -0.06167635]
# Device time: 3.2786 seconds
# Iters. done: 202 [Current cost: -22.841898045166253]
# Current parameters: [ 3.04190362 -0.10836498  2.91522129  3.62566539  0.01012141  2.45341025
#   2.12147619  1.938082    3.14796498  3.21239512  0.51571074  1.9128857
#   3.85715334  1.33357062  2.24750909  3.65165238  2.97614624  2.35033779
#   3.84959187  3.17788628  1.81967449  0.71191305  1.88082862 -0.06162889]
# Device time: 3.2651 seconds
# Iters. done: 203 [Current cost: -22.82896352690178]
# Current parameters: [ 3.0419345  -0.10838084  2.9151844   3.62560642  0.01015941  2.45338347
#   2.12149117  1.9379787   3.14788957  3.21231721  0.51575936  1.91286524
#   3.85723867  1.33358651  2.24760075  3.651619    2.97611147  2.35028655
#   3.8496527   3.17796063  1.81971078  0.7118169   1.88082856 -0.06164285]
# Device time: 3.2244 seconds
# Iters. done: 204 [Current cost: -22.85295539454083]
# Current parameters: [ 3.04185995 -0.10835988  2.91510295  3.62562916  0.01009679  2.45351207
#   2.12155649  1.93798115  3.14789975  3.21232374  0.51586658  1.91288046
#   3.85718078  1.33355572  2.24750661  3.65153596  2.97609575  2.35033346
#   3.84965718  3.17800234  1.81974435  0.71184194  1.88077227 -0.06163818]
# Device time: 3.2271 seconds

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -23.464443969849476
#        x: [ 3.175e+00  3.155e+00 ...  3.513e+00  1.032e+00]
#     nfev: 287
#    maxcv: 0.0

# %%
print(f"Best solution: {res.x}")
print(f"Best objective value: {res.fun}")
print(f"Number of function evaluations: {res.nfev}")
# Out:
# Best solution: [3.17482298 3.1551438  3.64955928 1.75823321 3.11576521 0.08255553
#  2.87634414 1.67324446 3.20432336 3.41102647 3.11938085 1.45082436
#  0.18599694 3.30449283 0.16657891 3.26276071 3.25724024 3.56776958
#  1.8383465  1.66824486 3.18368049 0.28080648 3.51315743 1.03153648]
# Best objective value: -23.464443969849476
# Number of function evaluations: 287

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -84.126219175835
#   - computed part:      -23.464443969849
#   - FreezeCoreTransformer extracted energy part: -60.661775205985
# ~ Nuclear repulsion energy (Hartree): 9.193913160623
# > Total ground state energy (Hartree): -74.932306015211
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [0.0  2.21475902  0.0]

# %%
from qiskit_algorithms import NumPyMinimumEigensolver


sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(hamiltonian)
result = problem.interpret(sol)
print(result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -84.171341371854
#   - computed part:      -23.509566165869
#   - FreezeCoreTransformer extracted energy part: -60.661775205985
# ~ Nuclear repulsion energy (Hartree): 9.193913160623
# > Total ground state energy (Hartree): -74.977428211231
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [0.0  2.21475902  0.0]

# %% [markdown]
# ## Step 4: Post-process, return result in classical format

# %% [markdown]
# If the procedure terminates correctly, then the `prev_vector` and `iters` values in our `cost_history_dict` dictionary should be equal to the solution vector and total number of function evaluations, respectively.  This is easy to verify:

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
