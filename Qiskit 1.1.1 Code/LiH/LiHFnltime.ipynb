# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import Aer
try:
    backend = Aer.get_backend('aer_simulator_statevector_gpu')
    backend.set_options(device='GPU')
    backend.set_options(cuStateVec_enable=False)
    print("GPU options set successfully." , backend)
except Exception as e:
    print(f"Failed to set GPU options: {e}")
# Out:
# GPU options set successfully. AerSimulator('aer_simulator_statevector_gpu')

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver

molecule = MoleculeInfo(
        # Coordinates in Angstrom
        symbols=["H", "H"],
        coords=([0.0, 0.0, 0.0], [1.6895640, 0.0, 0.0]),
        multiplicity=1,  # = 2*spin + 1
        charge=0,
    )


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, 
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['II', 'IZ', 'ZI', 'ZZ', 'XX'],
#               coeffs=[-0.97846545+0.j,  0.09735879+0.j, -0.09735879+0.j, -0.00287021+0.j,
#   0.24143891+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 3

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print("")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")
  

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
   
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([0.91175372, 1.02742005, 0.8131691 ])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
# Iters. done: 1 [Current cost: -0.8882882154251531]
# Current parameters: [1.91175372 1.02742005 0.8131691 ]
# Device time: 0.4096 seconds
#
# Iters. done: 2 [Current cost: -1.251220784439607]
# Current parameters: [1.91175372 2.02742005 0.8131691 ]
# Device time: 0.4018 seconds
#
# Iters. done: 3 [Current cost: -1.0471451382881511]
# Current parameters: [1.91175372 1.02742005 1.8131691 ]
# Device time: 0.4030 seconds
#
# Iters. done: 4 [Current cost: -0.9944935311352029]
# Current parameters: [2.65370699 0.61022246 0.28833435]
# Device time: 0.4011 seconds
#
# Iters. done: 5 [Current cost: -1.2047743785626908]
# Current parameters: [2.28273036 0.81882125 0.55075172]
# Device time: 0.4036 seconds
#
# Iters. done: 6 [Current cost: -1.24989806481912]
# Current parameters: [1.74303965 0.91262033 0.668751  ]
# Device time: 0.4088 seconds
#
# Iters. done: 7 [Current cost: -1.1737297671084017]
# Current parameters: [1.91175372 1.12527102 0.73538616]
# Device time: 0.4050 seconds
#
# Iters. done: 8 [Current cost: -1.2453746384695377]
# Current parameters: [2.07591976 1.11323187 0.9810555 ]
# Device time: 0.4845 seconds
#
# Iters. done: 9 [Current cost: -1.2578636145243662]
# Current parameters: [2.10371534 1.04841717 1.08426141]
# Device time: 0.4012 seconds
#
# Iters. done: 10 [Current cost: -1.227978316943762]
# Current parameters: [2.02962169 1.1420281  1.01160898]
# Device time: 0.4043 seconds
#
# Iters. done: 11 [Current cost: -1.265091667897484]
# Current parameters: [2.0193696  1.26143344 0.97608069]
# Device time: 0.4035 seconds
#
# Iters. done: 12 [Current cost: -1.2682449223658945]
# Current parameters: [1.96806454 1.25064982 0.94205489]
# Device time: 0.4018 seconds
#
# Iters. done: 13 [Current cost: -1.2678269075116733]
# Current parameters: [2.00155644 1.2673389  1.00106828]
# Device time: 0.4008 seconds
#
# Iters. done: 14 [Current cost: -1.269752833212244]
# Current parameters: [1.97554284 1.30715073 1.04162146]
# Device time: 0.4075 seconds
#
# Iters. done: 15 [Current cost: -1.266682308761642]
# Current parameters: [1.99924635 1.23957916 1.01523241]
# Device time: 0.4038 seconds
#
# Iters. done: 16 [Current cost: -1.2696916378926664]
# Current parameters: [1.98762881 1.26507392 0.99435771]
# Device time: 0.4061 seconds
#
# Iters. done: 17 [Current cost: -1.2697504322447153]
# Current parameters: [2.01569363 1.25480786 0.976175  ]
# Device time: 0.4084 seconds
#
# Iters. done: 18 [Current cost: -1.2660942330145304]
# Current parameters: [1.99460728 1.27438151 1.01316172]
# Device time: 0.4057 seconds
#
# Iters. done: 19 [Current cost: -1.26126888768537]
# Current parameters: [2.00505431 1.26395987 0.99495418]
# Device time: 0.4023 seconds
#
# Iters. done: 20 [Current cost: -1.2661756472690655]
# Current parameters: [2.0018389  1.27081498 0.99930877]
# Device time: 0.4107 seconds
#
# Iters. done: 21 [Current cost: -1.2641156777368896]
# Current parameters: [1.99996142 1.26173442 1.0062722 ]
# Device time: 0.4067 seconds
#
# Iters. done: 22 [Current cost: -1.2651929993598803]
# Current parameters: [2.00089467 1.27118794 1.00114421]
# Device time: 0.4106 seconds
#
# Iters. done: 23 [Current cost: -1.266246980784056]
# Current parameters: [2.00329709 1.26762161 1.00190786]
# Device time: 0.4060 seconds
#
# Iters. done: 24 [Current cost: -1.2679472203157396]
# Current parameters: [1.99893956 1.26474503 1.00236541]
# Device time: 0.4060 seconds
#
# Iters. done: 25 [Current cost: -1.2648075191995507]
# Current parameters: [2.00197744 1.26697295 0.9991965 ]
# Device time: 0.4007 seconds
#
# Iters. done: 26 [Current cost: -1.2635020853391916]
# Current parameters: [2.00100603 1.26701221 1.00180584]
# Device time: 0.4049 seconds
#
# Iters. done: 27 [Current cost: -1.2680301368049338]
# Current parameters: [2.00130136 1.26828094 1.00110239]
# Device time: 0.4045 seconds
#
# Iters. done: 28 [Current cost: -1.2676825579976874]
# Current parameters: [2.00198603 1.26735591 1.00129975]
# Device time: 0.3932 seconds
#
# Iters. done: 29 [Current cost: -1.2709750163006968]
# Current parameters: [2.00243199 1.26717194 1.0012243 ]
# Device time: 0.4052 seconds
#
# Iters. done: 30 [Current cost: -1.2654619426680211]
# Current parameters: [2.00204672 1.26755522 1.00117248]
# Device time: 0.4046 seconds
#
# Iters. done: 31 [Current cost: -1.2652991730738203]
# Current parameters: [2.00180392 1.26722456 1.00173335]
# Device time: 0.4034 seconds
#
# Iters. done: 32 [Current cost: -1.2695086174258419]
# Current parameters: [2.00198056 1.26759667 1.00133987]
# Device time: 0.4090 seconds
#
# Iters. done: 33 [Current cost: -1.2652978713788232]
# Current parameters: [2.0020166  1.26726506 1.00127126]
# Device time: 0.4025 seconds
#
# Iters. done: 34 [Current cost: -1.2661033823124863]
# Current parameters: [2.00203054 1.26736423 1.00132097]
# Device time: 0.4049 seconds
#
# Iters. done: 35 [Current cost: -1.2629279569829346]
# Current parameters: [2.00189393 1.26736835 1.00126283]
# Device time: 0.4128 seconds
#
# Iters. done: 36 [Current cost: -1.268941586748431]
# Current parameters: [2.0020054  1.26737551 1.00125803]
# Device time: 0.4658 seconds
#
# Iters. done: 37 [Current cost: -1.2646924534121318]
# Current parameters: [2.00196288 1.26735605 1.00139704]
# Device time: 0.4024 seconds
#
# Iters. done: 38 [Current cost: -1.268555030603717]
# Current parameters: [2.00196288 1.26735605 1.00139704]
# Device time: 0.4072 seconds
#
# Total time: 15.5444962978 seconds
# Total device time: 15.5238475800 seconds
# Total classical optimizer time 0.0206487179

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
# !nvidia-smi
# Out:
# Thu Oct  3 14:46:40 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-PCIE-40GB          Off |   00000000:3B:00.0 Off |                    0 |
# | N/A   34C    P0             36W /  250W |    7762MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1662134      C   python                                       7332MiB |
# |    0   N/A  N/A   2516655      C   ...iniconda3/envs/qiskit1.1/bin/python        416MiB |
# +-----------------------------------------------------------------------------------------+

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -1.268555030603717
#        x: [ 2.002e+00  1.267e+00  1.001e+00]
#     nfev: 38
#    maxcv: 0.0

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -1.268555030604
#   - computed part:      -1.268555030604
#   - FreezeCoreTransformer extracted energy part: 0.0
# ~ Nuclear repulsion energy (Hartree): 0.313203412786
# > Total ground state energy (Hartree): -0.955351617818
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.19281323  0.0  0.0]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
