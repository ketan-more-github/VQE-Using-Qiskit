# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import qiskit
print(qiskit.__version__)
# Out:
# 1.1.1

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import Aer
print(Aer.backends())
try:
    backend = Aer.get_backend('aer_simulator_statevector')
    backend.set_options(device='CPU')

    print("CPU options set successfully." , backend)
except Exception as e:
    print(f"Failed to set CPU options: {e}")
# Out:
# [AerSimulator('aer_simulator'), AerSimulator('aer_simulator'), AerSimulator('aer_simulator_statevector'), AerSimulator('aer_simulator_statevector_gpu'), AerSimulator('aer_simulator_density_matrix'), AerSimulator('aer_simulator_density_matrix_gpu'), AerSimulator('aer_simulator_stabilizer'), AerSimulator('aer_simulator_matrix_product_state'), AerSimulator('aer_simulator_extended_stabilizer'), AerSimulator('aer_simulator_unitary'), AerSimulator('aer_simulator_unitary_gpu'), AerSimulator('aer_simulator_superop'), AerSimulator('aer_simulator_tensor_network_gpu'), QasmSimulator('qasm_simulator'), StatevectorSimulator('statevector_simulator'), UnitarySimulator('unitary_simulator')]
# CPU options set successfully. AerSimulator('aer_simulator_statevector')

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver


molecule = MoleculeInfo(
        # Coordinates in Angstrom
        symbols=["Li", "H"],
        coords=([0.0, 0.0, 0.0], [1.5109, 0.0, 0.0]),
        multiplicity=1,  # = 2*spin + 1
        charge=0,
    )


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, remove_orbitals=[3,4,5,6] 
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['II', 'IZ', 'IX', 'ZI', 'XI', 'ZZ', 'XZ', 'ZX', 'XX'],
#               coeffs=[-0.82641018+0.j,  0.17369962+0.j,  0.02670817+0.j, -0.17369962+0.j,
#   0.02670817+0.j, -0.09492172+0.j,  0.02670816+0.j, -0.02670816+0.j,
#   0.01223207+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 3

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(" ")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([2.37408903, 0.37821807, 2.12037811])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
#
# Iters. done: 1 [Current cost: -0.6378276340210977]
# Current parameters: [3.37408903 0.37821807 2.12037811]
# Device time: 0.4475 seconds
#
# Iters. done: 2 [Current cost: -0.7368734239148417]
# Current parameters: [3.37408903 1.37821807 2.12037811]
# Device time: 0.4449 seconds
#
# Iters. done: 3 [Current cost: -0.9385375828990067]
# Current parameters: [3.37408903 1.37821807 3.12037811]
# Device time: 0.3795 seconds
#
# Iters. done: 4 [Current cost: -0.8761788550470411]
# Current parameters: [3.79887277 2.24310749 1.85293642]
# Device time: 0.4246 seconds
#
# Iters. done: 5 [Current cost: -0.7234860232441607]
# Current parameters: [2.88584602 1.48119747 2.08853475]
# Device time: 0.4188 seconds
#
# Iters. done: 6 [Current cost: -0.9246799181106232]
# Current parameters: [3.35356438 1.13607621 2.06167498]
# Device time: 0.3864 seconds
#
# Iters. done: 7 [Current cost: -0.932400403332559]
# Current parameters: [3.36025768 1.35005646 2.24137653]
# Device time: 0.4509 seconds
#
# Iters. done: 8 [Current cost: -0.9370284425842983]
# Current parameters: [3.57873759 1.52045553 2.10069384]
# Device time: 0.4580 seconds
#
# Iters. done: 9 [Current cost: -0.9081914303881231]
# Current parameters: [3.25378218 1.40871636 2.10550815]
# Device time: 0.4302 seconds
#
# Iters. done: 10 [Current cost: -0.9313662777207619]
# Current parameters: [3.43381141 1.39663901 2.11998342]
# Device time: 0.4122 seconds
#
# Iters. done: 11 [Current cost: -0.9380719980544577]
# Current parameters: [3.38841783 1.31997001 2.10282534]
# Device time: 0.5364 seconds
#
# Iters. done: 12 [Current cost: -0.9426589461835827]
# Current parameters: [3.39847758 1.26307142 2.07900094]
# Device time: 0.4627 seconds
#
# Iters. done: 13 [Current cost: -0.9415802520309559]
# Current parameters: [3.38564317 1.32832323 2.07284056]
# Device time: 0.3946 seconds
#
# Iters. done: 14 [Current cost: -0.9416341849364206]
# Current parameters: [3.40048961 1.2596492  2.11386715]
# Device time: 0.4165 seconds
#
# Iters. done: 15 [Current cost: -0.9488930913289294]
# Current parameters: [3.43168936 1.20553536 2.11599289]
# Device time: 0.3865 seconds
#
# Iters. done: 16 [Current cost: -0.9499358340414049]
# Current parameters: [3.3796601  1.17107028 2.11936396]
# Device time: 0.4013 seconds
#
# Iters. done: 17 [Current cost: -0.942408851137559]
# Current parameters: [3.43140549 1.2090015  2.14704878]
# Device time: 0.4163 seconds
#
# Iters. done: 18 [Current cost: -0.953509813743359]
# Current parameters: [3.48064703 1.21093278 2.18549082]
# Device time: 0.4510 seconds
#
# Iters. done: 19 [Current cost: -0.958330791697712]
# Current parameters: [3.48559093 1.26749547 2.21161493]
# Device time: 0.4551 seconds
#
# Iters. done: 20 [Current cost: -0.9482444428850721]
# Current parameters: [3.47985222 1.15695934 2.21699457]
# Device time: 0.4641 seconds
#
# Iters. done: 21 [Current cost: -0.9611992846566488]
# Current parameters: [3.5259908  1.12710881 2.18722163]
# Device time: 0.4489 seconds
#
# Iters. done: 22 [Current cost: -0.9648799201995032]
# Current parameters: [3.57892745 1.10152849 2.2084256 ]
# Device time: 0.4198 seconds
#
# Iters. done: 23 [Current cost: -0.9725525654411974]
# Current parameters: [3.63238384 1.09338913 2.2397691 ]
# Device time: 0.4022 seconds
#
# Iters. done: 24 [Current cost: -0.9799156064844021]
# Current parameters: [3.68747248 1.07992101 2.26603888]
# Device time: 0.3974 seconds
#
# Iters. done: 25 [Current cost: -0.9768589125816111]
# Current parameters: [3.61994591 1.06886329 2.25461308]
# Device time: 0.3937 seconds
#
# Iters. done: 26 [Current cost: -0.9756851739522442]
# Current parameters: [3.6877023  1.12197923 2.23440963]
# Device time: 0.4286 seconds
#
# Iters. done: 27 [Current cost: -0.9719539689266281]
# Current parameters: [3.64140363 1.07201257 2.21883472]
# Device time: 0.4315 seconds
#
# Iters. done: 28 [Current cost: -0.9745312621950992]
# Current parameters: [3.62043007 1.07663385 2.29878281]
# Device time: 0.4163 seconds
#
# Iters. done: 29 [Current cost: -0.9707343440573738]
# Current parameters: [3.64784445 1.12052101 2.23858892]
# Device time: 0.4815 seconds
#
# Iters. done: 30 [Current cost: -0.9759675360464597]
# Current parameters: [3.61830748 1.09795761 2.23475653]
# Device time: 0.4153 seconds
#
# Iters. done: 31 [Current cost: -0.9726547603768176]
# Current parameters: [3.63741282 1.08781382 2.25347187]
# Device time: 0.3800 seconds
#
# Iters. done: 32 [Current cost: -0.9713043985673818]
# Current parameters: [3.63620279 1.09018489 2.23375382]
# Device time: 0.3831 seconds
#
# Iters. done: 33 [Current cost: -0.9755538977540212]
# Current parameters: [3.63581636 1.10040595 2.23990008]
# Device time: 0.3852 seconds
#
# Iters. done: 34 [Current cost: -0.9765246161806775]
# Current parameters: [3.63238282 1.09162655 2.24325509]
# Device time: 0.4141 seconds
#
# Iters. done: 35 [Current cost: -0.9757582415637168]
# Current parameters: [3.62890173 1.09432017 2.23826348]
# Device time: 0.4181 seconds
#
# Iters. done: 36 [Current cost: -0.9706730198537156]
# Current parameters: [3.63380013 1.0924924  2.23876676]
# Device time: 0.4225 seconds
#
# Iters. done: 37 [Current cost: -0.9750103503911353]
# Current parameters: [3.6331437  1.09508447 2.2403717 ]
# Device time: 0.4516 seconds
#
# Iters. done: 38 [Current cost: -0.9758711372007514]
# Current parameters: [3.63144299 1.09338508 2.23950745]
# Device time: 0.4541 seconds
#
# Iters. done: 39 [Current cost: -0.9760628530165172]
# Current parameters: [3.63243384 1.09290169 2.24061384]
# Device time: 0.4324 seconds
#
# Iters. done: 40 [Current cost: -0.9758902796456728]
# Current parameters: [3.63269549 1.09324864 2.23942046]
# Device time: 0.3811 seconds
#
# Iters. done: 41 [Current cost: -0.9750254185532569]
# Current parameters: [3.6324269  1.09384883 2.23992798]
# Device time: 0.4108 seconds
#
# Iters. done: 42 [Current cost: -0.9782559053864458]
# Current parameters: [3.6323756  1.09327136 2.2399828 ]
# Device time: 0.3949 seconds
#
# Iters. done: 43 [Current cost: -0.9716029519583097]
# Current parameters: [3.63218888 1.0934403  2.23963134]
# Device time: 0.3901 seconds
#
# Iters. done: 44 [Current cost: -0.9741223205597432]
# Current parameters: [3.63246825 1.09339416 2.23971573]
# Device time: 0.4208 seconds
#
# Iters. done: 45 [Current cost: -0.9748417190218435]
# Current parameters: [3.63239633 1.09343133 2.23979284]
# Device time: 0.4277 seconds
#
# Iters. done: 46 [Current cost: -0.9758439521232024]
# Current parameters: [3.63230269 1.09336104 2.23971786]
# Device time: 0.4885 seconds
#
# Iters. done: 47 [Current cost: -0.976399949820788]
# Current parameters: [3.63239638 1.09330791 2.23982607]
# Device time: 0.3843 seconds
#
# Iters. done: 48 [Current cost: -0.9775806481862577]
# Current parameters: [3.63239638 1.09330791 2.23982607]
# Device time: 0.3973 seconds
#
# Total time: 20.3357744217 seconds
# Total device time: 20.3089692593 seconds
# Total classical optimizer time 0.0268051624

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -0.9775806481862577
#        x: [ 3.632e+00  1.093e+00  2.240e+00]
#     nfev: 48
#    maxcv: 0.0

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.812794267872
#   - computed part:      -0.977580648186
#   - FreezeCoreTransformer extracted energy part: -7.835213619686
# ~ Nuclear repulsion energy (Hartree): 1.050719195685
# > Total ground state energy (Hartree): -7.762075072187
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8551872  0.0  0.0]

# %%
from qiskit_algorithms import NumPyMinimumEigensolver


sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(hamiltonian)
result = problem.interpret(sol)
print(result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.914327525084
#   - computed part:      -1.079113905398
#   - FreezeCoreTransformer extracted energy part: -7.835213619686
# ~ Nuclear repulsion energy (Hartree): 1.050719195685
# > Total ground state energy (Hartree): -7.863608329399
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8551872  0.0  0.0]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
