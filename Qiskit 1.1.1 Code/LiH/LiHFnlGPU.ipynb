# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import Aer
from qiskit_ibm_runtime import QiskitRuntimeService, Session
try:
    backend = Aer.get_backend('aer_simulator_statevector_gpu')
    backend.set_options(device='GPU')
    backend.set_options(cuStateVec_enable=False)
    print("GPU options set successfully." , backend)
except Exception as e:
    print(f"Failed to set GPU options: {e}")
# Out:
# GPU options set successfully. AerSimulator('aer_simulator_statevector_gpu')

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver

molecule = MoleculeInfo(
        # Coordinates in Angstrom
        symbols=["Li", "H"],
        coords=([0.0, 0.0, 0.0], [1.5109, 0.0, 0.0]),
        multiplicity=1,  # = 2*spin + 1
        charge=0,
    )


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, remove_orbitals=[3,4,5,6]
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['II', 'IZ', 'IX', 'ZI', 'XI', 'ZZ', 'XZ', 'ZX', 'XX'],
#               coeffs=[-0.82641018+0.j,  0.17369962+0.j,  0.02670817+0.j, -0.17369962+0.j,
#   0.02670817+0.j, -0.09492172+0.j,  0.02670816+0.j, -0.02670816+0.j,
#   0.01223207+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 3

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(" ")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([1.26633462, 1.27459646, 2.42285584])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
#
# Iters. done: 1 [Current cost: -0.7291148505078487]
# Current parameters: [2.26633462 1.27459646 2.42285584]
# Device time: 0.4610 seconds
#
# Iters. done: 2 [Current cost: -0.7221628526245302]
# Current parameters: [1.26633462 2.27459646 2.42285584]
# Device time: 0.4669 seconds
#
# Iters. done: 3 [Current cost: -0.7228445395909838]
# Current parameters: [1.26633462 1.27459646 3.42285584]
# Device time: 0.4580 seconds
#
# Iters. done: 4 [Current cost: -0.43461546415159424]
# Current parameters: [1.24274038 1.25331579 1.42336074]
# Device time: 0.4831 seconds
#
# Iters. done: 5 [Current cost: -1.034093692033882]
# Current parameters: [1.21994538 1.23275598 0.42383201]
# Device time: 0.4636 seconds
#
# Iters. done: 6 [Current cost: -0.6024675506001457]
# Current parameters: [0.91923643 0.93010888 1.62555492]
# Device time: 0.4977 seconds
#
# Iters. done: 7 [Current cost: -0.9651161811159725]
# Current parameters: [1.4193147  1.07633737 1.42297419]
# Device time: 0.4814 seconds
#
# Iters. done: 8 [Current cost: -1.0308930888469376]
# Current parameters: [1.45585079 1.48183446 1.81369799]
# Device time: 0.5269 seconds
#
# Iters. done: 9 [Current cost: -1.0276199782154793]
# Current parameters: [1.35437631 1.39575574 1.25088384]
# Device time: 0.4358 seconds
#
# Iters. done: 10 [Current cost: -1.0075422064823685]
# Current parameters: [1.15787718 1.18888565 1.48872124]
# Device time: 0.4416 seconds
#
# Iters. done: 11 [Current cost: -1.0230927136035692]
# Current parameters: [1.21939976 1.23014454 1.37021417]
# Device time: 0.4592 seconds
#
# Iters. done: 12 [Current cost: -1.012412861193014]
# Current parameters: [1.3036263  1.32017761 1.50965908]
# Device time: 0.4911 seconds
#
# Iters. done: 13 [Current cost: -1.0564953062111742]
# Current parameters: [1.25902024 1.27860035 1.61877659]
# Device time: 0.4568 seconds
#
# Iters. done: 14 [Current cost: -1.0564000255731445]
# Current parameters: [1.25865193 1.36353754 1.50779556]
# Device time: 0.4989 seconds
#
# Iters. done: 15 [Current cost: -1.0574622792229278]
# Current parameters: [1.32555481 1.4504945  1.56769123]
# Device time: 0.4684 seconds
#
# Iters. done: 16 [Current cost: -1.0700369920017878]
# Current parameters: [1.38567081 1.54301483 1.62643692]
# Device time: 0.4397 seconds
#
# Iters. done: 17 [Current cost: -1.07014225156042]
# Current parameters: [1.3356831  1.57995042 1.61986104]
# Device time: 0.4377 seconds
#
# Iters. done: 18 [Current cost: -1.0661491420514433]
# Current parameters: [1.3967837  1.55317987 1.59905557]
# Device time: 0.4499 seconds
#
# Iters. done: 19 [Current cost: -1.071792616666866]
# Current parameters: [1.44985303 1.53825184 1.56960985]
# Device time: 0.4830 seconds
#
# Iters. done: 20 [Current cost: -1.0764241845463107]
# Current parameters: [1.5012616  1.52726785 1.5358051 ]
# Device time: 0.4798 seconds
#
# Iters. done: 21 [Current cost: -1.078300543697926]
# Current parameters: [1.48812721 1.56607212 1.48860376]
# Device time: 0.4915 seconds
#
# Iters. done: 22 [Current cost: -1.0740527706045357]
# Current parameters: [1.51602202 1.55041832 1.55072985]
# Device time: 0.4992 seconds
#
# Iters. done: 23 [Current cost: -1.0781838714591654]
# Current parameters: [1.53780275 1.48347565 1.56136361]
# Device time: 0.4767 seconds
#
# Iters. done: 24 [Current cost: -1.076245665497776]
# Current parameters: [1.51953217 1.50537175 1.54858436]
# Device time: 0.4505 seconds
#
# Iters. done: 25 [Current cost: -1.0775673513936073]
# Current parameters: [1.50475298 1.53261595 1.52154506]
# Device time: 0.4520 seconds
#
# Iters. done: 26 [Current cost: -1.0779084736769378]
# Current parameters: [1.48739721 1.53026672 1.54235692]
# Device time: 0.4500 seconds
#
# Iters. done: 27 [Current cost: -1.0790532348396353]
# Current parameters: [1.47355097 1.53318987 1.54898092]
# Device time: 0.5453 seconds
#
# Iters. done: 28 [Current cost: -1.0771541538579172]
# Current parameters: [1.48449216 1.52373882 1.53919742]
# Device time: 0.4809 seconds
#
# Iters. done: 29 [Current cost: -1.0774695735087392]
# Current parameters: [1.48985086 1.5436499  1.55003877]
# Device time: 0.4601 seconds
#
# Iters. done: 30 [Current cost: -1.0776784478436567]
# Current parameters: [1.48181383 1.52499487 1.54091868]
# Device time: 0.4619 seconds
#
# Iters. done: 31 [Current cost: -1.0783681614659708]
# Current parameters: [1.48848538 1.52825103 1.54552104]
# Device time: 0.4603 seconds
#
# Iters. done: 32 [Current cost: -1.0782821328582697]
# Current parameters: [1.4913738  1.53095053 1.53566705]
# Device time: 0.4446 seconds
#
# Iters. done: 33 [Current cost: -1.077036653582865]
# Current parameters: [1.4851307  1.53327785 1.54338393]
# Device time: 0.4376 seconds
#
# Iters. done: 34 [Current cost: -1.0774272580795008]
# Current parameters: [1.48858605 1.5298526  1.54086364]
# Device time: 0.4691 seconds
#
# Iters. done: 35 [Current cost: -1.0788727320947233]
# Current parameters: [1.48606291 1.52896883 1.54176545]
# Device time: 0.4816 seconds
#
# Iters. done: 36 [Current cost: -1.0787144415765644]
# Current parameters: [1.4872286  1.53122753 1.54231123]
# Device time: 0.4787 seconds
#
# Iters. done: 37 [Current cost: -1.0782560958670375]
# Current parameters: [1.48787454 1.52970017 1.5429932 ]
# Device time: 0.4554 seconds
#
# Iters. done: 38 [Current cost: -1.0766714936574626]
# Current parameters: [1.4870112  1.53010064 1.54210826]
# Device time: 0.4653 seconds
#
# Iters. done: 39 [Current cost: -1.078141593442193]
# Current parameters: [1.48771713 1.53027512 1.54198813]
# Device time: 0.4652 seconds
#
# Iters. done: 40 [Current cost: -1.0787378010388187]
# Current parameters: [1.48738588 1.53050763 1.54239486]
# Device time: 0.4541 seconds
#
# Iters. done: 41 [Current cost: -1.078467714394544]
# Current parameters: [1.48751096 1.53010674 1.54250208]
# Device time: 0.4525 seconds
#
# Iters. done: 42 [Current cost: -1.0776457643013178]
# Current parameters: [1.48745642 1.53027215 1.54227651]
# Device time: 0.4791 seconds
#
# Iters. done: 43 [Current cost: -1.0784582410301795]
# Current parameters: [1.48737175 1.53022931 1.54233564]
# Device time: 0.4653 seconds
#
# Iters. done: 44 [Current cost: -1.078688032977073]
# Current parameters: [1.4873603  1.53035048 1.54239718]
# Device time: 0.4754 seconds
#
# Iters. done: 45 [Current cost: -1.0781270580510791]
# Current parameters: [1.48745688 1.53022225 1.54242371]
# Device time: 0.4393 seconds
#
# Iters. done: 46 [Current cost: -1.0776080940199235]
# Current parameters: [1.48745688 1.53022225 1.54242371]
# Device time: 0.4565 seconds
#
# Total time: 21.5552394390 seconds
# Total device time: 21.5289766788 seconds
# Total classical optimizer time 0.0262627602

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -1.0776080940199235
#        x: [ 1.487e+00  1.530e+00  1.542e+00]
#     nfev: 46
#    maxcv: 0.0

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.912821713706
#   - computed part:      -1.07760809402
#   - FreezeCoreTransformer extracted energy part: -7.835213619686
# ~ Nuclear repulsion energy (Hartree): 1.050719195685
# > Total ground state energy (Hartree): -7.862102518021
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8551872  0.0  0.0]

# %%
from qiskit_algorithms import NumPyMinimumEigensolver


sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(hamiltonian)
result = problem.interpret(sol)
print(result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.914327525084
#   - computed part:      -1.079113905398
#   - FreezeCoreTransformer extracted energy part: -7.835213619686
# ~ Nuclear repulsion energy (Hartree): 1.050719195685
# > Total ground state energy (Hartree): -7.863608329399
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8551872  0.0  0.0]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
