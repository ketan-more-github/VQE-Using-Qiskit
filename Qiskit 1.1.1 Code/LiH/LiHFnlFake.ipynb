# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_ibm_runtime.fake_provider import FakeAlmadenV2
from qiskit_aer import QasmSimulator
# backend = QasmSimulator()
backend = FakeAlmadenV2()

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver

molecule = MoleculeInfo(
        # Coordinates in Angstrom
        symbols=["Li", "H"],
        coords=([0.0, 0.0, 0.0], [1.5109, 0.0, 0.0]),
        multiplicity=1,  # = 2*spin + 1
        charge=0,
    )


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, remove_orbitals=[3,4,5,6]
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['II', 'IZ', 'ZI', 'ZZ', 'XI', 'XZ', 'IX', 'ZX', 'XX'],
#               coeffs=[-0.82641018+0.j,  0.17369962+0.j, -0.17369962+0.j, -0.09492172+0.j,
#   0.02670817+0.j,  0.02670816+0.j,  0.02670817+0.j, -0.02670816+0.j,
#   0.01223207+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 3

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(" ")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([0.32667843, 1.64503762, 1.00947847])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    print(f"Current parameters: {xk}")
    print(f"Device time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
#
# Iters. done: 1 [Current cost: -0.9130069109214813]
# Current parameters: [1.32667843 1.64503762 1.00947847]
# Device time: 1.7987 seconds
#
# Iters. done: 2 [Current cost: -0.9014165212247616]
# Current parameters: [0.32667843 2.64503762 1.00947847]
# Device time: 1.6858 seconds
#
# Iters. done: 3 [Current cost: -0.7504192059833252]
# Current parameters: [0.32667843 1.64503762 2.00947847]
# Device time: 1.8704 seconds
#
# Iters. done: 4 [Current cost: -0.8661431873205464]
# Current parameters: [0.25834023 0.68640282 0.73316485]
# Device time: 1.7069 seconds
#
# Iters. done: 5 [Current cost: -0.7888290895276433]
# Current parameters: [0.29250933 1.16572022 0.87132166]
# Device time: 1.9085 seconds
#
# Iters. done: 6 [Current cost: -0.8364279068618556]
# Current parameters: [0.31064037 1.88594762 0.94463135]
# Device time: 1.7244 seconds
#
# Iters. done: 7 [Current cost: -0.9120087620250916]
# Current parameters: [0.20533452 1.64503762 1.03948938]
# Device time: 1.7355 seconds
#
# Iters. done: 8 [Current cost: -0.9022514422881346]
# Current parameters: [0.45033282 1.70603434 1.21801861]
# Device time: 1.8490 seconds
#
# Iters. done: 9 [Current cost: -0.9263809502395003]
# Current parameters: [0.69883902 1.7178653  1.24260915]
# Device time: 1.6740 seconds
#
# Iters. done: 10 [Current cost: -0.9582683895910254]
# Current parameters: [0.94758713 1.71976336 1.21769379]
# Device time: 1.8483 seconds
#
# Iters. done: 11 [Current cost: -0.9803172989263973]
# Current parameters: [1.17344968 1.75220403 1.31983935]
# Device time: 1.9393 seconds
#
# Iters. done: 12 [Current cost: -1.0149004880586612]
# Current parameters: [1.31514693 1.91045574 1.45166607]
# Device time: 1.6474 seconds
#
# Iters. done: 13 [Current cost: -1.029339851091763]
# Current parameters: [1.43386914 1.76816141 1.61946762]
# Device time: 1.7278 seconds
#
# Iters. done: 14 [Current cost: -1.0360292422606923]
# Current parameters: [1.65600638 1.76607941 1.50479107]
# Device time: 1.8227 seconds
#
# Iters. done: 15 [Current cost: -1.0390903950401498]
# Current parameters: [1.8011058  1.8839626  1.67077213]
# Device time: 1.9574 seconds
#
# Iters. done: 16 [Current cost: -1.0293284351027125]
# Current parameters: [1.66408046 1.64566643 1.47222538]
# Device time: 1.6582 seconds
#
# Iters. done: 17 [Current cost: -1.0438765759802335]
# Current parameters: [1.65367871 1.56116232 1.38070566]
# Device time: 2.0599 seconds
#
# Iters. done: 18 [Current cost: -1.0315870701255245]
# Current parameters: [1.72445225 1.65353527 1.45809813]
# Device time: 1.6585 seconds
#
# Iters. done: 19 [Current cost: -1.0378749245892853]
# Current parameters: [1.64930311 1.59489176 1.58548862]
# Device time: 1.9705 seconds
#
# Iters. done: 20 [Current cost: -1.0494638312417497]
# Current parameters: [1.54136796 1.53462111 1.60399406]
# Device time: 1.6648 seconds
#
# Iters. done: 21 [Current cost: -1.0464310830020496]
# Current parameters: [1.63090226 1.64652699 1.61551296]
# Device time: 1.7784 seconds
#
# Iters. done: 22 [Current cost: -1.0472533594571785]
# Current parameters: [1.69401891 1.56176756 1.61394095]
# Device time: 1.8381 seconds
#
# Iters. done: 23 [Current cost: -1.045675803679438]
# Current parameters: [1.62272153 1.57855135 1.58376439]
# Device time: 1.7954 seconds
#
# Iters. done: 24 [Current cost: -1.0505634026624433]
# Current parameters: [1.61155611 1.57706358 1.55461508]
# Device time: 1.8235 seconds
#
# Iters. done: 25 [Current cost: -1.0511326349816907]
# Current parameters: [1.60119145 1.5486762  1.54665938]
# Device time: 1.6982 seconds
#
# Iters. done: 26 [Current cost: -1.049951092216521]
# Current parameters: [1.5875214  1.59685593 1.55729052]
# Device time: 1.7925 seconds
#
# Iters. done: 27 [Current cost: -1.0480925430100094]
# Current parameters: [1.62525309 1.57851443 1.54723752]
# Device time: 1.6447 seconds
#
# Iters. done: 28 [Current cost: -1.047531658196273]
# Current parameters: [1.60824394 1.57010326 1.55588734]
# Device time: 1.6746 seconds
#
# Iters. done: 29 [Current cost: -1.0502902174571558]
# Current parameters: [1.61342594 1.57679882 1.55803449]
# Device time: 1.7559 seconds
#
# Iters. done: 30 [Current cost: -1.048160680435727]
# Current parameters: [1.60616631 1.57985478 1.54969629]
# Device time: 1.7333 seconds
#
# Iters. done: 31 [Current cost: -1.0488841705300658]
# Current parameters: [1.6139374  1.57561432 1.55187868]
# Device time: 1.8302 seconds
#
# Iters. done: 32 [Current cost: -1.0499891971647757]
# Current parameters: [1.61061195 1.57536313 1.55479328]
# Device time: 1.5993 seconds
#
# Iters. done: 33 [Current cost: -1.0506938993841222]
# Current parameters: [1.61025423 1.57819892 1.55370359]
# Device time: 1.7377 seconds
#
# Iters. done: 34 [Current cost: -1.0471152431609572]
# Current parameters: [1.61224025 1.5766748  1.55403673]
# Device time: 1.5955 seconds
#
# Iters. done: 35 [Current cost: -1.0517747545834322]
# Current parameters: [1.61299609 1.57642892 1.5546041 ]
# Device time: 1.9722 seconds
#
# Iters. done: 36 [Current cost: -1.0519076641010692]
# Current parameters: [1.6131907  1.57687165 1.55453671]
# Device time: 1.6343 seconds
#
# Iters. done: 37 [Current cost: -1.0486370011978239]
# Current parameters: [1.61267018 1.57551105 1.5546745 ]
# Device time: 1.6933 seconds
#
# Iters. done: 38 [Current cost: -1.048335000612422]
# Current parameters: [1.61324215 1.57683239 1.55448126]
# Device time: 1.8324 seconds
#
# Iters. done: 39 [Current cost: -1.0519247999274857]
# Current parameters: [1.61314035 1.57695148 1.55466849]
# Device time: 1.6837 seconds
#
# Iters. done: 40 [Current cost: -1.0499539863374672]
# Current parameters: [1.61345297 1.57659369 1.55411113]
# Device time: 1.7674 seconds
#
# Iters. done: 41 [Current cost: -1.0485008420897968]
# Current parameters: [1.6134251  1.57676565 1.55462851]
# Device time: 1.6613 seconds
#
# Iters. done: 42 [Current cost: -1.0516001131033086]
# Current parameters: [1.61296911 1.57709548 1.55478891]
# Device time: 1.7739 seconds
#
# Iters. done: 43 [Current cost: -1.0495339787981741]
# Current parameters: [1.61310563 1.57696394 1.55463508]
# Device time: 1.6192 seconds
#
# Iters. done: 44 [Current cost: -1.049628333283739]
# Current parameters: [1.61327485 1.57678755 1.55439807]
# Device time: 1.8193 seconds
#
# Iters. done: 45 [Current cost: -1.05180193183488]
# Current parameters: [1.61326833 1.57687333 1.55446948]
# Device time: 1.6527 seconds
#
# Iters. done: 46 [Current cost: -1.051648766835525]
# Current parameters: [1.61331001 1.57678533 1.55453766]
# Device time: 1.8351 seconds
#
# Iters. done: 47 [Current cost: -1.0476070257007937]
# Current parameters: [1.6131568  1.57685915 1.55443656]
# Device time: 1.9637 seconds
#
# Iters. done: 48 [Current cost: -1.051504948965129]
# Current parameters: [1.6131568  1.57685915 1.55443656]
# Device time: 1.7103 seconds
#
# Total time: 84.8431742191 seconds
# Total device time: 84.8244118690 seconds
# Total classical optimizer time 0.0187623501

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: -1.051504948965129
#        x: [ 1.613e+00  1.577e+00  1.554e+00]
#     nfev: 48
#    maxcv: 0.0

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.886718568651
#   - computed part:      -1.051504948965
#   - FreezeCoreTransformer extracted energy part: -7.835213619686
# ~ Nuclear repulsion energy (Hartree): 1.050719195685
# > Total ground state energy (Hartree): -7.835999372966
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8551872  0.0  0.0]

# %%
from qiskit_algorithms import NumPyMinimumEigensolver


sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(hamiltonian)
result = problem.interpret(sol)
print(result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.914327525084
#   - computed part:      -1.079113905398
#   - FreezeCoreTransformer extracted energy part: -7.835213619686
# ~ Nuclear repulsion energy (Hartree): 1.050719195685
# > Total ground state energy (Hartree): -7.863608329399
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8551872  0.0  0.0]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
