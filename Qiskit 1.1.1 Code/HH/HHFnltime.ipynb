# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# * Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# * Qiskit Runtime (`pip install qiskit-ibm-runtime`) 0.22 or later
# * SciPy (`python -m pip install scipy`)

# %%
import numpy as np
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import Aer
try:
    backend = Aer.get_backend('aer_simulator_statevector_gpu')
    backend.set_options(device='GPU')
    backend.set_options(cuStateVec_enable=False)
    print("GPU options set successfully." , backend)
except Exception as e:
    print(f"Failed to set GPU options: {e}")
# Out:
# GPU options set successfully. AerSimulator('aer_simulator_statevector_gpu')

# %%
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.drivers import PySCFDriver

molecule = MoleculeInfo(
        # Coordinates in Angstrom
        symbols=["H", "H"],
        coords=([0.0, 0.0, 0.0], [1.6895640, 0.0, 0.0]),
        multiplicity=1,  # = 2*spin + 1
        charge=0,
    )


driver = PySCFDriver.from_molecule(molecule)
properties = driver.run()

problem = FreezeCoreTransformer(
    freeze_core=True, 
).transform(properties)

num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

mapper = ParityMapper(num_particles=num_particles)
hamiltonian = mapper.map(problem.second_q_ops()[0])
hamiltonian
# Out:
# SparsePauliOp(['II', 'IZ', 'ZI', 'ZZ', 'XX'],
#               coeffs=[-0.97846545+0.j,  0.09735879+0.j, -0.09735879+0.j, -0.00287021+0.j,
#   0.24143891+0.j])

# %%
init_state = HartreeFock( num_spatial_orbitals, num_particles, mapper)
var_form = UCCSD( num_spatial_orbitals, num_particles, mapper, initial_state=init_state)
var_form.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params1 = var_form.num_parameters
print(f"using usscd = {num_params1}")
# Out:
# using usscd = 3

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(var_form)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
 
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print("")
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")
  

    return energy

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
   
}

# %%
x0 =  np.pi * np.random.random(num_params1)

# %%
x0
# Out:
# array([0.89155152, 1.76344476, 2.50417308])

# %%
import time

classical_time = 0
device_time = 0
ttl_device_time = 0

def timed_cost_func(x, *args):
    global device_time , ttl_device_time
    ansatz_isa, hamiltonian_isa, estimator = args
    start_device_time = time.time()
    
    cost = cost_func(x, ansatz_isa, hamiltonian_isa, estimator )

    end_device_time = time.time()
    device_time = end_device_time - start_device_time
    ttl_device_time += device_time
    
    return cost



def callback(xk):
    global classical_time
    
    print(f"Current parameters: {xk}")
    print(f"Device (GPU) time: {device_time:.4f} seconds")

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    start_classical_time = time.time()
    res = minimize(
        timed_cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="slsqp",
        callback=callback,
    
        
    )
    end_classical_time = time.time()
    classical_time += end_classical_time - start_classical_time
    print("")
    print(f"Total time: {classical_time:.10f} seconds")
    print(f"Total device time: {ttl_device_time:.10f} seconds")
    print(f"Total classical optimizer time { classical_time - ttl_device_time:.10f} " )
# Out:
# Iters. done: 1 [Current cost: -0.837564378623465]
#
# Iters. done: 2 [Current cost: -0.8374529275673163]
#
# Iters. done: 3 [Current cost: -0.832008090244973]
#
# Iters. done: 4 [Current cost: -0.8369274993699614]
#
# Iters. done: 5 [Current cost: -1.088603217401945]
# Current parameters: [  -7478.46221822 -372874.43769224  -42737.73903472]
# Device (GPU) time: 0.4760 seconds
#
# Iters. done: 6 [Current cost: -0.9962066734590843]
#
# Iters. done: 7 [Current cost: -1.0298065518740935]
#
# Iters. done: 8 [Current cost: -1.2580748659137535]
#
# Iters. done: 9 [Current cost: -1.1478543389760303]
#
# Iters. done: 10 [Current cost: -0.9727502560817436]
#
# Iters. done: 11 [Current cost: -0.7622751067720834]
#
# Iters. done: 12 [Current cost: -1.0318991555326973]
#
# Iters. done: 13 [Current cost: -1.0628602169948107]
#
# Iters. done: 14 [Current cost: -0.8740400920628113]
#
# Iters. done: 15 [Current cost: -0.9434096505307876]
#
# Iters. done: 16 [Current cost: -0.9417874268955142]
#
# Iters. done: 17 [Current cost: -0.9469938571744048]
#
# Iters. done: 18 [Current cost: -0.9482753844997112]
#
# Iters. done: 19 [Current cost: -0.9568850039945342]
# Current parameters: [ -67894.13282876 -108039.5707476   160458.39202704]
# Device (GPU) time: 0.4496 seconds
#
# Iters. done: 20 [Current cost: -1.035755192044207]
#
# Iters. done: 21 [Current cost: -0.9543323767813051]
#
# Iters. done: 22 [Current cost: -0.985761102761133]
#
# Iters. done: 23 [Current cost: -1.1319810228716725]
#
# Iters. done: 24 [Current cost: -0.7598889121120435]
#
# Iters. done: 25 [Current cost: -1.0101279585399945]
#
# Iters. done: 26 [Current cost: -1.0009458008477965]
#
# Iters. done: 27 [Current cost: -0.8655248683021539]
#
# Iters. done: 28 [Current cost: -0.8311311659764604]
#
# Iters. done: 29 [Current cost: -0.8779761421600963]
#
# Iters. done: 30 [Current cost: -0.8752325484102295]
#
# Iters. done: 31 [Current cost: -0.8815645693401032]
#
# Iters. done: 32 [Current cost: -0.8772222678664632]
#
# Iters. done: 33 [Current cost: -0.8392072173989378]
# Current parameters: [-147588.27162951  -42294.74120221   29466.41674987]
# Device (GPU) time: 0.4617 seconds
#
# Iters. done: 34 [Current cost: -0.7655612018291251]
#
# Iters. done: 35 [Current cost: -0.9965011051173118]
#
# Iters. done: 36 [Current cost: -1.0441768543664678]
#
# Iters. done: 37 [Current cost: -0.7050371635298545]
#
# Iters. done: 38 [Current cost: -1.0174911596790746]
#
# Iters. done: 39 [Current cost: -0.741933281583786]
#
# Iters. done: 40 [Current cost: -0.7434001541705824]
#
# Iters. done: 41 [Current cost: -0.8583259030955281]
#
# Iters. done: 42 [Current cost: -1.040961773756758]
#
# Iters. done: 43 [Current cost: -0.8736847149681232]
#
# Iters. done: 44 [Current cost: -0.8729733264777343]
#
# Iters. done: 45 [Current cost: -0.8676901414135222]
#
# Iters. done: 46 [Current cost: -0.8667729818818792]
#
# Iters. done: 47 [Current cost: -0.804698903490595]
# Current parameters: [-18991.06264944  -6807.77006817   3777.80489769]
# Device (GPU) time: 0.5185 seconds
#
# Iters. done: 48 [Current cost: -0.9666899474607231]
#
# Iters. done: 49 [Current cost: -0.8341220912545865]
#
# Iters. done: 50 [Current cost: -0.9794414473282674]
#
# Iters. done: 51 [Current cost: -0.9266813413824276]
#
# Iters. done: 52 [Current cost: -0.9295330799368624]
#
# Iters. done: 53 [Current cost: -1.0070707045846161]
#
# Iters. done: 54 [Current cost: -1.0407210563779516]
#
# Iters. done: 55 [Current cost: -1.0834267743893262]
#
# Iters. done: 56 [Current cost: -0.8565738917365947]
#
# Iters. done: 57 [Current cost: -1.0298530215638526]
#
# Iters. done: 58 [Current cost: -1.0304354929531123]
#
# Iters. done: 59 [Current cost: -1.0275240377407908]
#
# Iters. done: 60 [Current cost: -1.029734625673922]
#
# Iters. done: 61 [Current cost: -1.1119007910569347]
# Current parameters: [-424.53372549 -612.9751542   238.43524944]
# Device (GPU) time: 0.5040 seconds
#
# Iters. done: 62 [Current cost: -0.990914542366987]
#
# Iters. done: 63 [Current cost: -0.9889888613128334]
#
# Iters. done: 64 [Current cost: -1.226578049203849]
#
# Iters. done: 65 [Current cost: -1.0644654050383748]
#
# Iters. done: 66 [Current cost: -1.0077225835391772]
#
# Iters. done: 67 [Current cost: -1.2473705383821458]
#
# Iters. done: 68 [Current cost: -1.0632395806242063]
#
# Iters. done: 69 [Current cost: -1.2065908326005443]
#
# Iters. done: 70 [Current cost: -1.1154246283188285]
#
# Iters. done: 71 [Current cost: -1.0640725538383098]
#
# Iters. done: 72 [Current cost: -1.0633521395313916]
#
# Iters. done: 73 [Current cost: -1.066933177216553]
#
# Iters. done: 74 [Current cost: -1.0645556487302332]
#
# Iters. done: 75 [Current cost: -1.0059338698241387]
# Current parameters: [-237.46454839 -515.23231227  150.51185834]
# Device (GPU) time: 0.5286 seconds
#
# Iters. done: 76 [Current cost: -1.1380600561626657]
#
# Iters. done: 77 [Current cost: -1.1567012405430672]
#
# Iters. done: 78 [Current cost: -1.1146856114555717]
#
# Iters. done: 79 [Current cost: -1.0909873651910822]
#
# Iters. done: 80 [Current cost: -1.074399793479295]
#
# Iters. done: 81 [Current cost: -1.076227688653768]
#
# Iters. done: 82 [Current cost: -1.0711468552113161]
#
# Iters. done: 83 [Current cost: -1.0719640385127172]
#
# Iters. done: 84 [Current cost: -1.0672193060537736]
#
# Iters. done: 85 [Current cost: -1.0653963269583175]
#
# Iters. done: 86 [Current cost: -1.065472061679569]
#
# Iters. done: 87 [Current cost: -1.0702202481462533]
#
# Iters. done: 88 [Current cost: -1.0632992166060455]
#
# Iters. done: 89 [Current cost: -1.0631907066409603]
# Current parameters: [-235.2661638  -514.58548017  149.82980622]
# Device (GPU) time: 0.5016 seconds
#
# Iters. done: 90 [Current cost: -1.0706108776307042]
#
# Iters. done: 91 [Current cost: -1.068260802078543]
#
# Iters. done: 92 [Current cost: -1.0672749532765122]
#
# Iters. done: 93 [Current cost: -1.069078359402237]
#
# Iters. done: 94 [Current cost: -1.0682583485357813]
#
# Iters. done: 95 [Current cost: -1.0665761579865758]
#
# Iters. done: 96 [Current cost: -1.0698945959289197]
#
# Iters. done: 97 [Current cost: -1.0709117099382102]
#
# Iters. done: 98 [Current cost: -1.067193206622069]
#
# Iters. done: 99 [Current cost: -1.0672628974724627]
#
# Iters. done: 100 [Current cost: -1.0702788044491143]
#
# Iters. done: 101 [Current cost: -1.069876237490706]
#
# Iters. done: 102 [Current cost: -1.0651788422741917]
#
# Iters. done: 103 [Current cost: -1.1841976200090158]
# Current parameters: [-163.08441397 -418.04822302  241.0956863 ]
# Device (GPU) time: 0.4822 seconds
#
# Iters. done: 104 [Current cost: -1.0914848994533175]
#
# Iters. done: 105 [Current cost: -1.0317123466026576]
#
# Iters. done: 106 [Current cost: -0.6862945664827171]
#
# Iters. done: 107 [Current cost: -1.0001111373356821]
#
# Iters. done: 108 [Current cost: -0.9385173255954098]
#
# Iters. done: 109 [Current cost: -1.0700489958344883]
#
# Iters. done: 110 [Current cost: -0.7440697186886658]
#
# Iters. done: 111 [Current cost: -0.9230443612550032]
#
# Iters. done: 112 [Current cost: -1.0273907804541749]
#
# Iters. done: 113 [Current cost: -1.0571822161643398]
#
# Iters. done: 114 [Current cost: -1.0583298791396105]
#
# Iters. done: 115 [Current cost: -1.0680541866383066]
#
# Iters. done: 116 [Current cost: -1.063311637314745]
#
# Iters. done: 117 [Current cost: -0.9189254447937789]
# Current parameters: [1948.29055333 2405.94400878 2910.91625507]
# Device (GPU) time: 0.4802 seconds
#
# Iters. done: 118 [Current cost: -1.0016502111568286]
#
# Iters. done: 119 [Current cost: -0.9446852977798719]
#
# Iters. done: 120 [Current cost: -0.9732643312880221]
#
# Iters. done: 121 [Current cost: -0.9228371925171432]
#
# Iters. done: 122 [Current cost: -1.1643620169850861]
#
# Iters. done: 123 [Current cost: -0.8472086643073925]
#
# Iters. done: 124 [Current cost: -1.0385602015691506]
#
# Iters. done: 125 [Current cost: -0.754976164660374]
#
# Iters. done: 126 [Current cost: -0.9850683031169032]
#
# Iters. done: 127 [Current cost: -0.9195827157736454]
#
# Iters. done: 128 [Current cost: -0.9172553348755995]
#
# Iters. done: 129 [Current cost: -0.921907414841011]
#
# Iters. done: 130 [Current cost: -0.9186785013649026]
#
# Iters. done: 131 [Current cost: -0.907883212039655]
# Current parameters: [-233.11801957 -511.71908317  152.54075034]
# Device (GPU) time: 0.4842 seconds
#
# Iters. done: 132 [Current cost: -0.9152281253274024]
#
# Iters. done: 133 [Current cost: -0.9159856541684384]
#
# Iters. done: 134 [Current cost: -0.9157982464460326]
#
# Iters. done: 135 [Current cost: -0.9124358185829811]
#
# Iters. done: 136 [Current cost: -0.924616527501617]
#
# Iters. done: 137 [Current cost: -0.9191227440161663]
#
# Iters. done: 138 [Current cost: -0.9197435501194733]
#
# Iters. done: 139 [Current cost: -0.9151707779076481]
#
# Iters. done: 140 [Current cost: -0.9199501034463083]
#
# Iters. done: 141 [Current cost: -0.9166059784484064]
#
# Iters. done: 142 [Current cost: -0.9172386480418175]
#
# Iters. done: 143 [Current cost: -0.9194558439519898]
#
# Iters. done: 144 [Current cost: -0.9177249036664803]
#
# Iters. done: 145 [Current cost: -0.9157030420227116]
# Current parameters: [-233.08561849 -511.67574644  152.58170732]
# Device (GPU) time: 0.5061 seconds
#
# Iters. done: 146 [Current cost: -0.917751111246482]
#
# Iters. done: 147 [Current cost: -0.9192395745671587]
#
# Iters. done: 148 [Current cost: -0.9171482143869412]
#
# Iters. done: 149 [Current cost: -0.9192700522609517]
#
# Iters. done: 150 [Current cost: -0.9197453584647861]
#
# Iters. done: 151 [Current cost: -0.9226310901504993]
#
# Iters. done: 152 [Current cost: -0.9152190686882343]
#
# Iters. done: 153 [Current cost: -0.9208805690167925]
#
# Iters. done: 154 [Current cost: -0.9162507596087247]
#
# Iters. done: 155 [Current cost: -0.917146860116711]
#
# Total time: 75.7278087139 seconds
# Total device time: 75.6708357334 seconds
# Total classical optimizer time 0.0569729805

# %%
res.x
# Out:
# array([-233.08583576, -511.67603922,  152.58201   ])

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
# !nvidia-smi
# Out:
# Tue Oct  8 12:20:21 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-PCIE-40GB          Off |   00000000:3B:00.0 Off |                    0 |
# | N/A   35C    P0             36W /  250W |     846MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   3114821      C   ...iniconda3/envs/qiskit1.1/bin/python        416MiB |
# |    0   N/A  N/A   3201673      C   python                                        416MiB |
# +-----------------------------------------------------------------------------------------+

# %%
res
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -0.917146860116711
#        x: [-2.331e+02 -5.117e+02  1.526e+02]
#      nit: 11
#      jac: [-4.246e+04 -1.913e+05 -7.509e+04]
#     nfev: 155
#     njev: 11

# %%
from qiskit_algorithms import MinimumEigensolverResult

result = MinimumEigensolverResult()
result.eigenvalue = res.fun
interpreted_result = problem.interpret(result)
print(interpreted_result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -0.917146860117
#   - computed part:      -0.917146860117
#   - FreezeCoreTransformer extracted energy part: 0.0
# ~ Nuclear repulsion energy (Hartree): 0.313203412786
# > Total ground state energy (Hartree): -0.603943447331
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.19281323  0.0  0.0]

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# True

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# True

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.29.0'

# %%
import qiskit

qiskit.version.get_version_info()
# Out:
# '1.1.1'
